# %% [markdown]
# ## 1. Syntactic Patterns for Technical Terms ##

# %%
import nltk
from nltk.corpus import brown

# %% [markdown]
# As seen in the Manning and Schuetze chapter, there is a well-known part-of-speech
# based pattern defined by Justeson and Katz for identifying simple noun phrases
# that often words well for pulling out keyphrases.
#
#  Technical Term  T = (A | N)+ (N | C)  | N
#
# Below, write a function to  define a chunker using the RegexpParser as illustrated in the NLTK book Chapter 7 section 2.3 *Chunking with Regular Expressions*.  You'll need to revise the grammar rules shown there to match the pattern shown above.  You can be liberal with your definition of what is meant by *N* here.  Also, C refers to cardinal number, which is CD in the brown corpus.

# %%
def reg_chunking(sentence):
    grammar = "TT: {(<JJ>|<NN>)+(<NN>|<IN>)|<NN>}"
    cp = nltk.RegexpParser(grammar)
    result = cp.parse(sentence)
    return result

# %% [markdown]
# Below, write a function to call the chunker, run it on some sentences, and then print out the results for  those sentences.
#
# For uniformity, please run it on sentences 100 through 104 from the full tagged brown corpus.

# %%
for genre in brown.categories():
    for sent in brown.tagged_sents(categories=genre)[100:104]:
        print(reg_chunking(sent))
# Out:
# (S We'll/PPSS+MD work/VB hard/RB ,/, Mr./NP Morgan/NP ''/'' ./.)
# (S ``/`` I'll/PPSS+MD see/VB ''/'' ,/, Morgan/NP said/VBD ./.)
# (S
#   ``/``
#   Right/QL
#   now/RB
#   you/PPSS
#   need/MD
#   a/AT
#   (TT meal/NN)
#   and/CC
#   a/AT
#   (TT bath/NN)
#   ./.)
# (S Your/PP$ wife's/NN+BEZ in/IN (TT terrible/JJ shape/NN) ''/'' ./.)
# (S
#   In/IN
#   the/AT
#   (TT past/NN)
#   ,/,
#   the/AT
#   duties/NNS
#   of/IN
#   the/AT
#   (TT state/NN)
#   ,/,
#   as/CS
#   Sir/NP
#   Henry/NP
#   Maine/NP
#   noted/VBD
#   long/RB
#   ago/RB
#   ,/,
#   were/BED
#   only/RB
#   two/CD
#   in/IN
#   (TT number/NN)
#   :/:
#   (TT internal/JJ order/NN)
#   and/CC
#   (TT external/JJ security/NN)
#   ./.)
# (S
#   By/IN
#   prevailing/VBG
#   over/IN
#   other/AP
#   claimants/NNS
#   for/IN
#   the/AT
#   loyalties/NNS
#   of/IN
#   men/NNS
#   ,/,
#   the/AT
#   (TT nation-state/NN)
#   maintained/VBD
#   an/AT
#   (TT adequate/JJ measure/NN of/IN)
#   (TT certainty/NN)
#   and/CC
#   (TT order/NN within/IN)
#   its/PP$
#   territorial/JJ
#   borders/NNS
#   ./.)
# (S
#   Outside/IN
#   those/DTS
#   limits/NNS
#   it/PPS
#   asserted/VBD
#   ,/,
#   as/CS
#   against/IN
#   other/AP
#   states/NNS
#   ,/,
#   a/AT
#   (TT position/NN of/IN)
#   (TT sovereign/NN equality/NN)
#   ,/,
#   and/CC
#   ,/,
#   as/CS
#   against/IN
#   the/AT
#   ``/``
#   inferior/JJ
#   ''/''
#   peoples/NNS
#   of/IN
#   the/AT
#   (TT non-Western/JJ world/NN)
#   ,/,
#   a/AT
#   (TT position/NN of/IN)
#   (TT dominance/NN)
#   ./.)
# (S
#   It/PPS
#   became/VBD
#   the/AT
#   sole/JJ
#   ``/``
#   (TT subject/NN)
#   ''/''
#   of/IN
#   ``/``
#   (TT international/JJ law/NN)
#   ''/''
#   (/(
#   a/AT
#   (TT term/NN)
#   which/WDT
#   ,/,
#   it/PPS
#   is/BEZ
#   pertinent/JJ
#   to/TO
#   remember/VB
#   ,/,
#   was/BEDZ
#   coined/VBN
#   by/IN
#   Bentham/NP
#   )/)
#   ,/,
#   a/AT
#   (TT body/NN of/IN)
#   (TT legal/JJ principle/NN)
#   which/WDT
#   by/IN
#   and/CC
#   large/JJ
#   was/BEDZ
#   made/VBN
#   up/RP
#   of/IN
#   what/WDT
#   Western/JJ-TL
#   nations/NNS
#   could/MD
#   do/DO
#   in/IN
#   the/AT
#   (TT world/NN arena/NN)
#   ./.)
# (S
#   (TT Such/JJ support/NN)
#   should/MD
#   not/*
#   be/BE
#   difficult/JJ
#   to/TO
#   come/VB
#   by/RB
#   if/CS
#   all/ABN
#   the/AT
#   plans/NNS
#   to/TO
#   be/BE
#   presented/VBN
#   by/IN
#   the/AT
#   (TT NCTA/NN)
#   are/BER
#   as/QL
#   attractive/JJ
#   as/CS
#   this/DT
#   (TT outline/NN of/IN)
#   (TT express/NN)
#   buses/NNS
#   coming/VBG
#   into/IN
#   the/AT
#   downtown/NR
#   (TT area/NN)
#   ./.)
# (S
#   Because/CS
#   the/AT
#   buses/NNS
#   would/MD
#   not/*
#   stop/VB
#   on/IN
#   the/AT
#   (TT parkway/NN)
#   ,/,
#   (TT land/NN for/IN)
#   (TT bus/NN)
#   stations/NNS
#   and/CC
#   for/IN
#   parking/VBG
#   areas/NNS
#   nearby/RB
#   will/MD
#   be/BE
#   needed/VBN
#   ./.)
# (S
#   The/AT
#   (TT NCTA/NN)
#   is/BEZ
#   well/QL
#   advised/VBN
#   to/TO
#   seek/VB
#   funds/NNS
#   for/IN
#   this/DT
#   (TT purpose/NN from/IN)
#   the/AT
#   (TT present/JJ session/NN of/IN)
#   Congress/NP
#   ./.)
# (S Must/MD-HL Berlin/NP-HL remain/VB-HL divided/VBN-HL ?/.-HL ?/.-HL)
# (S
#   ``/``
#   I/PPSS
#   think/VB
#   by/IN
#   the/AT
#   (TT end/NN of/IN)
#   next/AP
#   (TT week/NN)
#   he/PPS
#   could/MD
#   get/VB
#   out/RP
#   in/IN
#   the/AT
#   (TT air/NN)
#   a/AT
#   little/JJ
#   ./.)
# (S
#   He/PPS
#   could/MD
#   now/RB
#   but/CC
#   the/AT
#   (TT weakness/NN)
#   is/BEZ
#   very/QL
#   definite/JJ
#   ;/.
#   ;/.)
# (S
#   it/PPS
#   would/MD
#   exhaust/VB
#   him/PPO
#   further/RBR
#   and/CC
#   unnecessarily/RB
#   ./.)
# (S He'll/PPS+MD be/BE stronger/JJR soon/RB ''/'' ./.)
# (S Dallas/NP ,/, Tex./NP ;/. ;/.)
# (S Denver/NP ,/, Colo./NP ;/. ;/.)
# (S Detroit/NP ,/, Mich./NP ;/. ;/.)
# (S Kansas/NP-TL City/NN-TL ,/, Mo./NP ;/. ;/.)
# (S But/CC don't/DO* worry/VB ./.)
# (S
#   Before/CS
#   your/PP$
#   first/OD
#   training/VBG
#   (TT experiment/NN)
#   has/HVZ
#   ended/VBN
#   there/EX
#   will/MD
#   be/BE
#   a/AT
#   (TT big/JJ improvement/NN)
#   and/CC
#   almost/RB
#   before/CS
#   you/PPSS
#   know/VB
#   it/PPO
#   you'll/PPSS+MD
#   be/BE
#   raising/VBG
#   and/CC
#   lowering/VBG
#   yourself/PPL
#   just/RB
#   like/CS
#   a/AT
#   (TT veteran/NN)
#   !/.
#   !/.)
# (S
#   Although/CS
#   I/PPSS
#   suggested/VBD
#   that/CS
#   you/PPSS
#   hold/VB
#   the/AT
#   (TT bar/NN at/IN)
#   the/AT
#   (TT back/NN of/IN)
#   the/AT
#   (TT neck/NN)
#   there's/EX+BEZ
#   no/AT
#   (TT reason/NN)
#   why/WRB
#   you/PPSS
#   shouldn't/MD*
#   make/VB
#   some/DTI
#   experiments/NNS
#   with/IN
#   the/AT
#   (TT bar/NN)
#   held/VBN
#   in/IN
#   (TT front/NN of/IN)
#   the/AT
#   (TT neck/NN)
#   ./.)
# (S
#   Squat-style/JJ
#   lifters/NNS
#   and/CC
#   (TT leg-split/NN)
#   lifters/NNS
#   would/MD
#   both/ABX
#   benefit/VB
#   enormously/RB
#   by/IN
#   practicing/VBG
#   those/DTS
#   variations/NNS
#   providing/CS
#   that/CS
#   they/PPSS
#   remember/VB
#   to/TO
#   make/VB
#   alternate/JJ
#   sets/NNS
#   with/IN
#   the/AT
#   left/JJ
#   and/CC
#   (TT right/JJ leg/NN to/IN)
#   the/AT
#   (TT front/NN)
#   ./.)
# (S
#   I/PPSS
#   couldn't/MD*
#   invite/VB
#   Viola/NP
#   to/IN
#   our/PP$
#   (TT house/NN)
#   ,/,
#   for/CS
#   Mother/NN-TL
#   snobbishly/RB
#   refused/VBD
#   to/TO
#   receive/VB
#   her/PPO
#   ./.)
# (S
#   Now/RB
#   the/AT
#   Czarship/NN-TL
#   had/HVD
#   not/*
#   affected/VBN
#   my/PP$
#   (TT own/JJ sense/NN of/IN)
#   social/JJ
#   values/NNS
#   ,/,
#   but/CC
#   Mother/NN-TL
#   had/HVD
#   attained/VBN
#   a/AT
#   reflected/VBN
#   (TT glory/NN through/IN)
#   it/PPO
#   ,/,
#   which/WDT
#   had/HVD
#   opened/VBN
#   the/AT
#   doors/NNS
#   of/IN
#   Los/NP-TL
#   Angeles-Pasadena/NP-TL
#   Society/NN-TL
#   to/IN
#   her/PPO
#   ./.)
# (S
#   There/RB
#   ,/,
#   Mother/NN-TL
#   was/BEDZ
#   received/VBN
#   by/IN
#   the/AT
#   scions/NNS
#   of/IN
#   aristocratic/JJ
#   lines/NNS
#   which/WDT
#   are/BER
#   dominated/VBN
#   by/IN
#   the/AT
#   Budweisers/NPS
#   (/(
#   of/IN
#   (TT beer/NN derivation/NN)
#   )/)
#   ,/,
#   the/AT
#   Chalmers/NPS
#   (/(
#   of/IN
#   (TT underwear/NN origin/NN)
#   )/)
#   ,/,
#   and/CC
#   the/AT
#   Heinzes/NPS
#   (/(
#   whose/WP$
#   forbears/NNS
#   founded/VBD
#   a/AT
#   nationally/RB
#   (TT famous/JJ trade/NN in/IN)
#   pickles/NNS
#   )/)
#   ./.)
# (S
#   I/PPSS
#   hated/VBD
#   being/BEG
#   dragged/VBN
#   into/IN
#   the/AT
#   salons/NNS
#   of/IN
#   these/DTS
#   aristocrats/NNS
#   ./.)
# (S
#   The/AT
#   (TT use/NN of/IN)
#   high/JJ
#   voltages/NNS
#   and/CC
#   low/JJ
#   currents/NNS
#   by/IN
#   (TT proper/JJ design/NN)
#   to/TO
#   reduce/VB
#   (TT electron/NN heat/NN transfer/NN to/IN)
#   the/AT
#   (TT anode/NN for/IN)
#   a/AT
#   given/VBN
#   (TT power/NN output/NN)
#   ./.)
# (S 2/CD ./.)
# (S
#   (TT Continuous/JJ motion/NN of/IN)
#   the/AT
#   (TT arc/NN contact/NN area/NN at/IN)
#   the/AT
#   (TT anode/NN by/IN)
#   (TT flow/NN)
#   or/CC
#   magnetic/JJ
#   forces/NNS
#   ./.)
# (S 3/CD ./.)
# (S No/AT one/PN else/RB must/MD know/VB ./.)
# (S
#   Thus/RB
#   ,/,
#   in/IN
#   the/AT
#   (TT immemorial/JJ way/NN)
#   --/--
#   in/IN
#   the/AT
#   (TT way/NN of/IN)
#   the/AT
#   (TT right/JJ hand/NN)
#   that/WPS
#   knows/VBZ
#   and/CC
#   the/AT
#   left/JJ
#   that/WPS
#   does/DOZ
#   not/*
#   --/--
#   was/BEDZ
#   the/AT
#   (TT stage/NN)
#   set/VBN
#   for/IN
#   (TT tragedy/NN at/IN)
#   Bari/NP
#   ./.)
# (S
#   It/PPS
#   was/BEDZ
#   the/AT
#   (TT night/NN of/IN)
#   December/NP
#   2/CD
#   ,/,
#   1943/CD
#   ,/,
#   and/CC
#   it/PPS
#   was/BEDZ
#   growing/VBG
#   (TT dark/JJ in/IN)
#   Bari/NP
#   ./.)
# (S
#   It/PPS
#   was/BEDZ
#   getting/VBG
#   on/RP
#   toward/IN
#   7/CD
#   o'clock/RB
#   and/CC
#   the/AT
#   (TT German/JJ Me-210/NN plane/NN)
#   had/HVD
#   been/BEN
#   and/CC
#   gone/VBN
#   on/IN
#   its/PP$
#   eighth/OD
#   (TT straight/JJ visit/NN)
#   ./.)
# (S
#   Perhaps/RB
#   this/DT
#   was/BEDZ
#   (TT reality/NN)
#   and/CC
#   Dale/NP
#   Nelson/NP
#   ,/,
#   the/AT
#   (TT actor/NN)
#   ,/,
#   was/BEDZ
#   (TT delusion/NN)
#   ;/.
#   ;/.)
# (S
#   a/AT
#   (TT figment/NN of/IN)
#   Carl/NP
#   Anderson's/NP$
#   (TT imagination/NN)
#   ./.)
# (S Four/CD-HL)
# (S
#   I/PPSS
#   had/HVD
#   come/VBN
#   to/IN
#   Chicago/NP
#   from/IN
#   New/JJ-TL
#   York/NP-TL
#   early/RB
#   in/IN
#   September/NP
#   with/IN
#   a/AT
#   (TT dramatic/JJ production/NN)
#   called/VBN
#   Ask/VB-TL
#   Tony/NP-TL
#   ./.)
# (S
#   Daniel/NP
#   personally/RB
#   led/VBD
#   the/AT
#   (TT fight/NN for/IN)
#   the/AT
#   (TT measure/NN)
#   ,/,
#   which/WDT
#   he/PPS
#   had/HVD
#   watered/VBN
#   down/RP
#   considerably/RB
#   since/IN
#   its/PP$
#   (TT rejection/NN by/IN)
#   two/CD
#   previous/JJ
#   Legislatures/NNS-TL
#   ,/,
#   in/IN
#   a/AT
#   (TT public/JJ hearing/NN before/IN)
#   the/AT
#   House/NN-TL
#   Committee/NN-TL
#   on/IN-TL
#   Revenue/NN-TL
#   and/CC-TL
#   Taxation/NN-TL
#   ./.)
# (S
#   Under/IN
#   (TT committee/NN)
#   rules/NNS
#   ,/,
#   it/PPS
#   went/VBD
#   automatically/RB
#   to/IN
#   a/AT
#   (TT subcommittee/NN for/IN)
#   one/CD
#   (TT week/NN)
#   ./.)
# (S
#   But/CC
#   questions/NNS
#   with/IN
#   which/WDT
#   (TT committee/NN)
#   members/NNS
#   taunted/VBD
#   bankers/NNS
#   appearing/VBG
#   as/CS
#   witnesses/NNS
#   left/VBD
#   little/AP
#   (TT doubt/NN)
#   that/CS
#   they/PPSS
#   will/MD
#   recommend/VB
#   (TT passage/NN of/IN)
#   it/PPO
#   ./.)
# (S
#   Daniel/NP
#   termed/VBD
#   ``/``
#   extremely/RB
#   conservative/JJ
#   ''/''
#   his/PP$
#   (TT estimate/NN)
#   that/CS
#   it/PPS
#   would/MD
#   produce/VB
#   17/CD
#   million/CD
#   dollars/NNS
#   to/TO
#   help/VB
#   erase/VB
#   an/AT
#   anticipated/VBN
#   (TT deficit/NN of/IN)
#   63/CD
#   million/CD
#   dollars/NNS
#   at/IN
#   the/AT
#   (TT end/NN of/IN)
#   the/AT
#   (TT current/JJ fiscal/JJ year/NN)
#   next/AP
#   Aug./NP
#   31/CD
#   ./.)
# (S
#   In/IN
#   the/AT
#   (TT absence/NN of/IN)
#   a/AT
#   truly/RB
#   (TT adequate/JJ conceptuality/NN in/IN)
#   which/WDT
#   the/AT
#   (TT gospel/NN)
#   can/MD
#   be/BE
#   expressed/VBN
#   ,/,
#   the/AT
#   (TT unavoidable/JJ need/NN)
#   to/TO
#   demythologize/VB
#   it/PPO
#   makes/VBZ
#   (TT use/NN of/IN)
#   whatever/WDT
#   resources/NNS
#   are/BER
#   at/IN
#   (TT hand/NN)
#   --/--
#   and/CC
#   this/DT
#   usually/RB
#   means/VBZ
#   one/CD
#   or/CC
#   another/DT
#   of/IN
#   the/AT
#   various/JJ
#   forms/NNS
#   of/IN
#   ``/``
#   (TT folk/NN religion/NN)
#   ''/''
#   (TT current/JJ in/IN)
#   the/AT
#   (TT situation/NN)
#   ./.)
# (S
#   This/DT
#   is/BEZ
#   not/*
#   to/TO
#   say/VB
#   that/CS
#   the/AT
#   only/AP
#   (TT explanation/NN of/IN)
#   the/AT
#   (TT present/JJ infatuation/NN with/IN)
#   Norman/NP
#   Vincent/NP
#   Peale's/NP$
#   ``/``
#   (TT cult/NN of/IN)
#   (TT reassurance/NN)
#   ''/''
#   or/CC
#   the/AT
#   other/AP
#   types/NNS
#   of/IN
#   a/AT
#   purely/QL
#   cultural/JJ
#   Christianity/NP
#   is/BEZ
#   the/AT
#   (TT ever-present/JJ need/NN for/IN)
#   a/AT
#   demythologized/VBN
#   (TT gospel/NN)
#   ./.)
# (S
#   But/CC
#   it/PPS
#   is/BEZ
#   to/TO
#   say/VB
#   that/CS
#   this/DT
#   (TT need/NN)
#   is/BEZ
#   far/QL
#   more/QL
#   (TT important/JJ for/IN)
#   (TT such/JJ infatuation/NN)
#   than/CS
#   most/AP
#   of/IN
#   the/AT
#   pundits/NNS
#   seem/VB
#   to/TO
#   have/HV
#   suspected/VBN
#   ./.)
# (S
#   However/RB
#   ,/,
#   even/RB
#   if/CS
#   the/AT
#   (TT latent/JJ demand/NN for/IN)
#   (TT demythologization/NN)
#   is/BEZ
#   not/*
#   nearly/RB
#   as/QL
#   widespread/JJ
#   as/CS
#   we/PPSS
#   are/BER
#   claiming/VBG
#   ,/,
#   at/IN
#   least/AP
#   among/IN
#   the/AT
#   cultured/VBN
#   elements/NNS
#   of/IN
#   the/AT
#   (TT population/NN)
#   there/EX
#   tends/VBZ
#   to/TO
#   be/BE
#   an/AT
#   almost/QL
#   (TT complete/JJ indifference/NN to/IN)
#   the/AT
#   (TT church/NN)
#   and/CC
#   its/PP$
#   (TT traditional/JJ message/NN of/IN)
#   (TT sin/NN)
#   and/CC
#   (TT grace/NN)
#   ./.)
# (S
#   His/PP$
#   (TT addle-brained/JJ knight-errant/NN)
#   ,/,
#   (TT self-appointed/JJ to/IN)
#   the/AT
#   (TT ridiculous/JJ position/NN in/IN)
#   an/AT
#   (TT age/NN)
#   when/WRB
#   (TT armor/NN)
#   had/HVD
#   already/RB
#   been/BEN
#   relegated/VBN
#   to/IN
#   museums/NNS
#   and/CC
#   the/AT
#   (TT chivalrous/JJ code/NN of/IN)
#   (TT knight-errantry/NN)
#   had/HVD
#   become/VBN
#   a/AT
#   (TT joke/NN)
#   ,/,
#   is/BEZ
#   ,/,
#   as/CS
#   Cervantes/NP
#   no/AT
#   (TT doubt/NN)
#   intended/VBD
#   ,/,
#   a/AT
#   gaunt/JJ
#   but/CC
#   (TT gracious/JJ symbol/NN of/IN)
#   (TT good/NN)
#   ,/,
#   moving/VBG
#   soberly/RB
#   and/CC
#   sincerely/RB
#   in/IN
#   a/AT
#   (TT world/NN of/IN)
#   cynics/NNS
#   ,/,
#   hypocrites/NNS
#   and/CC
#   rogues/NNS
#   ./.)
# (S
#   Cherkasov/NP
#   does/DOZ
#   not/*
#   caricature/VB
#   him/PPO
#   ,/,
#   as/CS
#   some/DTI
#   actors/NNS
#   have/HV
#   been/BEN
#   inclined/VBN
#   to/TO
#   do/DO
#   ./.)
# (S
#   He/PPS
#   treats/VBZ
#   this/DT
#   deep-eyed/JJ
#   ,/,
#   bearded/JJ
#   ,/,
#   (TT bony/JJ crackpot/NN with/IN)
#   (TT tangible/JJ affection/NN)
#   and/CC
#   (TT respect/NN)
#   ./.)
# (S
#   Directed/VBN
#   by/IN
#   Grigory/NP
#   Kozintsev/NP
#   in/IN
#   a/AT
#   (TT tempo/NN)
#   that/WPS
#   is/BEZ
#   studiously/QL
#   slow/JJ
#   ,/,
#   he/PPS
#   develops/VBZ
#   a/AT
#   (TT sense/NN of/IN)
#   a/AT
#   (TT high/JJ tradition/NN)
#   shining/VBG
#   brightly/RB
#   and/CC
#   passing/VBG
#   gravely/RB
#   through/IN
#   an/AT
#   (TT impious/JJ world/NN)
#   ./.)
# (S
#   The/AT
#   eyes/NNS
#   ,/,
#   blue/JJ
#   and/CC
#   always/RB
#   somewhat/QL
#   downcast/JJ
#   ,/,
#   possessed/VBD
#   a/AT
#   (TT sullen/JJ quality/NN)
#   ./.)
# (S
#   Even/RB
#   though/CS
#   the/AT
#   (TT boy/NN)
#   could/MD
#   not/*
#   see/VB
#   them/PPO
#   ,/,
#   he/PPS
#   knew/VBD
#   they/PPSS
#   were/BED
#   clouded/VBN
#   by/IN
#   (TT distance/NN)
#   ./.)
# (S
#   He/PPS
#   was/BEDZ
#   never/RB
#   sure/JJ
#   they/PPSS
#   fully/RB
#   took/VBD
#   him/PPO
#   in/RP
#   ./.)
# (S Pompeii/NP called/VBD again/RB ,/, ``/`` Laura/NP ''/'' !/. !/.)
# (S
#   A/AT
#   (TT long/JJ time/NN)
#   later/RBR
#   ,/,
#   by/IN
#   (TT cosmic/JJ clock/NN)
#   ,/,
#   she/PPS
#   said/VBD
#   ,/,
#   ``/``
#   Mike/NP
#   ?/.
#   ?/.)
# (S
#   Is/BEZ
#   that/DT
#   --/--
#   I/PPSS
#   mean/VB
#   ,/,
#   '/'
#   Do/DO
#   you/PPSS
#   know/VB
#   '/'
#   ''/''
#   --/--)
# (S ``/`` I/PPSS know/VB ./.)
# (S It/PPS is/BEZ for/IN growing/VBG closer/RBR ./.)

# %% [markdown]
# Then extract out the phrases themselves on sentences 100 through 160 using the subtree extraction technique shown in the
# *Exploring Text Corpora* category.

# %%
cp = nltk.RegexpParser('TT: {(<JJ>|<NN>)+(<NN>|<IN>)|<NN>}') 

for genre in brown.categories():
    for sent in brown.tagged_sents(categories=genre)[100:160]:
        tree = cp.parse(sent)
        for subtree in tree.subtrees():
            if subtree.label() == 'TT': print(subtree)
# Out:
# (TT meal/NN)
# (TT bath/NN)
# (TT terrible/JJ shape/NN)
# (TT fire/NN box/NN with/IN)
# (TT wood/NN)
# (TT supper/NN)
# (TT table/NN)
# (TT meal/NN)
# (TT front/JJ room/NN)
# (TT girl/NN)
# (TT supper/NN)
# (TT hair/NN)
# (TT mess/NN)
# (TT front/NN of/IN)
# (TT house/NN)
# (TT drink/NN)
# (TT sleep/NN)
# (TT front/JJ door/NN)
# (TT table/NN)
# (TT course/NN)
# (TT arm/NN)
# (TT kitchen/NN)
# (TT table/NN)
# (TT head/NN)
# (TT strong/JJ woman/NN)
# (TT meal/NN)
# (TT meal/NN)
# (TT girl/NN)
# (TT food/NN)
# (TT work/NN)
# (TT grateful/JJ way/NN)
# (TT ashamed/JJ of/IN)
# (TT expression/NN in/IN)
# (TT sure/JJ of/IN)
# (TT water/NN)
# (TT spring/NN)
# (TT tub/NN from/IN)
# (TT back/NN of/IN)
# (TT house/NN)
# (TT nail/NN in/IN)
# (TT wall/NN)
# (TT lot/NN)
# (TT bath/NN)
# (TT bad/JJ shape/NN)
# (TT town/NN)
# (TT doc/NN)
# (TT way/NN)
# (TT work/NN)
# (TT town/NN)
# (TT needle/NN)
# (TT thread/NN)
# (TT girl/NN)
# (TT dress/NN)
# (TT work/NN on/IN)
# (TT bedroom/NN)
# (TT needle/NN)
# (TT thread/NN)
# (TT bed/NN)
# (TT door/NN in/IN)
# (TT front/NN of/IN)
# (TT spare/JJ bedroom/NN)
# (TT bed/NN)
# (TT plenty/NN of/IN)
# (TT girl/NN)
# (TT past/NN)
# (TT state/NN)
# (TT number/NN)
# (TT internal/JJ order/NN)
# (TT external/JJ security/NN)
# (TT nation-state/NN)
# (TT adequate/JJ measure/NN of/IN)
# (TT certainty/NN)
# (TT order/NN within/IN)
# (TT position/NN of/IN)
# (TT sovereign/NN equality/NN)
# (TT non-Western/JJ world/NN)
# (TT position/NN of/IN)
# (TT dominance/NN)
# (TT subject/NN)
# (TT international/JJ law/NN)
# (TT term/NN)
# (TT body/NN of/IN)
# (TT legal/JJ principle/NN)
# (TT world/NN arena/NN)
# (TT corpus/NN of/IN)
# (TT law/NN)
# (TT reflection/NN of/IN)
# (TT power/NN system/NN in/IN)
# (TT existence/NN during/IN)
# (TT world/NN politics/NN)
# (TT confusion/NN)
# (TT international/JJ law/NN)
# (TT need/NN of/IN)
# (TT reexamination/NN)
# (TT clarification/NN in/IN)
# (TT light/NN of/IN)
# (TT present/JJ era/NN)
# (TT attention/NN)
# (TT statesman/NN)
# (TT scholar/NN to/IN)
# (TT idea/NN of/IN)
# (TT state/NN responsibility/NN)
# (TT true/JJ in/IN)
# (TT world/NN arena/NN)
# (TT anarchical/JJ battleground/NN)
# (TT strife/NN)
# (TT avaricious/JJ competition/NN for/IN)
# (TT sort/NN of/IN)
# (TT duty/NN)
# (TT nation/NN to/IN)
# (TT nineteenth-century/NN statesman/NN)
# (TT duty/NN)
# (TT sovereign/NN)
# (TT nation/NN)
# (TT extension/NN to/IN)
# (TT example/NN)
# (TT century/NN)
# (TT British/JJ navy/NN)
# (TT world/NN finance/NN)
# (TT national/JJ in/IN)
# (TT motivation/NN)
# (TT time/NN)
# (TT sort/NN of/IN)
# (TT societal/JJ responsibility/NN)
# (TT welfare/NN of/IN)
# (TT territorial/JJ state/NN)
# (TT incipient/JJ socialist/NN movement/NN)
# (TT present/JJ century/NN)
# (TT observable/JJ shift/NN)
# (TT national/JJ activity/NN)
# (TT concept/NN of/IN)
# (TT responsibility/NN)
# (TT process/NN of/IN)
# (TT articulation/NN)
# (TT establishment/NN)
# (TT factor/NN in/IN)
# (TT important/JJ corner/NN)
# (TT constitutional/JJ revolution/NN)
# (TT basic/JJ nature/NN of/IN)
# (TT government/NN)
# (TT negative/JJ in/IN)
# (TT nature/NN)
# (TT night-watchman/NN state/NN)
# (TT positive/JJ state/NN)
# (TT existence/NN)
# (TT special/JJ fascination/NN since/IN)
# (TT role/NN)
# (TT transformation/NN)
# (TT manner/NN in/IN)
# (TT switch/NN in/IN)
# (TT time/NN)
# (TT effect/NN)
# (TT Court-packing/NN plan/NN)
# (TT imprimatur/NN of/IN)
# (TT judicial/JJ approval/NN)
# (TT social/JJ legislation/NN)
# (TT importance/NN)
# (TT content/NN of/IN)
# (TT Labor/NN)
# (TT income/NN security/NN)
# (TT feature/NN of/IN)
# (TT American/JJ version/NN of/IN)
# (TT welfare/NN state/NN)
# (TT part/NN of/IN)
# (TT conventional/JJ wisdom/NN)
# (TT national/JJ consensus/NN of/IN)
# (TT unanimity/NN)
# (TT victory/NN in/IN)
# (TT social/JJ legislation/NN)
# (TT general/JJ acceptance/NN of/IN)
# (TT idea/NN of/IN)
# (TT responsibility/NN for/IN)
# (TT economic/JJ well-being/NN of/IN)
# (TT American/JJ constitutional/JJ history/NN)
# (TT course/NN)
# (TT conflict/NN)
# (TT century/NN)
# (TT national/JJ unity/NN over/IN)
# (TT fragmentation/NN)
# (TT importance/NN)
# (TT American/JJ immersion/NN)
# (TT involvement/NN in/IN)
# (TT world/NN)
# (TT Internal/JJ national/JJ responsibility/NN)
# (TT truism/NN)
# (TT example/NN)
# (TT employment/NN)
# (TT new/JJ concept/NN)
# (TT nation/NN)
# (TT economic/JJ depression/NN)
# (TT philosophy/NN of/IN)
# (TT government/NN)
# (TT distress/NN)
# (TT principle/NN of/IN)
# (TT siege/NN)
# (TT score/NN of/IN)
# (TT national/JJ government/NN)
# (TT responsibility/NN of/IN)
# (TT action/NN)
# (TT maximum/JJ employment/NN)
# (TT economy/NN)
# (TT conscious/JJ guidance/NN through/IN)
# (TT economic/JJ side/NN of/IN)
# (TT constitutional/JJ revolution/NN)
# (TT important/JJ legislative/JJ victory/NN of/IN)
# (TT principle/NN of/IN)
# (TT national/JJ responsibility/NN for/IN)
# (TT local/JJ economic/JJ distress/NN)
# (TT state's-responsibility/NN)
# (TT proposal/NN)
# (TT provision/NN)
# (TT payment/NN for/IN)
# (TT unemployment/NN relief/NN by/IN)
# (TT nation-wide/JJ taxation/NN rather/IN)
# (TT levy/NN)
# (TT manpower/NN surplus/NN)
# (TT long/JJ way/NN in/IN)
# (TT brief/JJ interval/NN between/IN)
# (TT Internal/JJ national/JJ responsibility/NN)
# (TT societal/JJ response/NN to/IN)
# (TT impact/NN of/IN)
# (TT assumption/NN of/IN)
# (TT collective/JJ duty/NN)
# (TT inability/NN of/IN)
# (TT era/NN)
# (TT National/JJ responsibility/NN for/IN)
# (TT individual/JJ welfare/NN)
# (TT concept/NN)
# (TT measure/NN of/IN)
# (TT widespread/JJ acceptance/NN)
# (TT statement/NN of/IN)
# (TT body/NN of/IN)
# (TT free/JJ world/NN)
# (TT majority/NN of/IN)
# (TT principle/NN)
# (TT day/NN in/IN)
# (TT court/NN)
# (TT impartial/JJ tribunal/NN)
# (TT responsibility/NN of/IN)
# (TT government/NN)
# (TT individual/JJ welfare/NN)
# (TT dynamic/JJ concept/NN)
# (TT individual/NN in/IN)
# (TT free/JJ society/NN)
# (TT responsibility/NN)
# (TT dignity/NN)
# (TT idea/NN of/IN)
# (TT national/JJ responsibility/NN)
# (TT common/JJ feature/NN of/IN)
# (TT non-Soviet/JJ world/NN)
# (TT welfare/NN)
# (TT principle/NN of/IN)
# (TT collective/JJ responsibility/NN for/IN)
# (TT individual/JJ well-being/NN)
# (TT concept/NN analogous/JJ to/IN)
# (TT principle/NN of/IN)
# (TT internal/JJ responsibility/NN)
# (TT hypothesis/NN)
# (TT evidence/NN)
# (TT proposition/NN)
# (TT content/NN)
# (TT individual/JJ security/NN)
# (TT security/NN)
# (TT existence/NN of/IN)
# (TT ideological/JJ group/NN)
# (TT free/JJ world/NN)
# (TT External/JJ national/JJ responsibility/NN)
# (TT requirement/NN)
# (TT viability/NN of/IN)
# (TT internal/JJ responsibility/NN)
# (TT acceptance/NN of/IN)
# (TT socialist/JJ ideal/NN of/IN)
# (TT equality/NN)
# (TT external/JJ responsibility/NN)
# (TT adherence/NN to/IN)
# (TT ideological/JJ supranationalism/NN)
# (TT Reference/NN to/IN)
# (TT nationalism/NN)
# (TT sovereignty/NN)
# (TT new/JJ principle/NN)
# (TT nation-state/NN)
# (TT power/NN)
# (TT influence/NN of/IN)
# (TT loyalty/NN)
# (TT breakup/NN of/IN)
# (TT downfall/NN of/IN)
# (TT feudalism/NN)
# (TT surge/NN of/IN)
# (TT nationalism/NN)
# (TT time-span/NN of/IN)
# (TT nation-state/NN)
# (TT separate/JJ existence/NN of/IN)
# (TT independent/JJ entity/NN)
# (TT natural/JJ for/IN)
# (TT nation/NN)
# (TT representative/JJ of/IN)
# (TT form/NN of/IN)
# (TT order/NN)
# (TT concept/NN of/IN)
# (TT nationalism/NN)
# (TT political/JJ principle/NN)
# (TT territorial/JJ state/NN)
# (TT characteristic/JJ type/NN of/IN)
# (TT socal/JJ structure/NN)
# (TT homeland/NN)
# (TT large/JJ group/NN of/IN)
# (TT unit/NN)
# (TT nationalism/NN)
# (TT hurricane/NN)
# (TT loose/JJ in/IN)
# (TT world/NN)
# (TT Such/JJ support/NN)
# (TT NCTA/NN)
# (TT outline/NN of/IN)
# (TT express/NN)
# (TT area/NN)
# (TT parkway/NN)
# (TT land/NN for/IN)
# (TT bus/NN)
# (TT NCTA/NN)
# (TT purpose/NN from/IN)
# (TT present/JJ session/NN of/IN)
# (TT inference/NN)
# (TT free/JJ world/NN)
# (TT dismemberment/NN of/IN)
# (TT city/NN)
# (TT record/NN)
# (TT grace/NN of/IN)
# (TT man/NN in/IN)
# (TT right/NN)
# (TT government/NN of/IN)
# (TT semi-city/NN into/IN)
# (TT zone/NN)
# (TT wartime/NN protocol/NN of/IN)
# (TT area/NN)
# (TT entire/JJ city/NN)
# (TT joint/JJ occupation/NN)
# (TT part/NN of/IN)
# (TT occupation/NN by/IN)
# (TT blockade/NN)
# (TT airlift/NN)
# (TT purpose/NN)
# (TT present/JJ administrative/JJ division/NN of/IN)
# (TT time/NN)
# (TT distinction/NN between/IN)
# (TT zone/NN of/IN)
# (TT sector/NN of/IN)
# (TT German/JJ puppet/NN government/NN into/IN)
# (TT capital/NN of/IN)
# (TT closing/NN of/IN)
# (TT border/NN)
# (TT gratuitous/JJ protest/NN over/IN)
# (TT visit/NN of/IN)
# (TT business/NN)
# (TT juvenile/JJ sound-truck/NN)
# (TT note/NN)
# (TT outside/NN)
# (TT capital/NN of/IN)
# (TT fundamental/JJ fact/NN)
# (TT whole/NN of/IN)
# (TT quadripartite/JJ status/NN)
# (TT fact/NN)
# (TT course/NN)
# (TT question/NN of/IN)
# (TT diplomatic/JJ protest/NN)
# (TT ground/NN of/IN)
# (TT action/NN)
# (TT car/NN)
# (TT glass/NN)
# (TT glass/NN)
# (TT trivial/JJ but/IN)
# (TT official/JJ hooliganism/NN)
# (TT step-by-step/JJ fate/NN of/IN)
# (TT salami/NN)
# (TT dispatch/NN of/IN)
# (TT representative/NN)
# (TT stiffening/NN of/IN)
# (TT response/NN)
# (TT buffalo/NN)
# (TT bison/NN)
# (TT man/NN on/IN)
# (TT street/NN)
# (TT mobile/JJ brown/JJ throw-rug/NN upon/IN)
# (TT dusty-green/JJ grassland/NN)
# (TT horizon/NN)
# (TT vast/JJ sun-bleached/JJ dome/NN of/IN)
# (TT sky/NN to/IN)
# (TT earth/NN)
# (TT picture/NN of/IN)
# (TT American/JJ prairie/NN)
# (TT memory/NN of/IN)
# (TT conquest/NN of/IN)
# (TT American/JJ continent/NN)
# (TT cinema/NN image/NN of/IN)
# (TT live-oak/NN)
# (TT buffalo/NN)
# (TT prairie/NN chicken/NN)
# (TT grass/NN)
# (TT whole/JJ generation/NN of/IN)
# (TT abundant/JJ supply/NN)
# (TT area/NN in/IN)
# (TT buffalo/NN)
# (TT tapestry/NN)
# (TT moth-eaten/JJ zoo/NN)
# (TT Wooded/JJ stream/NN)
# (TT earth/NN)
# (TT unbroken/JJ by/IN)
# (TT silo/NN)
# (TT barn/NN)
# (TT statistical/JJ case/NN for/IN)
# (TT new/JJ park/NN)
# (TT American/JJ history/NN)
# (TT case/NN)
# (TT distiller/NN)
# (TT customary/JJ prohibition/NN against/IN)
# (TT hard-liquor/NN advertising/NN on/IN)
# (TT TV/NN)
# (TT radio/NN)
# (TT firm/NN)
# (TT major-market/NN)
# (TT answer/NN to/IN)
# (TT kind/NN of/IN)
# (TT wedge/NN)
# (TT congressional/JJ action/NN)
# (TT such/JJ advertising/NN through/IN)
# (TT power/NN)
# (TT code/NN)
# (TT hard-liquor/NN)
# (TT public/JJ opinion/NN)
# (TT popular/JJ favor/NN for/IN)
# (TT policy/NN)
# (TT specific/JJ prohibition/NN)
# (TT state/NN)
# (TT liquor/NN)
# (TT congressional/JJ action/NN)
# (TT action/NN of/IN)
# (TT radio/NN)
# (TT TV/NN)
# (TT NAB/NN)
# (TT industry/NN)
# (TT non-code/NN)
# (TT false/JJ glamour/NN)
# (TT bourbon/NN)
# (TT whisky/NN)
# (TT pseudo-sophistication/NN with/IN)
# (TT TV/NN)
# (TT toothpaste/NN)
# (TT sad/JJ difference/NN between/IN)
# (TT viewer/NN into/IN)
# (TT bourbon/NN)
# (TT law/NN)
# (TT year/NN)
# (TT opportunity/NN)
# (TT party/NN organization/NN)
# (TT central/JJ contest/NN)
# (TT faction/NN)
# (TT responsibility/NN for/IN)
# (TT performance/NN in/IN)
# (TT office/NN)
# (TT blame/NN for/IN)
# (TT regime/NN)
# (TT law/NN enforcement/NN)
# (TT own/JJ record/NN)
# (TT hand/NN)
# (TT candidate/NN of/IN)
# (TT party/NN)
# (TT rule/NN)
# (TT interest/NN in/IN)
# (TT political/JJ power/NN)
# (TT welfare/NN)
# (TT impression/NN of/IN)
# (TT quiet/JJ competence/NN in/IN)
# (TT state/NN post/NN)
# (TT election/NN)
# (TT hand/NN)
# (TT term/NN)
# (TT free/JJ of/IN)
# (TT pressure/NN of/IN)
# (TT course/NN)
# (TT support/NN)
# (TT independent/JJ vote/NN)
# (TT reelection/NN)
# (TT labor/NN)
# (TT end/NN of/IN)
# (TT week/NN)
# (TT air/NN)
# (TT weakness/NN)
# (TT stethoscope/NN)
# (TT table/NN by/IN)
# (TT bed/NN)
# (TT cap/NN on/IN)
# (TT stethoscope/NN)
# (TT silver/NN in/IN)
# (TT room/NN)
# (TT doctor/NN)
# (TT bed/NN)
# (TT floor/NN)
# (TT disinterest/NN)
# (TT desire/NN)
# (TT school/NN)
# (TT irritability/NN)
# (TT head/NN)
# (TT number/NN of/IN)
# (TT popularity/NN contest/NN at/IN)
# (TT school/NN without/IN)
# (TT trouble/NN)
# (TT visit/NN)
# (TT light/NN of/IN)
# (TT bed/NN)
# (TT doctor/NN)
# (TT self-consciousness/NN)
# (TT characteristic/JJ of/IN)
# (TT tone/NN)
# (TT floor/NN)
# (TT slight/JJ pain/NN)
# (TT different/JJ from/IN)
# (TT throbbing/NN in/IN)
# (TT head/NN)
# (TT time/NN)
# (TT case/NN)
# (TT slipper/NN)
# (TT mate/NN at/IN)
# (TT foot/NN of/IN)
# (TT bed/NN)
# (TT time/NN)
# (TT forehead/NN)
# (TT father/NN)
# (TT constant/JJ visitor/NN)
# (TT front/JJ door/NN in/IN)
# (TT evening/NN)
# (TT deep/JJ slow/JJ voice/NN)
# (TT reply/NN)
# (TT plenty/NN of/IN)
# (TT rest/NN)
# (TT appetite/NN)
# (TT exercise/NN)
# (TT exchange/NN)
# (TT bed/NN)
# (TT word/NN of/IN)
# (TT energy/NN)
# (TT satirical/JJ about/IN)
# (TT father/NN)
# (TT father/NN)
# (TT foot/NN of/IN)
# (TT bed/NN)
# (TT son/NN)
# (TT pause/NN)
# (TT face/NN)
# (TT Branch/NN)
# (TT request/NN)
# (TT independent/JJ agency/NN)
# (TT cooperative/JJ credit/NN system/NN for/IN)
# (TT agriculture/NN)
# (TT system/NN)
# (TT credit/NN)
# (TT short-term/NN)
# (TT system/NN)
# (TT short-term/NN credit/NN to/IN)
# (TT cooperative/JJ marketing/NN)
# (TT business/NN service/NN)
# (TT source/NN of/IN)
# (TT investment/NN capital/NN)
# (TT system/NN)
# (TT beneficial/JJ to/IN)
# (TT development/NN of/IN)
# (TT credit/NN)
# (TT system/NN)
# (TT credit/NN service/NN)
# (TT authority/NN of/IN)
# (TT permanent/JJ source/NN of/IN)
# (TT credit/NN on/IN)
# (TT sound/JJ basis/NN for/IN)
# (TT available/JJ to/IN)
# (TT Commodity/NN)
# (TT capital/NN)
# (TT facility/NN)
# (TT cooperative/NN)
# (TT association/NN in/IN)
# (TT farm/NN)
# (TT farm/NN)
# (TT farm/NN business/NN)
# (TT Interest/NN)
# (TT board/NN of/IN)
# (TT bank/NN with/IN)
# (TT approval/NN of/IN)
# (TT information/NN)
# (TT region/NN)
# (TT request/NN)
# (TT exploration/NN for/IN)
# (TT financial/JJ assistance/NN to/IN)
# (TT mineral/NN)
# (TT OME/NN)
# (TT help/NN)
# (TT exploration/NN under/IN)
# (TT sole/JJ expense/NN)
# (TT applicant/NN)
# (TT sufficient/JJ interest/NN in/IN)
# (TT property/NN)
# (TT eligible/JJ applicant/NN)
# (TT one-half/NN of/IN)
# (TT cost/NN of/IN)
# (TT exploration/NN work/NN)
# (TT applicant/NN)
# (TT rest/NN of/IN)
# (TT cost/NN)
# (TT own/JJ time/NN)
# (TT work/NN)
# (TT use/NN of/IN)
# (TT equipment/NN)
# (TT share/NN of/IN)
# (TT cost/NN)
# (TT royalty/NN on/IN)
# (TT production/NN from/IN)
# (TT property/NN)
# (TT obligation/NN)
# (TT 5-percent/NN royalty/NN)
# (TT production/NN during/IN)
# (TT period/NN)
# (TT contract/NN)
# (TT effect/NN)
# (TT production/NN)
# (TT possible/JJ from/IN)
# (TT property/NN)
# (TT royalty/NN obligation/NN)
# (TT 10-year/JJ period/NN)
# (TT contract/NN)
# (TT contribution/NN)
# (TT interest/NN)
# (TT royalty/NN)
# (TT principal/NN)
# (TT interest/NN)
# (TT percent/NN)
# (TT Information/NN)
# (TT application/NN)
# (TT assistance/NN in/IN)
# (TT appropriate/JJ regional/JJ office/NN)
# (TT such/JJ programing/NN)
# (TT so-called/JJ development/NN)
# (TT analysis/NN of/IN)
# (TT attention/NN)
# (TT accurate/JJ progress/NN)
# (TT evaluation/NN)
# (TT growth/NN)
# (TT development/NN program/NN)
# (TT country/NN)
# (TT own/JJ will/NN)
# (TT goal/NN)
# (TT aid/NN program/NN in/IN)
# (TT manner/NN)
# (TT development/NN of/IN)
# (TT responsible/JJ programing/NN)
# (TT responsibility/NN by/IN)
# (TT assistance/NN on/IN)
# (TT scale/NN)
# (TT definition/NN of/IN)
# (TT assessment/NN of/IN)
# (TT assistance/NN for/IN)
# (TT conditional/JJ on/IN)
# (TT consistency/NN of/IN)
# (TT program/NN)
# (TT experiment/NN)
# (TT big/JJ improvement/NN)
# (TT veteran/NN)
# (TT bar/NN at/IN)
# (TT back/NN of/IN)
# (TT neck/NN)
# (TT reason/NN)
# (TT bar/NN)
# (TT front/NN of/IN)
# (TT neck/NN)
# (TT leg-split/NN)
# (TT right/JJ leg/NN to/IN)
# (TT front/NN)
# (TT beautiful/JJ bed/NN of/IN)
# (TT yard/NN on/IN)
# (TT day/NN)
# (TT perky/JJ in/IN)
# (TT sun/NN)
# (TT gardener/NN)
# (TT weather/NN)
# (TT question/NN)
# (TT secret/NN of/IN)
# (TT riotous/JJ blooming/NN)
# (TT course/NN)
# (TT love/NN)
# (TT intelligent/JJ care/NN)
# (TT pansy/NN)
# (TT pansy/NN specialist/NN)
# (TT great/JJ deal/NN of/IN)
# (TT work/NN)
# (TT size/NN)
# (TT health/NN of/IN)
# (TT size/NN of/IN)
# (TT unusual/JJ flower/NN)
# (TT pansy/NN)
# (TT fresh/JJ from/IN)
# (TT dealer/NN)
# (TT soil/NN)
# (TT prairie/NN land/NN)
# (TT compost/NN)
# (TT feeling/NN of/IN)
# (TT adequacy/NN)
# (TT right/JJ texture/NN)
# (TT tilth/NN)
# (TT body/NN)
# (TT gardener/NN)
# (TT such/JJ soil/NN)
# (TT seed/NN)
# (TT week/NN)
# (TT month/NN of/IN)
# (TT year/NN)
# (TT wide/JJ variation/NN of/IN)
# (TT temperature/NN)
# (TT cool/JJ in/IN)
# (TT seedbed/NN)
# (TT moderate/JJ protection/NN on/IN)
# (TT cold/JJ frame/NN)
# (TT ventilation/NN)
# (TT seedbed/NN)
# (TT good/JJ garden/NN soil/NN with/IN)
# (TT sand/NN)
# (TT fog/NN spray/NN)
# (TT sowing/NN with/IN)
# (TT board/NN)
# (TT ant/NN)
# (TT sprinkling/NN of/IN)
# (TT green/NN)
# (TT board/NN)
# (TT porous/JJ mulch/NN)
# (TT soil/NN soft/JJ during/IN)
# (TT growth/NN)
# (TT sawdust/NN for/IN)
# (TT hay/NN)
# (TT time/NN)
# (TT time/NN)
# (TT pansy/NN)
# (TT moral/NN)
# (TT little/JJ scoop/NN of/IN)
# (TT phosphate/NN rock/NN)
# (TT bone/NN meal/NN into/IN)
# (TT hole/NN with/IN)
# (TT plant/NN)
# (TT compost/NN into/IN)
# (TT bed/NN)
# (TT manure/NN)
# (TT bed/NN)
# (TT year/NN)
# (TT compost/NN pile/NN)
# (TT sand/NN)
# (TT experience/NN)
# (TT addition/NN to/IN)
# (TT rich/JJ soil/NN)
# (TT manure/NN water/NN)
# (TT week/NN)
# (TT color/NN of/IN)
# (TT weak/JJ tea/NN)
# (TT substitute/NN for/IN)
# (TT organic/JJ fertilizer/NN)
# (TT water/NN to/IN)
# (TT strength/NN in/IN)
# (TT mulch/NN)
# (TT light/JJ mulch/NN over/IN)
# (TT porous/JJ material/NN)
# (TT good/JJ job/NN of/IN)
# (TT soil/NN)
# (TT winter/NN)
# (TT ready/JJ with/IN)
# (TT additional/JJ mulch/NN)
# (TT hay/NN for/IN)
# (TT good/JJ frost/NN)
# (TT moisture/NN)
# (TT heaving/NN of/IN)
# (TT time/NN to/IN)
# (TT time/NN through/IN)
# (TT winter/NN)
# (TT thaw/NN)
# (TT brave/JJ little/JJ blossom/NN)
# (TT just/JJ for/IN)
# (TT winter/NN blooming/NN)
# (TT cold/JJ winter/NN)
# (TT house/NN)
# (TT own/JJ sense/NN of/IN)
# (TT glory/NN through/IN)
# (TT beer/NN derivation/NN)
# (TT underwear/NN origin/NN)
# (TT famous/JJ trade/NN in/IN)
# (TT cinema/NN)
# (TT fact/NN)
# (TT area/NN)
# (TT debutante/NN)
# (TT girl/NN)
# (TT high/JJ school/NN)
# (TT time/NN)
# (TT society/NN)
# (TT chi-chi/NN)
# (TT order/NN)
# (TT cosy/JJ evening/NN with/IN)
# (TT chaperon/NN at/IN)
# (TT hotbed/NN of/IN)
# (TT gossip/NN)
# (TT trial/NN)
# (TT precaution/NN)
# (TT visit/NN from/IN)
# (TT world/NN)
# (TT Society/NN)
# (TT own/JJ mother/NN)
# (TT surprise/NN)
# (TT kitchen/NN)
# (TT apron/NN)
# (TT ladle/NN in/IN)
# (TT hand/NN)
# (TT night/NN)
# (TT dinner/NN)
# (TT chicken/NN with/IN)
# (TT dressing/NN)
# (TT giblet/NN gravy/NN)
# (TT asparagus/NN)
# (TT sprig/NN of/IN)
# (TT mint/NN)
# (TT different/JJ problem/NN)
# (TT agony/NN)
# (TT tray/NN to/IN)
# (TT dish/NN pile/NN)
# (TT scale/NN)
# (TT fashion/NN)
# (TT decision/NN)
# (TT phone/NN)
# (TT household/NN hint/NN)
# (TT phone/NN)
# (TT matter/NN)
# (TT school/NN)
# (TT grandmother/NN)
# (TT field/NN trip/NN in/IN)
# (TT distant/JJ city/NN)
# (TT phone/NN)
# (TT stool/NN)
# (TT hand/NN with/IN)
# (TT phone/NN)
# (TT immediate/JJ attention/NN on/IN)
# (TT extreme/JJ emergency/NN)
# (TT second/NN)
# (TT mouthpiece/NN)
# (TT warmth/NN)
# (TT poise/NN)
# (TT quick/JJ lecture/NN on/IN)
# (TT crime/NN)
# (TT punishment/NN)
# (TT lecture/NN)
# (TT call/NN)
# (TT phone/NN)
# (TT caller/NN)
# (TT everyday/JJ voice/NN)
# (TT conversation/NN)
# (TT holding/NN)
# (TT breath/NN)
# (TT dumping/NN)
# (TT sugar/NN bowl/NN on/IN)
# (TT table/NN)
# (TT difficulty/NN)
# (TT conversation/NN on/IN)
# (TT phone/NN)
# (TT town/NN meeting/NN)
# (TT evening/NN)
# (TT kitchen/NN)
# (TT living/NN room/NN)
# (TT gainer/NN)
# (TT peace/NN)
# (TT quiet/NN)
# (TT say/NN)
# (TT kitchen/NN sink/NN)
# (TT dismay/NN)
# (TT time/NN about/IN)
# (TT husband/NN)
# (TT month/NN)
# (TT time/NN)
# (TT meeting/NN)
# (TT hand/NN)
# (TT kind/JJ to/IN)
# (TT indebted/JJ to/IN)
# (TT information/NN as/IN)
# (TT dentist/NN)
# (TT doctor/NN)
# (TT plumber/NN)
# (TT sitter/NN)
# (TT choice/NN)
# (TT village/NN)
# (TT telephone/NN book/NN)
# (TT expert/NN on/IN)
# (TT fashion/NN editor/NN of/IN)
# (TT weekly/JJ magazine/NN with/IN)
# (TT tremendous/JJ circulation/NN)
# (TT daughter/NN)
# (TT sole/JJ heiress/NN of/IN)
# (TT baron/NN)
# (TT oil/NN millionaire/NN)
# (TT big/JJ bank/NN roll/NN)
# (TT dabbler/NN in/IN)
# (TT money/NN into/IN)
# (TT show/NN)
# (TT period/NN)
# (TT love/NN)
# (TT lavish/JJ ceremony/NN)
# (TT style/NN)
# (TT year/NN)
# (TT high/JJ on/IN)
# (TT year/NN)
# (TT house/NN in/IN)
# (TT suburbia/NN)
# (TT reputation/NN for/IN)
# (TT abundance/NN of/IN)
# (TT meeting/NN)
# (TT easy/JJ way/NN of/IN)
# (TT uneasiness/NN at/IN)
# (TT way/NN of/IN)
# (TT house/NN)
# (TT eminent/JJ architect/NN)
# (TT corner/NN)
# (TT kitchen/NN)
# (TT breakfast/NN room/NN)
# (TT luncheon/NN room/NN)
# (TT room/NN)
# (TT room/NN)
# (TT room/NN for/IN)
# (TT party/NN room/NN)
# (TT room/NN for/IN)
# (TT mud/NN)
# (TT dust/NN)
# (TT room/NN)
# (TT room/NN)
# (TT block/NN house/NN)
# (TT right/JJ time/NN)
# (TT right/JJ thing/NN at/IN)
# (TT right/JJ time/NN)
# (TT nonconformist/NN)
# (TT world/NN)
# (TT house/NN with/IN)
# (TT contemporary/JJ furniture/NN)
# (TT art/NN)
# (TT independence/NN by/IN)
# (TT uniform/NN of/IN)
# (TT uniform/NN in/IN)
# (TT blonde/JJ hair/NN)
# (TT uniform/NN)
# (TT member/NN of/IN)
# (TT use/NN of/IN)
# (TT proper/JJ design/NN)
# (TT electron/NN heat/NN transfer/NN to/IN)
# (TT anode/NN for/IN)
# (TT power/NN output/NN)
# (TT Continuous/JJ motion/NN of/IN)
# (TT arc/NN contact/NN area/NN at/IN)
# (TT anode/NN by/IN)
# (TT flow/NN)
# (TT Feedback/NN of/IN)
# (TT energy/NN)
# (TT anode/NN by/IN)
# (TT gas/NN transpiration/NN through/IN)
# (TT anode/NN)
# (TT method/NN)
# (TT knowledge/NN)
# (TT time/NN by/IN)
# (TT purpose/NN of/IN)
# (TT present/JJ study/NN)
# (TT energy/NN balance/NN for/IN)
# (TT transpiration/NN)
# (TT anode/NN)
# (TT effect/NN of/IN)
# (TT arc/NN voltage/NN)
# (TT Gas/NN injection/NN through/IN)
# (TT porous/JJ anode/NN)
# (TT transpiration/NN cooling/NN)
# (TT energy/NN)
# (TT anode/NN by/IN)
# (TT arc/NN)
# (TT study/NN of/IN)
# (TT phenomenon/NN)
# (TT paper/NN)
# (TT Argon/NN)
# (TT gas/NN)
# (TT dissociation/NN)
# (TT chemical/NN reaction/NN)
# (TT anode/NN material/NN)
# (TT porous/JJ graphite/NN)
# (TT usable/JJ in/IN)
# (TT principle/NN)
# (TT experimental/JJ arrangement/NN)
# (TT geometry/NN of/IN)
# (TT detail/NN during/IN)
# (TT test/NN stand/NN)
# (TT anode/NN holder/NN)
# (TT cathode/NN)
# (TT 1/4''/NN)
# (TT diameter/NN)
# (TT tungsten/NN rod/NN)
# (TT water/NN)
# (TT copper/NN tube/NN)
# (TT tube/NN)
# (TT axial/JJ direction/NN by/IN)
# (TT electric/JJ drive/NN)
# (TT electrode/NN spacing/NN)
# (TT anode/NN in/IN)
# (TT figure/NN)
# (TT means/NN of/IN)
# (TT anode/NN holder/NN)
# (TT steel/NN plug/NN)
# (TT disk/NN)
# (TT gas/NN)
# (TT anode/NN)
# (TT jet/NN)
# (TT cathode/NN)
# (TT Inflow/NN of/IN)
# (TT air/NN from/IN)
# (TT atmosphere/NN)
# (TT figure/NN)
# (TT Argon/NN)
# (TT mass/NN flow/NN rate/NN Af/NN)
# (TT tube/NN coaxial/JJ with/IN)
# (TT cathode/NN)
# (TT additional/JJ precaution/NN against/IN)
# (TT contamination/NN of/IN)
# (TT arc/NN by/IN)
# (TT air/NN)
# (TT anode/NN)
# (TT inch/NN diameter/NN porous/JJ graphite/NN plug/NN)
# (TT inch/NN)
# (TT graphite/NN)
# (TT NC/NN)
# (TT porosity/NN of/IN)
# (TT 50%/NN)
# (TT average/JJ pore/NN size/NN of/IN)
# (TT small/JJ pore/NN size/NN)
# (TT uniformity/NN of/IN)
# (TT flow/NN)
# (TT anode/NN)
# (TT anode/NN plug/NN)
# (TT carbon/NN anode/NN holder/NN)
# (TT thermocouple/NN)
# (TT upstream/JJ temperature/NN of/IN)
# (TT gas/NN)
# (TT high/JJ velocity/NN gas/NN jet/NN)
# (TT plug/NN)
# (TT tube/NN with/IN)
# (TT chamber/NN above/IN)
# (TT porous/JJ plug/NN into/IN)
# (TT arrangement/NN)
# (TT purpose/NN)
# (TT gas/NN)
# (TT thermocouple/NN by/IN)
# (TT natural/JJ convection/NN)
# (TT figure/NN)
# (TT simultaneous/JJ measurement/NN of/IN)
# (TT anode/NN surface/NN temperature/NN)
# (TT temperature/NN distribution/NN along/IN)
# (TT anode/NN holder/NN)
# (TT aluminum/NN disk/NN)
# (TT anode/NN holder/NN)
# (TT temperature/NN)
# (TT anode/NN holder/NN)
# (TT figure/NN)
# (TT design/NN)
# (TT anode/NN holder/NN)
# (TT water/NN)
# (TT heat/NN)
# (TT conduction/NN from/IN)
# (TT anode/NN)
# (TT temperature/NN rise/NN of/IN)
# (TT coolant/NN)
# (TT heat/NN transfer/NN from/IN)
# (TT hot/JJ gas/NN to/IN)
# (TT anode/NN holder/NN outside/IN)
# (TT regime/NN of/IN)
# (TT arc/NN)
# (TT carbon/NN shield/NN)
# (TT surface/NN)
# (TT air/NN gap/NN of/IN)
# (TT inch/NN between/IN)
# (TT plate/NN)
# (TT surface/NN of/IN)
# (TT anode/NN holder/NN)
# (TT addition/NN)
# (TT inner/JJ surface/NN of/IN)
# (TT carbon/NN shield/NN)
# (TT aluminum/NN foil/NN)
# (TT radiation/NN)
# (TT shield/NN)
# (TT surface/NN of/IN)
# (TT water-cooled/JJ anode/NN holder/NN)
# (TT heat/NN)
# (TT coolant/NN)
# (TT anode/NN plug/NN)
# (TT argon/NN flow/NN from/IN)
# (TT pressure/NN regulator/NN)
# (TT gas/NN flow/NN rator/NN)
# (TT power/NN source/NN)
# (TT rectifier/NN)
# (TT Amp/NN)
# (TT cycle/NN ripple/NN)
# (TT V/NN)
# (TT peak/NN to/IN)
# (TT peak/NN)
# (TT resistive/JJ load/NN)
# (TT current/NN)
# (TT means/NN of/IN)
# (TT variable/JJ resistor/NN)
# (TT mV/NN shunt/NN)
# (TT millivoltmeter/NN)
# (TT arc/NN voltage/NN)
# (TT voltmeter/NN)
# (TT anode/NN)
# (TT cathode/NN)
# (TT characteristic/NN of/IN)
# (TT rectifier/NN)
# (TT ballast/NN resistor/NN)
# (TT stability/NN of/IN)
# (TT operation/NN)
# (TT high/JJ frequency/NN starter/NN)
# (TT arc/NN)
# (TT anode/NN holder/NN)
# (TT figure/NN)
# (TT mind/NN)
# (TT heat/NN)
# (TT holder/NN)
# (TT accurate/JJ heat/NN balance/NN)
# (TT order/NN)
# (TT number/NN of/IN)
# (TT constant/JJ arc/NN length/NN of/IN)
# (TT current/NN of/IN)
# (TT Aj/NN)
# (TT argon/NN flow/NN through/IN)
# (TT porous/JJ anode/NN)
# (TT Af/NN)
# (TT Af/NN)
# (TT limit/NN)
# (TT fact/NN)
# (TT flow/NN)
# (TT arc/NN)
# (TT anode/NN holder/NN)
# (TT porous/JJ graphite/NN plug/NN)
# (TT upper/JJ limit/NN)
# (TT difficulty/NN of/IN)
# (TT characteristic/JJ anode/NN surface/NN temperature/NN)
# (TT small/JJ region/NN of/IN)
# (TT anode/NN)
# (TT arc/NN)
# (TT region/NN)
# (TT temperature/NN)
# (TT rest/NN of/IN)
# (TT anode/NN surface/NN)
# (TT size/NN)
# (TT location/NN)
# (TT mass/NN flow/NN rate/NN)
# (TT arc/NN voltage/NN)
# (TT surface/NN temperature/NN of/IN)
# (TT anode/NN plug/NN)
# (TT surface/NN)
# (TT pyrometer/NN)
# (TT hot/JJ region/NN)
# (TT plug/NN)
# (TT temperature/NN)
# (TT Af/NN)
# (TT size/NN of/IN)
# (TT hot/JJ region/NN)
# (TT eye/NN)
# (TT immemorial/JJ way/NN)
# (TT way/NN of/IN)
# (TT right/JJ hand/NN)
# (TT stage/NN)
# (TT tragedy/NN at/IN)
# (TT night/NN of/IN)
# (TT dark/JJ in/IN)
# (TT German/JJ Me-210/NN plane/NN)
# (TT straight/JJ visit/NN)
# (TT German/JJ long-range/NN)
# (TT attack/NN in/IN)
# (TT raid/NN on/IN)
# (TT convoy/NN off/IN)
# (TT troopship/NN)
# (TT night/NN)
# (TT Me-210/NN)
# (TT appearance/NN)
# (TT headquarters/NN)
# (TT German/JJ reconnaissance/NN plane/NN)
# (TT city/NN)
# (TT proper/JJ time/NN)
# (TT place/NN into/IN)
# (TT warning/NN)
# (TT commander/NN)
# (TT major/JJ raid/NN on/IN)
# (TT juncture/NN of/IN)
# (TT war/NN)
# (TT opposite/JJ coast/NN)
# (TT range/NN)
# (TT air/NN)
# (TT complete/JJ superiority/NN in/IN)
# (TT sector/NN)
# (TT harbor/NN post/NN)
# (TT plane/NN)
# (TT certainty/NN of/IN)
# (TT dread/NN)
# (TT paper/NN)
# (TT light/JJ anti-aircraft/JJ squadron/NN)
# (TT balloon/NN)
# (TT fighter/NN)
# (TT airfield/NN)
# (TT radar/NN station/NN with/IN)
# (TT location/NN)
# (TT Telephone/NN communication/NN)
# (TT evidence/NN among/IN)
# (TT old/JJ handmaiden/NN of/IN)
# (TT disaster/NN)
# (TT multiple/JJ command/NN)
# (TT morning/NN to/IN)
# (TT charge/NN of/IN)
# (TT guard/NN aboard/IN)
# (TT British/JJ officer/NN)
# (TT case/NN of/IN)
# (TT enemy/NN air/NN attack/NN)
# (TT fire/NN)
# (TT fire/NN with/IN)
# (TT radar-controlled/JJ shore/NN gun/NN)
# (TT harbor/NN)
# (TT paradise/NN)
# (TT frank/JJ grimness/NN)
# (TT help/NN from/IN)
# (TT flammable/JJ fluid/NN beneath/IN)
# (TT head/NN)
# (TT hell/NN)
# (TT hell/NN)
# (TT radar-controlled/JJ gun/NN)
# (TT whispering/NN of/IN)
# (TT night/NN)
# (TT moment/NN)
# (TT enemy/NN silhouette/NN)
# (TT letter/NN)
# (TT port/JJ wall/NN)
# (TT city/NN)
# (TT port/NN)
# (TT filthy/JJ stuff/NN)
# (TT hold/NN)
# (TT earth/NN)
# (TT burden/NN of/IN)
# (TT secret/NN)
# (TT innocent/JJ assumption/NN)
# (TT ship/NN)
# (TT happy/JJ at/IN)
# (TT delay/NN in/IN)
# (TT glad/JJ at/IN)
# (TT chance/NN)
# (TT lively/JJ liberty/NN port/NN)
# (TT gangplank/NN)
# (TT noncommittal/JJ nod/NN)
# (TT security/NN)
# (TT stock/NN in/IN)
# (TT trade/NN)
# (TT crew/NN)
# (TT sea/NN)
# (TT ship/NN)
# (TT old/JJ harbor/NN)
# (TT night/NN)
# (TT difficulty/NN)
# (TT silhouette/NN)
# (TT thought/NN of/IN)
# (TT cloudless/JJ sky/NN)
# (TT clear/JJ night/NN)
# (TT governor/NN of/IN)
# (TT rain/NN)
# (TT schooner/NN with/IN)
# (TT flamboyant/JJ name/NN)
# (TT cargo/NN of/IN)
# (TT badly-needed/JJ olive/NN oil/NN for/IN)
# (TT civilian/NN population/NN)
# (TT reality/NN)
# (TT actor/NN)
# (TT delusion/NN)
# (TT figment/NN of/IN)
# (TT imagination/NN)
# (TT dramatic/JJ production/NN)
# (TT bad/JJ play/NN)
# (TT real/JJ grade-A/NN turkey/NN)
# (TT prevalence/NN of/IN)
# (TT capital/NN gain/NN)
# (TT tax/NN money/NN)
# (TT rehearsal/NN)
# (TT producer/NN)
# (TT real/JJ hope/NN of/IN)
# (TT suspense/NN gangster/NN story/NN of/IN)
# (TT era/NN)
# (TT run/NN in/IN)
# (TT road/NN company/NN)
# (TT movie/NN)
# (TT Such/JJ optimism/NN)
# (TT indignation/NN)
# (TT moment/NN)
# (TT column/NN)
# (TT entire/JJ cast/NN)
# (TT portrayal/NN of/IN)
# (TT psychopathic/JJ killer/NN)
# (TT let/NN)
# (TT lot/NN of/IN)
# (TT kidding/NN from/IN)
# (TT rest/NN of/IN)
# (TT company/NN)
# (TT morning/NN)
# (TT life/NN)
# (TT brilliant/JJ failure/NN after/IN)
# (TT class/NN at/IN)
# (TT medical/JJ school/NN)
# (TT money/NN)
# (TT energy/NN at/IN)
# (TT time/NN)
# (TT secure/JJ five-a-week/JJ spot/NN on/IN)
# (TT network/NN soap/NN opera/NN)
# (TT part/NN in/IN)
# (TT play/NN)
# (TT orderly/NN at/IN)
# (TT hospital/NN)
# (TT counterman/NN at/IN)
# (TT job/NN)
# (TT sort/NN of/IN)
# (TT life/NN)
# (TT bag/NN)
# (TT door/NN for/IN)
# (TT bellboy/NN)
# (TT bathroom/NN for/IN)
# (TT drink/NN of/IN)
# (TT water/NN)
# (TT telephone/NN)
# (TT voice/NN)
# (TT actor/NN)
# (TT while/NN)
# (TT pardon/NN)
# (TT sir/NN)
# (TT actor/NN)
# (TT request/NN of/IN)
# (TT lunch/NN with/IN)
# (TT car/NN)
# (TT hotel/NN at/IN)
# (TT course/NN)
# (TT course/NN)
# (TT man/NN)
# (TT bar/NN off/IN)
# (TT lobby/NN)
# (TT cast/NN)
# (TT untimely/JJ passing/NN of/IN)
# (TT great/JJ actor/NN)
# (TT drink/NN)
# (TT tenspot/NN on/IN)
# (TT bar/NN)
# (TT bartender/NN)
# (TT round/NN)
# (TT change/NN)
# (TT doorman/NN)
# (TT street/NN)
# (TT car/NN)
# (TT entrance/NN)
# (TT lobby/NN to/IN)
# (TT street/NN)
# (TT day/NN)
# (TT ship/NN)
# (TT curb/NN)
# (TT elderly/JJ chauffeur/NN)
# (TT immaculate/JJ in/IN)
# (TT dark/JJ uniform/NN)
# (TT attention/NN)
# (TT door/NN of/IN)
# (TT town/NN car/NN)
# (TT once-over/NN)
# (TT license/NN number/NN)
# (TT stall/NN number/NN)
# (TT attendant/NN)
# (TT deal/NN on/IN)
# (TT office/NN in/IN)
# (TT building/NN)
# (TT entrance/NN)
# (TT ticket/NN on/IN)
# (TT agency/NN car/NN)
# (TT car/NN)
# (TT ticket/NN)
# (TT monthly/JJ rental/NN)
# (TT fight/NN for/IN)
# (TT measure/NN)
# (TT rejection/NN by/IN)
# (TT public/JJ hearing/NN before/IN)
# (TT committee/NN)
# (TT subcommittee/NN for/IN)
# (TT week/NN)
# (TT committee/NN)
# (TT doubt/NN)
# (TT passage/NN of/IN)
# (TT estimate/NN)
# (TT deficit/NN of/IN)
# (TT end/NN of/IN)
# (TT current/JJ fiscal/JJ year/NN)
# (TT committee/NN)
# (TT measure/NN)
# (TT escheat/NN law/NN)
# (TT republic/NN)
# (TT state/NN)
# (TT bank/NN)
# (TT personal/JJ property/NN of/IN)
# (TT bill/NN)
# (TT insurance/NN)
# (TT pipeline/NN)
# (TT such/JJ property/NN to/IN)
# (TT state/NN treasurer/NN)
# (TT escheat/NN law/NN)
# (TT such/JJ property/NN)
# (TT lawyer/NN)
# (TT opposition/NN keynote/NN)
# (TT confidence/NN of/IN)
# (TT bank/NN)
# (TT confidence/NN in/IN)
# (TT economy/NN)
# (TT circulation/NN)
# (TT sponsor/NN of/IN)
# (TT bill/NN)
# (TT failure/NN)
# (TT gift/NN)
# (TT insurance/NN)
# (TT pipeline/NN)
# (TT contention/NN)
# (TT bill/NN)
# (TT notice/NN)
# (TT hearing/NN)
# (TT bill/NN)
# (TT bill/NN of/IN)
# (TT establishment/NN of/IN)
# (TT day/NN)
# (TT deaf/JJ in/IN)
# (TT bill/NN)
# (TT special/JJ schooling/NN for/IN)
# (TT scholastic/JJ age/NN at/IN)
# (TT cost/NN to/IN)
# (TT state/NN)
# (TT debate/NN)
# (TT bill/NN on/IN)
# (TT county-wide/JJ day/NN)
# (TT deaf/JJ in/IN)
# (TT population/NN)
# (TT age/NN)
# (TT day/NN)
# (TT budget/NN for/IN)
# (TT day/NN)
# (TT capital/NN outlay/NN of/IN)
# (TT TEA/NN)
# (TT day/NN school/NN in/IN)
# (TT state/NN deaf/JJ school/NN)
# (TT debate/NN on/IN)
# (TT horse/NN race/NN)
# (TT constitutional/JJ amendment/NN)
# (TT horse/NN race/NN betting/NN)
# (TT question/NN)
# (TT political/JJ career/NN on/IN)
# (TT ex-gambler/NN from/IN)
# (TT advocacy/NN of/IN)
# (TT committee/NN)
# (TT local/JJ option/NN proposal/NN)
# (TT favorable/JJ report/NN)
# (TT resolution/NN)
# (TT hard/JJ sledding/NN)
# (TT house/NN)
# (TT bill/NN)
# (TT authority/NN)
# (TT assistance/NN to/IN)
# (TT senate/NN)
# (TT meager/JJ fare/NN of/IN)
# (TT calendar/NN)
# (TT school/NN)
# (TT authority/NN of/IN)
# (TT act/NN for/IN)
# (TT creation/NN of/IN)
# (TT special/JJ constitutional/JJ amendment/NN)
# (TT dissent/NN)
# (TT bill/NN by/IN)
# (TT establishment/NN in/IN)
# (TT future/NN of/IN)
# (TT school/NN for/IN)
# (TT district/NN)
# (TT Money/NN for/IN)
# (TT construction/NN)
# (TT meantime/NN)
# (TT board/NN)
# (TT site/NN)
# (TT tax/NN revision/NN)
# (TT group/NN of/IN)
# (TT miscellaneous/JJ excise/NN)
# (TT requirement/NN)
# (TT return/NN)
# (TT certificate/NN of/IN)
# (TT correctness/NN)
# (TT violation/NN of/IN)
# (TT penalty/NN of/IN)
# (TT prison/NN)
# (TT fine/NN)
# (TT series/NN of/IN)
# (TT bill/NN)
# (TT real/JJ estate/NN)
# (TT fee/NN)
# (TT annual/JJ occupation/NN license/NN on/IN)
# (TT Natural/JJ gas/NN public/JJ utility/NN)
# (TT right/NN of/IN)
# (TT eminent/JJ domain/NN)
# (TT bill/NN by/IN)
# (TT underground/JJ storage/NN)
# (TT gas/NN)
# (TT chairman/NN of/IN)
# (TT plan/NN)
# (TT appointment/NN)
# (TT need/NN for/IN)
# (TT plan/NN)
# (TT appointee/NN)
# (TT board/NN)
# (TT governor/NN)
# (TT lieutenant/NN governor/NN)
# (TT speaker/NN of/IN)
# (TT attorney/NN general/NN)
# (TT justice/NN of/IN)
# (TT State/NN)
# (TT poll/NN on/IN)
# (TT kind/NN of/IN)
# (TT adverse/JJ vote/NN of/IN)
# (TT bill/NN)
# (TT referendum/NN on/IN)
# (TT ballot/NN)
# (TT senator/NN)
# (TT sponsor/NN of/IN)
# (TT poll/NN idea/NN)
# (TT delay/NN in/IN)
# (TT committee/NN)
# (TT bill/NN)
# (TT committee/NN)
# (TT public/JJ hearing/NN on/IN)
# (TT proposal/NN)
# (TT final/JJ legislative/JJ approval/NN)
# (TT ballot/NN)
# (TT ballot/NN)
# (TT information/NN about/IN)
# (TT tax/NN)
# (TT intelligent/JJ choice/NN)
# (TT water/NN)
# (TT water/NN development/NN bill/NN)
# (TT effort/NN by/IN)
# (TT hamlet/NN of/IN)
# (TT shouting/NN)
# (TT bill/NN)
# (TT similar/JJ proposal/NN)
# (TT fire/NN)
# (TT bill/NN)
# (TT maximum/JJ loan/NN)
# (TT state/NN)
# (TT local/JJ water/NN project/NN)
# (TT effort/NN by/IN)
# (TT money/NN)
# (TT water/NN for/IN)
# (TT water/NN program/NN by/IN)
# (TT pending/JJ bill/NN)
# (TT attack/NN)
# (TT absence/NN of/IN)
# (TT adequate/JJ conceptuality/NN in/IN)
# (TT gospel/NN)
# (TT unavoidable/JJ need/NN)
# (TT use/NN of/IN)
# (TT hand/NN)
# (TT folk/NN religion/NN)
# (TT current/JJ in/IN)
# (TT situation/NN)
# (TT explanation/NN of/IN)
# (TT present/JJ infatuation/NN with/IN)
# (TT cult/NN of/IN)
# (TT reassurance/NN)
# (TT ever-present/JJ need/NN for/IN)
# (TT gospel/NN)
# (TT need/NN)
# (TT important/JJ for/IN)
# (TT such/JJ infatuation/NN)
# (TT latent/JJ demand/NN for/IN)
# (TT demythologization/NN)
# (TT population/NN)
# (TT complete/JJ indifference/NN to/IN)
# (TT church/NN)
# (TT traditional/JJ message/NN of/IN)
# (TT sin/NN)
# (TT grace/NN)
# (TT common/JJ response/NN among/IN)
# (TT little/JJ flock/NN)
# (TT great/JJ crowd/NN)
# (TT solace/NN from/IN)
# (TT castigation/NN of/IN)
# (TT wisdom/NN of/IN)
# (TT chapter/NN of/IN)
# (TT luxury/NN of/IN)
# (TT such/JJ smug/JJ indigation/NN)
# (TT church/NN)
# (TT folly/NN)
# (TT dear/JJ to/IN)
# (TT wisdom/NN)
# (TT foolishness/NN of/IN)
# (TT foolishness/NN of/IN)
# (TT thing/NN)
# (TT co-operation/NN)
# (TT mission/NN in/IN)
# (TT world/NN)
# (TT venerable/JJ tradition/NN in/IN)
# (TT church/NN)
# (TT heritage/NN of/IN)
# (TT independent/JJ of/IN)
# (TT creation/NN)
# (TT need/NN of/IN)
# (TT work/NN in/IN)
# (TT world/NN)
# (TT analogy/NN)
# (TT church/NN)
# (TT independent/JJ of/IN)
# (TT world/NN)
# (TT sense/NN of/IN)
# (TT order/NN)
# (TT church/NN)
# (TT need/NN of/IN)
# (TT church/NN)
# (TT world/NN)
# (TT providence/NN)
# (TT risk/NN)
# (TT gospel/NN in/IN)
# (TT form/NN)
# (TT irrelevant/JJ to/IN)
# (TT gospel/NN into/IN)
# (TT language/NN)
# (TT success/NN of/IN)
# (TT witness/NN)
# (TT way/NN)
# (TT restatement/NN of/IN)
# (TT kerygma/NN)
# (TT conviction/NN)
# (TT point/NN)
# (TT restatement/NN)
# (TT demand/NN)
# (TT kerygma/NN)
# (TT demand/NN)
# (TT condition/NN)
# (TT right/NN)
# (TT choice/NN)
# (TT price/NN for/IN)
# (TT faithful/JJ follower/NN of/IN)
# (TT form/NN of/IN)
# (TT self-destruction/NN)
# (TT body/NN)
# (TT mind/NN)
# (TT alternative/NN)
# (TT price/NN)
# (TT essential/JJ to/IN)
# (TT argument/NN of/IN)
# (TT chapter/NN)
# (TT Modern/JJ man/NN)
# (TT age/NN)
# (TT process/NN by/IN)
# (TT unambiguous/JJ gain/NN)
# (TT fact/NN)
# (TT estrangement/NN from/IN)
# (TT cost/NN of/IN)
# (TT human/JJ maturation/NN)
# (TT positive/JJ step/NN)
# (TT event/NN)
# (TT irreversible/JJ step/NN)
# (TT honest/JJ with/IN)
# (TT alternative/NN)
# (TT world/NN in/IN)
# (TT course/NN)
# (TT position/NN on/IN)
# (TT side/NN of/IN)
# (TT controversy/NN)
# (TT rate/NN)
# (TT beginning/NN of/IN)
# (TT modern/JJ period/NN in/IN)
# (TT theological/JJ thought/NN)
# (TT tradition/NN in/IN)
# (TT history/NN)
# (TT part/NN at/IN)
# (TT tradition/NN)
# (TT century/NN)
# (TT American/JJ theology/NN)
# (TT movement/NN)
# (TT creative/JJ work/NN of/IN)
# (TT diverse/JJ tradition/NN)
# (TT earnest/JJ about/IN)
# (TT modern/JJ world/NN)
# (TT tradition/NN of/IN)
# (TT apostolic/JJ church/NN)
# (TT willingness/NN)
# (TT modernity/NN to/IN)
# (TT modern/JJ culture/NN)
# (TT treason/NN to/IN)
# (TT way/NN)
# (TT faithful/JJ to/IN)
# (TT situation/NN)
# (TT demand/NN for/IN)
# (TT demythologization/NN)
# (TT condition/NN)
# (TT liberal/JJ tradition/NN)
# (TT achievement/NN)
# (TT theology/NN)
# (TT liberalism/NN)
# (TT decisive/JJ step/NN in/IN)
# (TT deadlock/NN into/IN)
# (TT attempt/NN)
# (TT theology/NN)
# (TT effect/NN)
# (TT position/NN)
# (TT discussion/NN)
# (TT alternative/NN)
# (TT demand/NN for/IN)
# (TT demythologization/NN)
# (TT theology/NN)
# (TT position/NN of/IN)
# (TT right/NN)
# (TT center/NN)
# (TT position/NN)
# (TT indefensible/JJ on/IN)
# (TT general/JJ position/NN of/IN)
# (TT right/NN)
# (TT rejection/NN)
# (TT qualification/NN of/IN)
# (TT demand/NN for/IN)
# (TT demythologization/NN)
# (TT material/NN)
# (TT real/JJ alternative/NN)
# (TT general/JJ viewpoint/NN of/IN)
# (TT left/NN)
# (TT extent/NN at/IN)
# (TT significant/JJ in/IN)
# (TT English/JJ theology/NN)
# (TT order/NN)
# (TT position/NN)
# (TT argument/NN at/IN)
# (TT length/NN)
# (TT alternative/NN)
# (TT principle/NN in/IN)
# (TT question/NN of/IN)
# (TT possibility/NN)
# (TT meaningless/JJ question/NN)
# (TT issue/NN)
# (TT S/NN)
# (TT P/NN)
# (TT S/NN)
# (TT P/NN)
# (TT S/NN)
# (TT P/NN)
# (TT case/NN)
# (TT judgment/NN in/IN)
# (TT question/NN)
# (TT question/NN)
# (TT theology/NN myth/NN)
# (TT little/JJ bit/NN of/IN)
# (TT myth/NN)
# (TT considerable/JJ quantity/NN)
# (TT event/NN)
# (TT possibility/NN)
# (TT hand/NN)
# (TT hand/NN)
# (TT pseudo/JJ position/NN)
# (TT analogous/JJ to/IN)
# (TT round/JJ square/NN)
# (TT point/NN)
# (TT comment/NN)
# (TT discussion/NN in/IN)
# (TT position/NN of/IN)
# (TT right/NN)
# (TT thesis/NN)
# (TT tenable/JJ alternative/NN to/IN)
# (TT position/NN)
# (TT theology/NN)
# (TT unconditioned/JJ demand/NN for/IN)
# (TT demythologization/NN)
# (TT existential/JJ interpretation/NN)
# (TT special/JJ biblical/JJ hermeneutics/NN)
# (TT method/NN of/IN)
# (TT interpretation/NN)
# (TT appropriate/JJ emphasis/NN to/IN)
# (TT event/NN)
# (TT point/NN of/IN)
# (TT view/NN)
# (TT communion/NN of/IN)
# (TT prayer/NN unacceptable/JJ to/IN)
# (TT association/NN)
# (TT fruit/NN)
# (TT fact/NN)
# (TT religious/JJ sphere/NN)
# (TT Christian/JJ unity/NN)
# (TT prayer/NN)
# (TT discussion/NN by/IN)
# (TT real/JJ attainment/NN of/IN)
# (TT Christian/JJ unity/NN in/IN)
# (TT religious/JJ picture/NN in/IN)
# (TT hope/NN)
# (TT Catholic/JJ side/NN)
# (TT tide/NN)
# (TT turn/NN)
# (TT Catholic/JJ weekly/NN)
# (TT summer/NN)
# (TT research/NN on/IN)
# (TT American/JJ Catholic/JJ of/IN)
# (TT Irish/JJ ancestry/NN)
# (TT addle-brained/JJ knight-errant/NN)
# (TT self-appointed/JJ to/IN)
# (TT ridiculous/JJ position/NN in/IN)
# (TT age/NN)
# (TT armor/NN)
# (TT chivalrous/JJ code/NN of/IN)
# (TT knight-errantry/NN)
# (TT joke/NN)
# (TT doubt/NN)
# (TT gracious/JJ symbol/NN of/IN)
# (TT good/NN)
# (TT world/NN of/IN)
# (TT bony/JJ crackpot/NN with/IN)
# (TT tangible/JJ affection/NN)
# (TT respect/NN)
# (TT tempo/NN)
# (TT sense/NN of/IN)
# (TT high/JJ tradition/NN)
# (TT impious/JJ world/NN)
# (TT communication/NN)
# (TT case/NN by/IN)
# (TT stilted/JJ English/JJ language/NN)
# (TT place/NN of/IN)
# (TT Russian/JJ dialogue/NN)
# (TT richness/NN)
# (TT roughness/NN)
# (TT color/NN)
# (TT dialogue/NN)
# (TT violation/NN of/IN)
# (TT artistry/NN)
# (TT logic/NN)
# (TT performance/NN of/IN)
# (TT squire/NN)
# (TT character/NN)
# (TT don/NN)
# (TT firmness/NN)
# (TT toughness/NN)
# (TT sort/NN of/IN)
# (TT peasant/NN dignity/NN)
# (TT character/NN)
# (TT vitality/NN)
# (TT courage/NN of/IN)
# (TT episode/NN in/IN)
# (TT joke/NN)
# (TT command/NN of/IN)
# (TT island/NN)
# (TT film/NN)
# (TT pattern/NN)
# (TT flow/NN of/IN)
# (TT drama/NN)
# (TT bit/NN wearisome/JJ in/IN)
# (TT court/NN)
# (TT strength/NN)
# (TT poignancy/NN)
# (TT windmill/NN)
# (TT deathbed/NN)
# (TT realization/NN of/IN)
# (TT wonderfulness/NN of/IN)
# (TT old/JJ boy/NN)
# (TT court/NN by/IN)
# (TT last/NN of/IN)
# (TT country/NN in/IN)
# (TT program/NN of/IN)
# (TT joint/NN cultural/JJ exchange/NN)
# (TT bill/NN at/IN)
# (TT nice/JJ ten-minute/JJ color/NN film/NN)
# (TT tour/NN of/IN)
# (TT Television/NN)
# (TT arrangement/NN with/IN)
# (TT jazz/NN)
# (TT medium/NN)
# (TT uneasy/JJ guest/NN)
# (TT member/NN of/IN)
# (TT family/NN)
# (TT unfortunate/JJ assumption/NN)
# (TT hour/NN of/IN)
# (TT Chicago-style/JJ jazz/NN in/IN)
# (TT prime/JJ evening/NN time/NN)
# (TT example/NN)
# (TT portentous/JJ documentary/NN)
# (TT hypothesis/NN for/IN)
# (TT NBC-TV/NN)
# (TT program/NN)
# (TT NBC/NN)
# (TT department/NN)
# (TT series/NN)
# (TT documentary/NN)
# (TT worth/JJ while/NN)
# (TT future/JJ jazz/NN show/NN to/IN)
# (TT different/JJ department/NN)
# (TT confidence/NN in/IN)
# (TT musical/JJ material/NN)
# (TT number/NN of/IN)
# (TT room/NN)
# (TT matter/NN of/IN)
# (TT fact/NN)
# (TT approach/NN)
# (TT broad/JJ range/NN of/IN)
# (TT big/JJ band/NN to/IN)
# (TT enthusiastic/JJ audience/NN)
# (TT character/NN of/IN)
# (TT hour/NN)
# (TT interaction/NN between/IN)
# (TT musician/NN)
# (TT hearer/NN)
# (TT quality/NN of/IN)
# (TT performance/NN)
# (TT time/NN)
# (TT TV/NN series/NN on/IN)
# (TT jazz/NN)
# (TT space/NN)
# (TT producer/NN)
# (TT hour/NN)
# (TT rudderless/JJ movement/NN)
# (TT score/NN of/IN)
# (TT jazz/NN)
# (TT program/NN)
# (TT establishment/NN of/IN)
# (TT mood/NN of/IN)
# (TT intense/JJ concentration/NN on/IN)
# (TT music/NN)
# (TT ensemble/NN work/NN)
# (TT choice/NN of/IN)
# (TT in-person/NN)
# (TT jazz/NN buff/NN)
# (TT ideal/JJ master/NN of/IN)
# (TT host/NN at/IN)
# (TT show/NN)
# (TT music/NN of/IN)
# (TT past/NN with/IN)
# (TT lot/NN of/IN)
# (TT historical/JJ material/NN)
# (TT example/NN)
# (TT sheet/NN music/NN with/IN)
# (TT word/NN)
# (TT jazz/NN)
# (TT title/NN)
# (TT word/NN of/IN)
# (TT uncertain/JJ origin/NN)
# (TT hold/NN)
# (TT closeup/JJ range/NN in/IN)
# (TT regular/JJ succession/NN)
# (TT telephone/NN)
# (TT highway/NN)
# (TT representative/JJ music/NN)
# (TT mood/NN of/IN)
# (TT interruption/NN)
# (TT auxiliary/NN to/IN)
# (TT business/NN)
# (TT talent/NN at/IN)
# (TT hand/NN)
# (TT gathering/NN of/IN)
# (TT style/NN)
# (TT source/NN of/IN)
# (TT NBC/NN pride/NN)
# (TT rare/JJ film/NN clip/NN of/IN)
# (TT view/NN of/IN)
# (TT great/JJ trumpeter/NN)
# (TT wink/NN)
# (TT entire/JJ glimpse/NN)
# (TT early/JJ jazz/NN)
# (TT program/NN)
# (TT time/NN for/IN)
# (TT close/JJ perusal/NN)
# (TT fan/NN)
# (TT inquisitive/JJ newcomer/NN)
# (TT serious/JJ survey/NN of/IN)
# (TT bygone/JJ era/NN)
# (TT showcase/NN for/IN)
# (TT program/NN)
# (TT not-quite-perfect/JJ example/NN of/IN)
# (TT willingness/NN)
# (TT musical/JJ field/NN)
# (TT tremendous/JJ reception/NN)
# (TT audience/NN)
# (TT debut/NN)
# (TT night/NN)
# (TT crowd/NN)
# (TT own/JJ mad/JJ scene/NN in/IN)
# (TT applause/NN)
# (TT ovation/NN)
# (TT curtain/NN call/NN after/IN)
# (TT curtain/NN call/NN)
# (TT help/NN of/IN)
# (TT composer/NN)
# (TT entrance/NN in/IN)
# (TT disconcerting/JJ applause/NN)
# (TT note/NN)
# (TT audience/NN)
# (TT judgment/NN)
# (TT singing/NN)
# (TT strain/NN)
# (TT musicianship/NN)
# (TT questionable/JJ procedure/NN)
# (TT acting/NN uncomfortable/JJ stylization/NN)
# (TT composure/NN during/IN)
# (TT act/NN)
# (TT technical/JJ resourcefulness/NN)
# (TT trill/NN)
# (TT unprecedented/JJ in/IN)
# (TT sextet/NN)
# (TT high/JJ note/NN)
# (TT crowd/NN in/IN)
# (TT ecstasy/NN)
# (TT show/NN midway/NN in/IN)
# (TT real/JJ reason/NN)
# (TT realization/NN of/IN)
# (TT extraordinary/JJ performance/NN)
# (TT moment/NN)
# (TT person/NN in/IN)
# (TT scene/NN)
# (TT sensational/JJ coloratura/NN)
# (TT stage/NN)
# (TT actress/NN)
# (TT role/NN)
# (TT outburst/NN)
# (TT breathless/JJ silence/NN)
# (TT mastery/NN of/IN)
# (TT voice/NN)
# (TT unique/JJ among/IN)
# (TT flexible/JJ voice/NN with/IN)
# (TT uncommon/JJ range/NN)
# (TT Nervousness/NN at/IN)
# (TT start/NN)
# (TT scene/NN)
# (TT fullness/NN of/IN)
# (TT vocal/JJ splendor/NN)
# (TT famous/JJ scene/NN)
# (TT audience/NN)
# (TT debut/NN)
# (TT sullen/JJ quality/NN)
# (TT boy/NN)
# (TT distance/NN)
# (TT answer/NN)
# (TT porch/NN rail/NN from/IN)
# (TT leg/NN)
# (TT mood/NN)
# (TT month/NN)
# (TT mood/NN)
# (TT sun/NN)
# (TT pipe/NN)
# (TT daydreaming/NN by/IN)
# (TT warm/JJ wetness/NN)
# (TT chin/NN)
# (TT sight/NN of/IN)
# (TT claret/JJ tongue/NN)
# (TT salt/NN taste/NN of/IN)
# (TT tongue/NN)
# (TT yellow/JJ eye/NN)
# (TT sphere/NN of/IN)
# (TT pink/JJ skin/NN)
# (TT goat/NN)
# (TT goat/NN)
# (TT milk/NN)
# (TT hand/NN)
# (TT smoothness/NN of/IN)
# (TT touch/NN)
# (TT head/NN)
# (TT space/NN)
# (TT taut/JJ belly/NN within/IN)
# (TT warmth/NN of/IN)
# (TT mouth/NN)
# (TT warm/JJ white/JJ milk/NN against/IN)
# (TT roof/NN of/IN)
# (TT mouth/NN)
# (TT tongue/NN)
# (TT earthy/JJ taste/NN of/IN)
# (TT mouth/NN)
# (TT skilled/JJ unity/NN of/IN)
# (TT bagpipe/NN player/NN)
# (TT evasive/JJ shadow/NN of/IN)
# (TT storm/NN cloud/NN)
# (TT form/NN)
# (TT heavy/JJ figure/NN in/IN)
# (TT soutane/NN)
# (TT boy/NN)
# (TT belly/NN)
# (TT corner/NN)
# (TT shadow/NN pass/NN over/IN)
# (TT portentous/JJ in/IN)
# (TT finger/NN except/IN)
# (TT back/NN)
# (TT time/NN)
# (TT devil/NN)
# (TT due/NN)
# (TT Time/NN)
# (TT soul/NN)
# (TT meantime/NN)
# (TT ocher/NN)
# (TT color/NN)
# (TT hair/NN)
# (TT clapping/NN)
# (TT concrete/NN)
# (TT ecstatic/JJ pleasure/NN)
# (TT hold/NN on/IN)
# (TT goat/NN)
# (TT glance/NN)
# (TT idiot/NN brother/NN)
# (TT small/JJ body/NN)
# (TT ground/NN)
# (TT thin/JJ hand/NN)
# (TT boy/NN)
# (TT impetuous/JJ voice/NN)
# (TT rotundity/NN of/IN)
# (TT flesh/NN)
# (TT sure/JJ of/IN)
# (TT evening/NN)
# (TT baby/NN)
# (TT room/NN)
# (TT smoke/NN)
# (TT head/NN)
# (TT excitement/NN)
# (TT fatigue/NN)
# (TT earnest/JJ look/NN of/IN)
# (TT proud/JJ possession/NN on/IN)
# (TT face/NN)
# (TT mother/NN in/IN)
# (TT recovery/NN)
# (TT social/JJ baby/NN)
# (TT fuzz/NN of/IN)
# (TT flaxen/JJ hair/NN)
# (TT head/NN)
# (TT food/NN)
# (TT cream/NN complexion/NN)
# (TT sunny/JJ disposition/NN)
# (TT life/NN)
# (TT food/NN at/IN)
# (TT activity/NN)
# (TT care/NN of/IN)
# (TT strength/NN)
# (TT big/JJ basket/NN of/IN)
# (TT rackety/JJ old/JJ washer/NN)
# (TT daily/JJ round/NN of/IN)
# (TT household/NN)
# (TT Worry/NN)
# (TT great/JJ deal/NN)
# (TT produce/NN company/NN)
# (TT office/NN)
# (TT salary/NN)
# (TT father/NN)
# (TT death/NN)
# (TT bankruptcy/NN to/IN)
# (TT son/NN)
# (TT upkeep/NN)
# (TT baby/NN)
# (TT milk/NN)
# (TT orange/NN juice/NN)
# (TT soap/NN)
# (TT plain/JJ soap/NN)
# (TT night/NN)
# (TT desperation/NN)
# (TT afternoon/NN)
# (TT money/NN)
# (TT baby/NN)
# (TT rest/NN of/IN)
# (TT machine/NN to/IN)
# (TT baby/NN to/IN)
# (TT stove/NN)
# (TT plenty/NN of/IN)
# (TT lot/NN)
# (TT baby/NN with/IN)
# (TT nursery/NN)
# (TT thing/NN)
# (TT child/NN in/IN)
# (TT skin/NN)
# (TT day/NN)
# (TT baby/NN)
# (TT fat/JJ warm/JJ little/JJ neck/NN)
# (TT beautiful/JJ in/IN)
# (TT thing/NN on/IN)
# (TT child/NN but/IN)
# (TT flannel/NN wrapper/NN)
# (TT baby/NN)
# (TT way/NN for/IN)
# (TT long/JJ time/NN)
# (TT cosmic/JJ clock/NN)
# (TT long/JJ time/NN)
# (TT goodness/NN)
# (TT answer/NN)
# (TT grokking/NN)
# (TT voice/NN)
# (TT pressure/NN)
# (TT male/NN)
# (TT female/NN party/NN)
# (TT ship/NN)
# (TT Part/NN of/IN)
# (TT time/NN)
# (TT preliminary/JJ estimate/NN for/IN)
# (TT long-distance/NN plan/NN)
# (TT oxygen/NN in/IN)
# (TT planet/NN)
# (TT friendly/JJ to/IN)
# (TT future/JJ human/NN)
# (TT plan/NN)
# (TT time/NN)
# (TT violent/JJ cusp/NN)
# (TT Martian/JJ art/NN for/IN)
# (TT poet/NN)
# (TT edition/NN of/IN)
# (TT verse/NN)
# (TT punctuation/NN)
# (TT magazine/NN)
# (TT medium/NN)
# (TT colossal/JJ campaign/NN)
# (TT table/NN)
# (TT Tibetan/JJ swami/NN from/IN)
# (TT ancient/JJ yoga/NN discipline/NN for/IN)
# (TT ripple/NN breathing/NN)
# (TT pranha/NN)
# (TT cosmic/JJ attraction/NN between/IN)
# (TT posture/NN)
# (TT assistant/NN guru/NN)
# (TT room/NN)
# (TT purpose/NN)
# (TT funeral/NN parlor/NN chain/NN)
# (TT price-cutting/NN)
# (TT secret/JJ conclave/NN)
# (TT glorious/JJ news/NN)
# (TT Heavenly/JJ confirmation/NN of/IN)
# (TT elevation/NN of/IN)
# (TT candidate/NN)
# (TT faction/NN)
# (TT cast/NN)
# (TT elevation/NN)
# (TT promotion/NN)
# (TT work/NN)
# (TT stupid/JJ jackass/NN)
# (TT angelic/JJ patience/NN)
# (TT angel/NN)
# (TT Eternity/NN)
# (TT time/NN for/IN)
# (TT stupid/JJ jackass/NN)
# (TT professional/JJ jealousy/NN)
# (TT request/NN)
# (TT halo/NN)
# (TT requisition/NN for/IN)
# (TT miracle/NN)
# (TT fool/NN of/IN)
# (TT own/JJ setup/NN)
# (TT different/JJ from/IN)
# (TT show/NN)
# (TT way/NN)
# (TT variety/NN)
# (TT fact/NN)
# (TT punk/NN)
# (TT thing/NN)
# (TT work/NN)
# (TT performance/NN)
# (TT halo/NN)
# (TT angel/NN)
# (TT deep/JJ ethereal/JJ sigh/NN)

# %% [markdown]
# ## 2. Identify Proper Nouns ##
# For this next task, write a new version of the chunker, but this time change it in two ways:
#  1. Make it recognize proper nouns
#  2. Make it work on your personal text collection which means that you need to run a tagger over your personal text collection.
#
# Note that the second requirements means that you need to run a tagger over your personal text collection before you design the proper noun recognizer.  You can use a pre-trained tagger or train your own on one of the existing tagged collections (brown, conll, or treebank)

# %% [markdown]
# **Tagger:** Your code for optionally training tagger, and for definitely running tagger on your personal collection goes here:

# %%
def tokenize_text(corpus):
    sent_tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')
    raw_sents = sent_tokenizer.tokenize(corpus) # Split text into sentences    
    return [nltk.word_tokenize(word) for word in raw_sents]

def build_backoff_tagger(train_sents):
    t0 = nltk.DefaultTagger('NN')
    t1 = nltk.UnigramTagger(train_sents, backoff=t0)
    t2 = nltk.BigramTagger(train_sents, backoff=t1)
    return t2


def train_tagger(already_tagged_sents):
    ngram_tagger = build_backoff_tagger(already_tagged_sents)
#     print ("%0.3f pos accuracy on test set" % ngram_tagger.evaluate(test_sents))
    return ngram_tagger

# read file and tokennize sentence
txtfile = "pride_and_prejudice.txt"
fp = open(txtfile, 'r')
contents = fp.read()
contents = contents.replace("\ufeff", '')
sents = tokenize_text(contents)

# train tagger
brown_tagged_sents = brown.tagged_sents(categories=['adventure', 'belles_lettres', 'editorial', 'fiction', 'government', 'hobbies',
    'humor', 'learned', 'lore', 'mystery', 'religion', 'reviews', 'romance', 'science_fiction'])

tagger = train_tagger(brown_tagged_sents)

txt_tagged = []
for sent in sents:
    txt_tagged.append(tagger.tag(sent))

txt_tagged
# Out:
# [[('Chapter', 'NN-HL'),
#   ('1', 'CD-HL'),
#   ('It', 'PPS'),
#   ('is', 'BEZ'),
#   ('a', 'AT'),
#   ('truth', 'NN'),
#   ('universally', 'RB'),
#   ('acknowledged', 'VBN'),
#   (',', ','),
#   ('that', 'CS'),
#   ('a', 'AT'),
#   ('single', 'AP'),
#   ('man', 'NN'),
#   ('in', 'IN'),
#   ('possession', 'NN'),
#   ('of', 'IN'),
#   ('a', 'AT'),
#   ('good', 'JJ'),
#   ('fortune', 'NN'),
#   (',', ','),
#   ('must', 'MD'),
#   ('be', 'BE'),
#   ('in', 'IN'),
#   ('want', 'NN'),
#   ('of', 'IN'),
#   ('a', 'AT'),
#   ('wife', 'NN'),
#   ('.', '.')],
#  [('However', 'RB'),
#   ('little', 'JJ'),
#   ('known', 'VBN'),
#   ('the', 'AT'),
#   ('feelings', 'NNS'),
#   ('or', 'CC'),
#   ('views', 'NNS'),
#   ('of', 'IN'),
#   ('such', 'JJ'),
#   ('a', 'AT'),
#   ('man', 'NN'),
#   ('may', 'MD'),
#   ('be', 'BE'),
#   ('on', 'IN'),
#   ('his', 'PP$'),
#   ('first', 'OD'),
#   ('entering', 'VBG'),
#   ('a', 'AT'),
#   ('neighbourhood', 'NN'),
#   (',', ','),
#   ('this', 'DT'),
#   ('truth', 'NN'),
#   ('is', 'BEZ'),
#   ('so', 'QL'),
#   ('well', 'RB'),
#   ('fixed', 'VBN'),
#   ('in', 'IN'),
#   ('the', 'AT'),
#   ('minds', 'NNS'),
#   ('of', 'IN'),
#   ('the', 'AT'),
#   ('surrounding', 'VBG'),
#   ('families', 'NNS'),
#   (',', ','),
#   ('that', 'CS'),
#   ('he', 'PPS'),
#   ('is', 'BEZ'),
#   ('considered', 'VBN'),
#   ('the', 'AT'),
#   ('rightful', 'JJ'),
#   ('property', 'NN'),
#   ('of', 'IN'),
#   ('some', 'DTI'),
#   ('one', 'CD'),
#   ('or', 'CC'),
#   ('other', 'AP'),
#   ('of', 'IN'),
#   ('their', 'PP$'),
#   ('daughters', 'NNS'),
#   ('.', '.')],
#  [('``', '``'),
#   ('My', 'PP$'),
#   ('dear', 'NN'),
#   ('Mr.', 'NP'),
#   ('Bennet', 'NN'),
#   (',', ','),
#   ("''", "''"),
#   ('said', 'VBD'),
#   ('his', 'PP$'),
#   ('lady', 'NN'),
#   ('to', 'IN'),
#   ('him', 'PPO'),
#   ('one', 'CD'),
#   ('day', 'NN'),
#   (',', ','),
#   ('``', '``'),
#   ('have', 'HV'),
#   ('you', 'PPSS'),
#   ('heard', 'VBD'),
#   ('that', 'CS'),
#   ('Netherfield', 'NN'),
#   ('Park', 'NN-TL'),
#   ('is', 'BEZ'),
#   ('let', 'VB'),
#   ('at', 'IN'),
#   ('last', 'AP'),
#   ('?', '.'),
#   ("''", "''")],
#  [('Mr.', 'NP'),
#   ('Bennet', 'NN'),
#   ('replied', 'VBD'),
#   ('that', 'CS'),
#   ('he', 'PPS'),
#   ('had', 'HVD'),
#   ('not', '*'),
#   ('.', '.')],
#  [('``', '``'),
#   ('But', 'CC'),
#   ('it', 'PPS'),
#   ('is', 'BEZ'),
#   (',', ','),
#   ("''", "''"),
#   ('returned', 'VBD'),
#   ('she', 'PPS'),
#   (';', '.'),
#   ('``', '``'),
#   ('for', 'IN'),
#   ('Mrs.', 'NP'),
#   ('Long', 'NP'),
#   ('has', 'HVZ'),
#   ('just', 'RB'),
#   ('been', 'BEN'),
#   ('here', 'RB'),
#   (',', ','),
#   ('and', 'CC'),
#   ('she', 'PPS'),
#   ('told', 'VBD'),
#   ('me', 'PPO'),
#   ('all', 'ABN'),
#   ('about', 'IN'),
#   ('it', 'PPO'),
#   ('.', '.'),
#   ("''", "''")],
#  [('Mr.', 'NP'),
#   ('Bennet', 'NN'),
#   ('made', 'VBD'),
#   ('no', 'AT'),
#   ('answer', 'NN'),
#   ('.', '.')],
#  [('``', '``'),
#   ('Do', 'DO'),
#   ('you', 'PPSS'),
#   ('not', '*'),
#   ('want', 'VB'),
#   ('to', 'TO'),
#   ('know', 'VB'),
#   ('who', 'WPS'),
#   ('has', 'HVZ'),
#   ('taken', 'VBN'),
#   ('it', 'PPO'),
#   ('?', '.'),
#   ("''", "''")],
#  [('cried', 'VBD'),
#   ('his', 'PP$'),
#   ('wife', 'NN'),
#   ('impatiently', 'RB'),
#   ('.', '.')],
#  [('``', '``'),
#   ('_You_', 'NN'),
#   ('want', 'VB'),
#   ('to', 'TO'),
#   ('tell', 'VB'),
#   ('me', 'PPO'),
#   (',', ','),
#   ('and', 'CC'),
#   ('I', 'PPSS'),
#   ('have', 'HV'),
#   ('no', 'AT'),
#   ('objection', 'NN'),
#   ('to', 'IN'),
#   ('hearing', 'VBG'),
#   ('it', 'PPO'),
#   ('.', '.'),
#   ("''", "''")],
#  [('This', 'DT'),
#   ('was', 'BEDZ'),
#   ('invitation', 'NN'),
#   ('enough', 'AP'),
#   ('.', '.')],
#  [('``', '``'),
#   ('Why', 'WRB'),
#   (',', ','),
#   ('my', 'PP$'),
#   ('dear', 'NN'),
#   (',', ','),
#   ('you', 'PPSS'),
#   ('must', 'MD'),
#   ('know', 'VB'),
#   (',', ','),
#   ('Mrs.', 'NP'),
#   ('Long', 'NP'),
#   ('says', 'VBZ'),
#   ('that', 'CS'),
#   ('Netherfield', 'NN'),
#   ('is', 'BEZ'),
#   ('taken', 'VBN'),
#   ('by', 'IN'),
#   ('a', 'AT'),
#   ('young', 'JJ'),
#   ('man', 'NN'),
#   ('of', 'IN'),
#   ('large', 'JJ'),
#   ('fortune', 'NN'),
#   ('from', 'IN'),
#   ('the', 'AT'),
#   ('north', 'NR'),
#   ('of', 'IN'),
#   ('England', 'NP'),
#   (';', '.'),
#   ('that', 'CS'),
#   ('he', 'PPS'),
#   ('came', 'VBD'),
#   ('down', 'RP'),
#   ('on', 'IN'),
#   ('Monday', 'NR'),
#   ('in', 'IN'),
#   ('a', 'AT'),
#   ('chaise', 'NN'),
#   ('and', 'CC'),
#   ('four', 'CD'),
#   ('to', 'IN'),
#   ('see', 'VB'),
#   ('the', 'AT'),
#   ('place', 'NN'),
#   (',', ','),
#   ('and', 'CC'),
#   ('was', 'BEDZ'),
#   ('so', 'QL'),
#   ('much', 'AP'),
#   ('delighted', 'VBN'),
#   ('with', 'IN'),
#   ('it', 'PPO'),
#   (',', ','),
#   ('that', 'CS'),
#   ('he', 'PPS'),
#   ('agreed', 'VBD'),
#   ('with', 'IN'),
#   ('Mr.', 'NP'),
#   ('Morris', 'NP'),
#   ('immediately', 'RB'),
#   (';', '.'),
#   ('that', 'CS'),
#   ('he', 'PPS'),
#   ('is', 'BEZ'),
#   ('to', 'TO'),
#   ('take', 'VB'),
#   ('possession', 'NN'),
#   ('before', 'IN'),
#   ('Michaelmas', 'NN'),
#   (',', ','),
#   ('and', 'CC'),
#   ('some', 'DTI'),
#   ('of', 'IN'),
#   ('his', 'PP$'),
#   ('servants', 'NNS'),
#   ('are', 'BER'),
#   ('to', 'TO'),
#   ('be', 'BE'),
#   ('in', 'IN'),
#   ('the', 'AT'),
#   ('house', 'NN'),
#   ('by', 'IN'),
#   ('the', 'AT'),
#   ('end', 'NN'),
#   ('of', 'IN'),
#   ('next', 'AP'),
#   ('week', 'NN'),
#   ('.', '.'),
#   ("''", "''")],
#  [('``', '``'),
#   ('What', 'WDT'),
#   ('is', 'BEZ'),
#   ('his', 'PP$'),
#   ('name', 'NN'),
#   ('?', '.'),
#   ("''", "''")],
#  [('``', '``'), ('Bingley', 'NN'), ('.', '.'), ("''", "''")],
#  [('``', '``'),
#   ('Is', 'BEZ'),
#   ('he', 'PPS'),
#   ('married', 'VBD'),
#   ('or', 'CC'),
#   ('single', 'AP'),
#   ('?', '.'),
#   ("''", "''")],
#  [('``', '``'), ('Oh', 'UH'), ('!', '.')],
#  [('Single', 'NN'),
#   (',', ','),
#   ('my', 'PP$'),
#   ('dear', 'NN'),
#   (',', ','),
#   ('to', 'TO'),
#   ('be', 'BE'),
#   ('sure', 'JJ'),
#   ('!', '.')],
#  [('A', 'AT'),
#   ('single', 'AP'),
#   ('man', 'NN'),
#   ('of', 'IN'),
#   ('large', 'JJ'),
#   ('fortune', 'NN'),
#   (';', '.'),
#   ('four', 'CD'),
#   ('or', 'CC'),
#   ('five', 'CD'),
#   ('thousand', 'CD'),
#   ('a', 'AT'),
#   ('year', 'NN'),
#   ('.', '.')],
#  [('What', 'WDT'),
#   ('a', 'AT'),
#   ('fine', 'JJ'),
#   ('thing', 'NN'),
#   ('for', 'IN'),
#   ('our', 'PP$'),
#   ('girls', 'NNS'),
#   ('!', '.'),
#   ("''", "''")],
#  [('``', '``'), ('How', 'WRB'), ('so', 'RB'), ('?', '.')],
#  [('How', 'WRB'),
#   ('can', 'MD'),
#   ('it', 'PPS'),
#   ('affect', 'VB'),
#   ('them', 'PPO'),
#   ('?', '.'),
#   ("''", "''")],
#  [('``', '``'),
#   ('My', 'PP$'),
#   ('dear', 'NN'),
#   ('Mr.', 'NP'),
#   ('Bennet', 'NN'),
#   (',', ','),
#   ("''", "''"),
#   ('replied', 'VBD'),
#   ('his', 'PP$'),
#   ('wife', 'NN'),
#   (',', ','),
#   ('``', '``'),
#   ('how', 'WRB'),
#   ('can', 'MD'),
#   ('you', 'PPSS'),
#   ('be', 'BE'),
#   ('so', 'QL'),
#   ('tiresome', 'JJ'),
#   ('!', '.')],
#  [('You', 'PPSS'),
#   ('must', 'MD'),
#   ('know', 'VB'),
#   ('that', 'CS'),
#   ('I', 'PPSS'),
#   ('am', 'BEM'),
#   ('thinking', 'VBG'),
#   ('of', 'IN'),
#   ('his', 'PP$'),
#   ('marrying', 'VBG'),
#   ('one', 'CD'),
#   ('of', 'IN'),
#   ('them', 'PPO'),
#   ('.', '.'),
#   ("''", "''")],
#  [('``', '``'),
#   ('Is', 'BEZ'),
#   ('that', 'CS'),
#   ('his', 'PP$'),
#   ('design', 'NN'),
#   ('in', 'IN'),
#   ('settling', 'VBG'),
#   ('here', 'RB'),
#   ('?', '.'),
#   ("''", "''")],
#  [('``', '``'), ('Design', 'NN-TL'), ('!', '.')],
#  [('Nonsense', 'NN'),
#   (',', ','),
#   ('how', 'WRB'),
#   ('can', 'MD'),
#   ('you', 'PPSS'),
#   ('talk', 'VB'),
#   ('so', 'QL'),
#   ('!', '.')],
#  [('But', 'CC'),
#   ('it', 'PPS'),
#   ('is', 'BEZ'),
#   ('very', 'QL'),
#   ('likely', 'JJ'),
#   ('that', 'CS'),
#   ('he', 'PPS'),
#   ('_may_', 'NN'),
#   ('fall', 'VB'),
#   ('in', 'IN'),
#   ('love', 'NN'),
#   ('with', 'IN'),
#   ('one', 'CD'),
#   ('of', 'IN'),
#   ('them', 'PPO'),
#   (',', ','),
#   ('and', 'CC'),
#   ('therefore', 'RB'),
#   ('you', 'PPSS'),
#   ('must', 'MD'),
#   ('visit', 'VB'),
#   ('him', 'PPO'),
#   ('as', 'CS'),
#   ('soon', 'RB'),
#   ('as', 'CS'),
#   ('he', 'PPS'),
#   ('comes', 'VBZ'),
#   ('.', '.'),
#   ("''", "''")],
#  [('``', '``'),
#   ('I', 'PPSS'),
#   ('see', 'VB'),
#   ('no', 'AT'),
#   ('occasion', 'NN'),
#   ('for', 'IN'),
#   ('that', 'DT'),
#   ('.', '.')],
#  [('You', 'PPSS'),
#   ('and', 'CC'),
#   ('the', 'AT'),
#   ('girls', 'NNS'),
#   ('may', 'MD'),
#   ('go', 'VB'),
#   (',', ','),
#   ('or', 'CC'),
#   ('you', 'PPSS'),
#   ('may', 'MD'),
#   ('send', 'VB'),
#   ('them', 'PPO'),
#   ('by', 'IN'),
#   ('themselves', 'PPLS'),
#   (',', ','),
#   ('which', 'WDT'),
#   ('perhaps', 'RB'),
#   ('will', 'MD'),
#   ('be', 'BE'),
#   ('still', 'QL'),
#   ('better', 'JJR'),
#   (',', ','),
#   ('for', 'IN'),
#   ('as', 'CS'),
#   ('you', 'PPSS'),
#   ('are', 'BER'),
#   ('as', 'QL'),
#   ('handsome', 'JJ'),
#   ('as', 'CS'),
#   ('any', 'DTI'),
#   ('of', 'IN'),
#   ('them', 'PPO'),
#   (',', ','),
#   ('Mr.', 'NP'),
#   ('Bingley', 'NN'),
#   ('may', 'MD'),
#   ('like', 'VB'),
#   ('you', 'PPO'),
#   ('the', 'AT'),
#   ('best', 'JJT'),
#   ('of', 'IN'),
#   ('the', 'AT'),
#   ('party', 'NN'),
#   ('.', '.'),
#   ("''", "''")],
#  [('``', '``'),
#   ('My', 'PP$'),
#   ('dear', 'NN'),
#   (',', ','),
#   ('you', 'PPSS'),
#   ('flatter', 'VB'),
#   ('me', 'PPO'),
#   ('.', '.')],
#  [('I', 'PPSS'),
#   ('certainly', 'RB'),
#   ('_have_', 'NN'),
#   ('had', 'HVD'),
#   ('my', 'PP$'),
#   ('share', 'NN'),
#   ('of', 'IN'),
#   ('beauty', 'NN'),
#   (',', ','),
#   ('but', 'CC'),
#   ('I', 'PPSS'),
#   ('do', 'DO'),
#   ('not', '*'),
#   ('pretend', 'VB'),
#   ('to', 'TO'),
#   ('be', 'BE'),
#   ('anything', 'PN'),
#   ('extraordinary', 'JJ'),
#   ('now', 'RB'),
#   ('.', '.')],
#  [('When', 'WRB'),
#   ('a', 'AT'),
#   ('woman', 'NN'),
#   ('has', 'HVZ'),
#   ('five', 'CD'),
#   ('grown-up', 'JJ'),
#   ('daughters', 'NNS'),
#   (',', ','),
#   ('she', 'PPS'),
#   ('ought', 'MD'),
#   ('to', 'TO'),
#   ('give', 'VB'),
#   ('over', 'RP'),
#   ('thinking', 'VBG'),
#   ('of', 'IN'),
#   ('her', 'PP$'),
#   ('own', 'JJ'),
#   ('beauty', 'NN'),
#   ('.', '.'),
#   ("''", "''")],
#  [('``', '``'),
#   ('In', 'IN'),
#   ('such', 'JJ'),
#   ('cases', 'NNS'),
#   (',', ','),
#   ('a', 'AT'),
#   ('woman', 'NN'),
#   ('has', 'HVZ'),
#   ('not', '*'),
#   ('often', 'RB'),
#   ('much', 'QL'),
#   ('beauty', 'NN'),
#   ('to', 'IN'),
#   ('think', 'VB'),
#   ('of', 'IN'),
#   ('.', '.'),
#   ("''", "''")],
#  [('``', '``'),
#   ('But', 'CC'),
#   (',', ','),
#   ('my', 'PP$'),
#   ('dear', 'NN'),
#   (',', ','),
#   ('you', 'PPSS'),
#   ('must', 'MD'),
#   ('indeed', 'RB'),
#   ('go', 'VB'),
#   ('and', 'CC'),
#   ('see', 'VB'),
#   ('Mr.', 'NP'),
#   ('Bingley', 'NN'),
#   ('when', 'WRB'),
#   ('he', 'PPS'),
#   ('comes', 'VBZ'),
#   ('into', 'IN'),
#   ('the', 'AT'),
#   ('neighbourhood', 'NN'),
#   ('.', '.'),
#   ("''", "''")],
#  [('``', '``'),
#   ('It', 'PPS'),
#   ('is', 'BEZ'),
#   ('more', 'QL'),
#   ('than', 'CS'),
#   ('I', 'PPSS'),
#   ('engage', 'VB'),
#   ('for', 'IN'),
#   (',', ','),
#   ('I', 'PPSS'),
#   ('assure', 'VB'),
#   ('you', 'PPO'),
#   ('.', '.'),
#   ("''", "''")],
#  [('``', '``'),
#   ('But', 'CC'),
#   ('consider', 'VB'),
#   ('your', 'PP$'),
#   ('daughters', 'NNS'),
#   ('.', '.')],
#  [('Only', 'RB'),
#   ('think', 'VB'),
#   ('what', 'WDT'),
#   ('an', 'AT'),
#   ('establishment', 'NN'),
#   ('it', 'PPS'),
#   ('would', 'MD'),
#   ('be', 'BE'),
#   ('for', 'IN'),
#   ('one', 'CD'),
#   ('of', 'IN'),
#   ('them', 'PPO'),
#   ('.', '.')],
#  [('Sir', 'NP'),
#   ('William', 'NP'),
#   ('and', 'CC'),
#   ('Lady', 'NN-TL'),
#   ('Lucas', 'NP'),
#   ('are', 'BER'),
#   ('determined', 'VBN'),
#   ('to', 'TO'),
#   ('go', 'VB'),
#   (',', ','),
#   ('merely', 'RB'),
#   ('on', 'IN'),
#   ('that', 'DT'),
#   ('account', 'NN'),
#   (',', ','),
#   ('for', 'IN'),
#   ('in', 'IN'),
#   ('general', 'JJ'),
#   (',', ','),
#   ('you', 'PPSS'),
#   ('know', 'VB'),
#   (',', ','),
#   ('they', 'PPSS'),
#   ('visit', 'VB'),
#   ('no', 'AT'),
#   ('newcomers', 'NNS'),
#   ('.', '.')],
#  [('Indeed', 'RB'),
#   ('you', 'PPSS'),
#   ('must', 'MD'),
#   ('go', 'VB'),
#   (',', ','),
#   ('for', 'IN'),
#   ('it', 'PPO'),
#   ('will', 'MD'),
#   ('be', 'BE'),
#   ('impossible', 'JJ'),
#   ('for', 'IN'),
#   ('_us_', 'NN'),
#   ('to', 'IN'),
#   ('visit', 'NN'),
#   ('him', 'PPO'),
#   ('if', 'CS'),
#   ('you', 'PPSS'),
#   ('do', 'DO'),
#   ('not', '*'),
#   ('.', '.'),
#   ("''", "''")],
#  [('``', '``'),
#   ('You', 'PPSS'),
#   ('are', 'BER'),
#   ('over-scrupulous', 'NN'),
#   (',', ','),
#   ('surely', 'RB'),
#   ('.', '.')],
#  [('I', 'PPSS'),
#   ('dare', 'VB'),
#   ('say', 'VB'),
#   ('Mr.', 'NP'),
#   ('Bingley', 'NN'),
#   ('will', 'MD'),
#   ('be', 'BE'),
#   ('very', 'QL'),
#   ('glad', 'JJ'),
#   ('to', 'TO'),
#   ('see', 'VB'),
#   ('you', 'PPO'),
#   (';', '.'),
#   ('and', 'CC'),
#   ('I', 'PPSS'),
#   ('will', 'MD'),
#   ('send', 'VB'),
#   ('a', 'AT'),
#   ('few', 'AP'),
#   ('lines', 'NNS'),
#   ('by', 'IN'),
#   ('you', 'PPO'),
#   ('to', 'TO'),
#   ('assure', 'VB'),
#   ('him', 'PPO'),
#   ('of', 'IN'),
#   ('my', 'PP$'),
#   ('hearty', 'JJ'),
#   ('consent', 'NN'),
#   ('to', 'IN'),
#   ('his', 'PP$'),
#   ('marrying', 'VBG'),
#   ('whichever', 'WDT'),
#   ('he', 'PPS'),
#   ('chooses', 'VBZ'),
#   ('of', 'IN'),
#   ('the', 'AT'),
#   ('girls', 'NNS'),
#   (';', '.'),
#   ('though', 'CS'),
#   ('I', 'PPSS'),
#   ('must', 'MD'),
#   ('throw', 'VB'),
#   ('in', 'IN'),
#   ('a', 'AT'),
#   ('good', 'JJ'),
#   ('word', 'NN'),
#   ('for', 'IN'),
#   ('my', 'PP$'),
#   ('little', 'JJ'),
#   ('Lizzy', 'NP'),
#   ('.', '.'),
#   ("''", "''")],
#  [('``', '``'),
#   ('I', 'PPSS'),
#   ('desire', 'VB'),
#   ('you', 'PPO'),
#   ('will', 'MD'),
#   ('do', 'DO'),
#   ('no', 'AT'),
#   ('such', 'JJ'),
#   ('thing', 'NN'),
#   ('.', '.')],
#  [('Lizzy', 'NP'),
#   ('is', 'BEZ'),
#   ('not', '*'),
#   ('a', 'AT'),
#   ('bit', 'NN'),
#   ('better', 'RBR'),
#   ('than', 'CS'),
#   ('the', 'AT'),
#   ('others', 'NNS'),
#   (';', '.'),
#   ('and', 'CC'),
#   ('I', 'PPSS'),
#   ('am', 'BEM'),
#   ('sure', 'JJ'),
#   ('she', 'PPS'),
#   ('is', 'BEZ'),
#   ('not', '*'),
#   ('half', 'ABN'),
#   ('so', 'QL'),
#   ('handsome', 'JJ'),
#   ('as', 'CS'),
#   ('Jane', 'NP'),
#   (',', ','),
#   ('nor', 'CC'),
#   ('half', 'ABN'),
#   ('so', 'QL'),
#   ('good-humoured', 'NN'),
#   ('as', 'CS'),
#   ('Lydia', 'NP'),
#   ('.', '.')],
#  [('But', 'CC'),
#   ('you', 'PPSS'),
#   ('are', 'BER'),
#   ('always', 'RB'),
#   ('giving', 'VBG'),
#   ('_her_', 'NN'),
#   ('the', 'AT'),
#   ('preference', 'NN'),
#   ('.', '.'),
#   ("''", "''")],
#  [('``', '``'),
#   ('They', 'PPSS'),
#   ('have', 'HV'),
#   ('none', 'PN'),
#   ('of', 'IN'),
#   ('them', 'PPO'),
#   ('much', 'RB'),
#   ('to', 'IN'),
#   ('recommend', 'VB'),
#   ('them', 'PPO'),
#   (',', ','),
#   ("''", "''"),
#   ('replied', 'VBD'),
#   ('he', 'PPS'),
#   (';', '.'),
#   ('``', '``'),
#   ('they', 'PPSS'),
#   ('are', 'BER'),
#   ('all', 'ABN'),
#   ('silly', 'JJ'),
#   ('and', 'CC'),
#   ('ignorant', 'JJ'),
#   ('like', 'CS'),
#   ('other', 'AP'),
#   ('girls', 'NNS'),
#   (';', '.'),
#   ('but', 'CC'),
#   ('Lizzy', 'NP'),
#   ('has', 'HVZ'),
#   ('something', 'PN'),
#   ('more', 'AP'),
#   ('of', 'IN'),
#   ('quickness', 'NN'),
#   ('than', 'CS'),
#   ('her', 'PP$'),
#   ('sisters', 'NNS'),
#   ('.', '.'),
#   ("''", "''")],
#  [('``', '``'),
#   ('Mr.', 'NP'),
#   ('Bennet', 'NN'),
#   (',', ','),
#   ('how', 'WRB'),
#   ('_can_', 'NN'),
#   ('you', 'PPSS'),
#   ('abuse', 'NN'),
#   ('your', 'PP$'),
#   ('own', 'JJ'),
#   ('children', 'NNS'),
#   ('in', 'IN'),
#   ('such', 'JJ'),
#   ('a', 'AT'),
#   ('way', 'NN'),
#   ('?', '.')],
#  [('You', 'PPSS'),
#   ('take', 'VB'),
#   ('delight', 'NN'),
#   ('in', 'IN'),
#   ('vexing', 'VBG'),
#   ('me', 'PPO'),
#   ('.', '.')],
#  [('You', 'PPSS'),
#   ('have', 'HV'),
#   ('no', 'AT'),
#   ('compassion', 'NN'),
#   ('for', 'IN'),
#   ('my', 'PP$'),
#   ('poor', 'JJ'),
#   ('nerves', 'NNS'),
#   ('.', '.'),
#   ("''", "''")],
#  [('``', '``'),
#   ('You', 'PPSS'),
#   ('mistake', 'VB'),
#   ('me', 'PPO'),
#   (',', ','),
#   ('my', 'PP$'),
#   ('dear', 'NN'),
#   ('.', '.')],
#  [('I', 'PPSS'),
#   ('have', 'HV'),
#   ('a', 'AT'),
#   ('high', 'JJ'),
#   ('respect', 'NN'),
#   ('for', 'IN'),
#   ('your', 'PP$'),
#   ('nerves', 'NNS'),
#   ('.', '.')],
#  [('They', 'PPSS'),
#   ('are', 'BER'),
#   ('my', 'PP$'),
#   ('old', 'JJ'),
#   ('friends', 'NNS'),
#   ('.', '.')],
#  [('I', 'PPSS'),
#   ('have', 'HV'),
#   ('heard', 'VBN'),
#   ('you', 'PPO'),
#   ('mention', 'VB'),
#   ('them', 'PPO'),
#   ('with', 'IN'),
#   ('consideration', 'NN'),
#   ('these', 'DTS'),
#   ('last', 'AP'),
#   ('twenty', 'CD'),
#   ('years', 'NNS'),
#   ('at', 'IN'),
#   ('least', 'AP'),
#   ('.', '.'),
#   ("''", "''")],
#  [('``', '``'),
#   ('Ah', 'UH'),
#   (',', ','),
#   ('you', 'PPSS'),
#   ('do', 'DO'),
#   ('not', '*'),
#   ('know', 'VB'),
#   ('what', 'WDT'),
#   ('I', 'PPSS'),
#   ('suffer', 'VB'),
#   ('.', '.'),
#   ("''", "''")],
#  [('``', '``'),
#   ('But', 'CC'),
#   ('I', 'PPSS'),
#   ('hope', 'VB'),
#   ('you', 'PPO'),
#   ('will', 'MD'),
#   ('get', 'VB'),
#   ('over', 'RP'),
#   ('it', 'PPS'),
#   (',', ','),
#   ('and', 'CC'),
#   ('live', 'VB'),
#   ('to', 'TO'),
#   ('see', 'VB'),
#   ('many', 'AP'),
#   ('young', 'JJ'),
#   ('men', 'NNS'),
#   ('of', 'IN'),
#   ('four', 'CD'),
#   ('thousand', 'CD'),
#   ('a', 'AT'),
#   ('year', 'NN'),
#   ('come', 'VB'),
#   ('into', 'IN'),
#   ('the', 'AT'),
#   ('neighbourhood', 'NN'),
#   ('.', '.'),
#   ("''", "''")],
#  [('``', '``'),
#   ('It', 'PPS'),
#   ('will', 'MD'),
#   ('be', 'BE'),
#   ('no', 'AT'),
#   ('use', 'NN'),
#   ('to', 'IN'),
#   ('us', 'PPO'),
#   (',', ','),
#   ('if', 'CS'),
#   ('twenty', 'CD'),
#   ('such', 'JJ'),
#   ('should', 'MD'),
#   ('come', 'VB'),
#   (',', ','),
#   ('since', 'CS'),
#   ('you', 'PPSS'),
#   ('will', 'MD'),
#   ('not', '*'),
#   ('visit', 'NN'),
#   ('them', 'PPO'),
#   ('.', '.'),
#   ("''", "''")],
#  [('``', '``'),
#   ('Depend', 'NN'),
#   ('upon', 'IN'),
#   ('it', 'PPO'),
#   (',', ','),
#   ('my', 'PP$'),
#   ('dear', 'NN'),
#   (',', ','),
#   ('that', 'CS'),
#   ('when', 'WRB'),
#   ('there', 'EX'),
#   ('are', 'BER'),
#   ('twenty', 'CD'),
#   (',', ','),
#   ('I', 'PPSS'),
#   ('will', 'MD'),
#   ('visit', 'VB'),
#   ('them', 'PPO'),
#   ('all', 'ABN'),
#   ('.', '.'),
#   ("''", "''")],
#  [('Mr.', 'NP'),
#   ('Bennet', 'NN'),
#   ('was', 'BEDZ'),
#   ('so', 'QL'),
#   ('odd', 'JJ'),
#   ('a', 'AT'),
#   ('mixture', 'NN'),
#   ('of', 'IN'),
#   ('quick', 'JJ'),
#   ('parts', 'NNS'),
#   (',', ','),
#   ('sarcastic', 'JJ'),
#   ('humour', 'NN'),
#   (',', ','),
#   ('reserve', 'NN'),
#   (',', ','),
#   ('and', 'CC'),
#   ('caprice', 'NN'),
#   (',', ','),
#   ('that', 'CS'),
#   ('the', 'AT'),
#   ('experience', 'NN'),
#   ('of', 'IN'),
#   ('three-and-twenty', 'NN'),
#   ('years', 'NNS'),
#   ('had', 'HVD'),
#   ('been', 'BEN'),
#   ('insufficient', 'JJ'),
#   ('to', 'TO'),
#   ('make', 'VB'),
#   ('his', 'PP$'),
#   ('wife', 'NN'),
#   ('understand', 'VB'),
#   ('his', 'PP$'),
#   ('character', 'NN'),
#   ('.', '.')],
#  [('_Her_', 'NN'),
#   ('mind', 'NN'),
#   ('was', 'BEDZ'),
#   ('less', 'AP'),
#   ('difficult', 'JJ'),
#   ('to', 'TO'),
#   ('develop', 'VB'),
#   ('.', '.')],
#  [('She', 'PPS'),
#   ('was', 'BEDZ'),
#   ('a', 'AT'),
#   ('woman', 'NN'),
#   ('of', 'IN'),
#   ('mean', 'JJ'),
#   ('understanding', 'NN'),
#   (',', ','),
#   ('little', 'JJ'),
#   ('information', 'NN'),
#   (',', ','),
#   ('and', 'CC'),
#   ('uncertain', 'JJ'),
#   ('temper', 'NN'),
#   ('.', '.')],
#  [('When', 'WRB'),
#   ('she', 'PPS'),
#   ('was', 'BEDZ'),
#   ('discontented', 'JJ'),
#   (',', ','),
#   ('she', 'PPS'),
#   ('fancied', 'VBD'),
#   ('herself', 'PPL'),
#   ('nervous', 'JJ'),
#   ('.', '.')],
#  [('The', 'AT'),
#   ('business', 'NN'),
#   ('of', 'IN'),
#   ('her', 'PP$'),
#   ('life', 'NN'),
#   ('was', 'BEDZ'),
#   ('to', 'TO'),
#   ('get', 'VB'),
#   ('her', 'PPO'),
#   ('daughters', 'NNS'),
#   ('married', 'VBN'),
#   (';', '.'),
#   ('its', 'PP$'),
#   ('solace', 'NN'),
#   ('was', 'BEDZ'),
#   ('visiting', 'VBG'),
#   ('and', 'CC'),
#   ('news', 'NN'),
#   ('.', '.')],
#  [('Chapter', 'NN-HL'),
#   ('2', 'CD-HL'),
#   ('Mr.', 'NP'),
#   ('Bennet', 'NN'),
#   ('was', 'BEDZ'),
#   ('among', 'IN'),
#   ('the', 'AT'),
#   ('earliest', 'JJT'),
#   ('of', 'IN'),
#   ('those', 'DTS'),
#   ('who', 'WPS'),
#   ('waited', 'VBD'),
#   ('on', 'IN'),
#   ('Mr.', 'NP'),
#   ('Bingley', 'NN'),
#   ('.', '.')],
#  [('He', 'PPS'),
#   ('had', 'HVD'),
#   ('always', 'RB'),
#   ('intended', 'VBD'),
#   ('to', 'TO'),
#   ('visit', 'VB'),
#   ('him', 'PPO'),
#   (',', ','),
#   ('though', 'CS'),
#   ('to', 'TO'),
#   ('the', 'AT'),
#   ('last', 'AP'),
#   ('always', 'RB'),
#   ('assuring', 'VBG'),
#   ('his', 'PP$'),
#   ('wife', 'NN'),
#   ('that', 'CS'),
#   ('he', 'PPS'),
#   ('should', 'MD'),
#   ('not', '*'),
#   ('go', 'VB'),
#   (';', '.'),
#   ('and', 'CC'),
#   ('till', 'CS'),
#   ('the', 'AT'),
#   ('evening', 'NN'),
#   ('after', 'IN'),
#   ('the', 'AT'),
#   ('visit', 'NN'),
#   ('was', 'BEDZ'),
#   ('paid', 'VBN'),
#   ('she', 'PPS'),
#   ('had', 'HVD'),
#   ('no', 'AT'),
#   ('knowledge', 'NN'),
#   ('of', 'IN'),
#   ('it', 'PPO'),
#   ('.', '.')],
#  [('It', 'PPS'),
#   ('was', 'BEDZ'),
#   ('then', 'RB'),
#   ('disclosed', 'VBN'),
#   ('in', 'IN'),
#   ('the', 'AT'),
#   ('following', 'VBG'),
#   ('manner', 'NN'),
#   ('.', '.')],
#  [('Observing', 'VBG'),
#   ('his', 'PP$'),
#   ('second', 'OD'),
#   ('daughter', 'NN'),
#   ('employed', 'VBN'),
#   ('in', 'IN'),
#   ('trimming', 'NN'),
#   ('a', 'AT'),
#   ('hat', 'NN'),
#   (',', ','),
#   ('he', 'PPS'),
#   ('suddenly', 'RB'),
#   ('addressed', 'VBN'),
#   ('her', 'PPO'),
#   ('with', 'IN'),
#   (':', ':'),
#   ("''", "''"),
#   ('I', 'PPSS'),
#   ('hope', 'VB'),
#   ('Mr.', 'NP'),
#   ('Bingley', 'NN'),
#   ('will', 'MD'),
#   ('like', 'VB'),
#   ('it', 'PPO'),
#   (',', ','),
#   ('Lizzy', 'NP'),
#   ('.', '.'),
#   ("''", "''")],
#  [('``', '``'),
#   ('We', 'PPSS'),
#   ('are', 'BER'),
#   ('not', '*'),
#   ('in', 'IN'),
#   ('a', 'AT'),
#   ('way', 'NN'),
#   ('to', 'IN'),
#   ('know', 'VB'),
#   ('_what_', 'NN'),
#   ('Mr.', 'NP'),
#   ('Bingley', 'NN'),
#   ('likes', 'VBZ'),
#   (',', ','),
#   ("''", "''"),
#   ('said', 'VBD'),
#   ('her', 'PPO'),
#   ('mother', 'NN'),
#   ('resentfully', 'NN'),
#   (',', ','),
#   ('``', '``'),
#   ('since', 'CS'),
#   ('we', 'PPSS'),
#   ('are', 'BER'),
#   ('not', '*'),
#   ('to', 'TO'),
#   ('visit', 'VB'),
#   ('.', '.'),
#   ("''", "''")],
#  [('``', '``'),
#   ('But', 'CC'),
#   ('you', 'PPSS'),
#   ('forget', 'VB'),
#   (',', ','),
#   ('mamma', 'NN'),
#   (',', ','),
#   ("''", "''"),
#   ('said', 'VBD'),
#   ('Elizabeth', 'NP'),
#   (',', ','),
#   ('``', '``'),
#   ('that', 'CS'),
#   ('we', 'PPSS'),
#   ('shall', 'MD'),
#   ('meet', 'VB'),
#   ('him', 'PPO'),
#   ('at', 'IN'),
#   ('the', 'AT'),
#   ('assemblies', 'NNS'),
#   (',', ','),
#   ('and', 'CC'),
#   ('that', 'CS'),
#   ('Mrs.', 'NP'),
#   ('Long', 'NP'),
#   ('promised', 'VBD'),
#   ('to', 'TO'),
#   ('introduce', 'VB'),
#   ('him', 'PPO'),
#   ('.', '.'),
#   ("''", "''")],
#  [('``', '``'),
#   ('I', 'PPSS'),
#   ('do', 'DO'),
#   ('not', '*'),
#   ('believe', 'VB'),
#   ('Mrs.', 'NP'),
#   ('Long', 'NP'),
#   ('will', 'MD'),
#   ('do', 'DO'),
#   ('any', 'DTI'),
#   ('such', 'JJ'),
#   ('thing', 'NN'),
#   ('.', '.')],
#  [('She', 'PPS'),
#   ('has', 'HVZ'),
#   ('two', 'CD'),
#   ('nieces', 'NNS'),
#   ('of', 'IN'),
#   ('her', 'PP$'),
#   ('own', 'JJ'),
#   ('.', '.')],
#  [('She', 'PPS'),
#   ('is', 'BEZ'),
#   ('a', 'AT'),
#   ('selfish', 'JJ'),
#   (',', ','),
#   ('hypocritical', 'JJ'),
#   ('woman', 'NN'),
#   (',', ','),
#   ('and', 'CC'),
#   ('I', 'PPSS'),
#   ('have', 'HV'),
#   ('no', 'AT'),
#   ('opinion', 'NN'),
#   ('of', 'IN'),
#   ('her', 'PP$'),
#   ('.', '.'),
#   ("''", "''")],
#  [('``', '``'),
#   ('No', 'RB'),
#   ('more', 'QL'),
#   ('have', 'HV'),
#   ('I', 'PPSS'),
#   (',', ','),
#   ("''", "''"),
#   ('said', 'VBD'),
#   ('Mr.', 'NP'),
#   ('Bennet', 'NN'),
#   (';', '.'),
#   ('``', '``'),
#   ('and', 'CC'),
#   ('I', 'PPSS'),
#   ('am', 'BEM'),
#   ('glad', 'JJ'),
#   ('to', 'TO'),
#   ('find', 'VB'),
#   ('that', 'CS'),
#   ('you', 'PPSS'),
#   ('do', 'DO'),
#   ('not', '*'),
#   ('depend', 'VB'),
#   ('on', 'IN'),
#   ('her', 'PP$'),
#   ('serving', 'VBG'),
#   ('you', 'PPO'),
#   ('.', '.'),
#   ("''", "''")],
#  [('Mrs.', 'NP'),
#   ('Bennet', 'NN'),
#   ('deigned', 'VBD'),
#   ('not', '*'),
#   ('to', 'TO'),
#   ('make', 'VB'),
#   ('any', 'DTI'),
#   ('reply', 'NN'),
#   (',', ','),
#   ('but', 'CC'),
#   (',', ','),
#   ('unable', 'JJ'),
#   ('to', 'TO'),
#   ('contain', 'VB'),
#   ('herself', 'PPL'),
#   (',', ','),
#   ('began', 'VBD'),
#   ('scolding', 'VBG'),
#   ('one', 'CD'),
#   ('of', 'IN'),
#   ('her', 'PP$'),
#   ('daughters', 'NNS'),
#   ('.', '.')],
#  [('``', '``'),
#   ('Do', 'DO'),
#   ("n't", 'NN'),
#   ('keep', 'VB'),
#   ('coughing', 'VBG'),
#   ('so', 'RB'),
#   (',', ','),
#   ('Kitty', 'NP'),
#   (',', ','),
#   ('for', 'IN'),
#   ('Heaven', 'NN-TL'),
#   ("'s", 'NN'),
#   ('sake', 'NN'),
#   ('!', '.')],
#  [('Have', 'HV'),
#   ('a', 'AT'),
#   ('little', 'JJ'),
#   ('compassion', 'NN'),
#   ('on', 'IN'),
#   ('my', 'PP$'),
#   ('nerves', 'NNS'),
#   ('.', '.')],
#  [('You', 'PPSS'),
#   ('tear', 'VB'),
#   ('them', 'PPO'),
#   ('to', 'TO'),
#   ('pieces', 'NNS'),
#   ('.', '.'),
#   ("''", "''")],
#  [('``', '``'),
#   ('Kitty', 'NP'),
#   ('has', 'HVZ'),
#   ('no', 'AT'),
#   ('discretion', 'NN'),
#   ('in', 'IN'),
#   ('her', 'PP$'),
#   ('coughs', 'NN'),
#   (',', ','),
#   ("''", "''"),
#   ('said', 'VBD'),
#   ('her', 'PPO'),
#   ('father', 'NN'),
#   (';', '.'),
#   ('``', '``'),
#   ('she', 'PPS'),
#   ('times', 'NNS'),
#   ('them', 'PPO'),
#   ('ill.', 'NN'),
#   ("''", "''"),
#   ("''", "''"),
#   ('I', 'PPSS'),
#   ('do', 'DO'),
#   ('not', '*'),
#   ('cough', 'VB'),
#   ('for', 'IN'),
#   ('my', 'PP$'),
#   ('own', 'JJ'),
#   ('amusement', 'NN'),
#   (',', ','),
#   ("''", "''"),
#   ('replied', 'VBD'),
#   ('Kitty', 'NP'),
#   ('fretfully', 'NN'),
#   ('.', '.')],
#  [('``', '``'),
#   ('When', 'WRB'),
#   ('is', 'BEZ'),
#   ('your', 'PP$'),
#   ('next', 'AP'),
#   ('ball', 'NN'),
#   ('to', 'IN'),
#   ('be', 'BE'),
#   (',', ','),
#   ('Lizzy', 'NP'),
#   ('?', '.'),
#   ("''", "''")],
#  [('``', '``'),
#   ('To-morrow', 'NN'),
#   ('fortnight', 'NN'),
#   ('.', '.'),
#   ("''", "''")],
#  [('``', '``'),
#   ('Aye', 'NN'),
#   (',', ','),
#   ('so', 'CS'),
#   ('it', 'PPS'),
#   ('is', 'BEZ'),
#   (',', ','),
#   ("''", "''"),
#   ('cried', 'VBD'),
#   ('her', 'PPO'),
#   ('mother', 'NN'),
#   (',', ','),
#   ('``', '``'),
#   ('and', 'CC'),
#   ('Mrs.', 'NP'),
#   ('Long', 'NP'),
#   ('does', 'DOZ'),
#   ('not', '*'),
#   ('come', 'VB'),
#   ('back', 'RB'),
#   ('till', 'CS'),
#   ('the', 'AT'),
#   ('day', 'NN'),
#   ('before', 'IN'),
#   (';', '.'),
#   ('so', 'QL'),
#   ('it', 'PPS'),
#   ('will', 'MD'),
#   ('be', 'BE'),
#   ('impossible', 'JJ'),
#   ('for', 'IN'),
#   ('her', 'PP$'),
#   ('to', 'TO'),
#   ('introduce', 'VB'),
#   ('him', 'PPO'),
#   (',', ','),
#   ('for', 'IN'),
#   ('she', 'PPS-NC'),
#   ('will', 'MD'),
#   ('not', '*'),
#   ('know', 'VB'),
#   ('him', 'PPO'),
#   ('herself', 'PPL'),
#   ('.', '.'),
#   ("''", "''")],
#  [('``', '``'),
#   ('Then', 'RB'),
#   (',', ','),
#   ('my', 'PP$'),
#   ('dear', 'NN'),
#   (',', ','),
#   ('you', 'PPSS'),
#   ('may', 'MD'),
#   ('have', 'HV'),
#   ('the', 'AT'),
#   ('advantage', 'NN'),
#   ('of', 'IN'),
#   ('your', 'PP$'),
#   ('friend', 'NN'),
#   (',', ','),
#   ('and', 'CC'),
#   ('introduce', 'VB'),
#   ('Mr.', 'NP'),
#   ('Bingley', 'NN'),
#   ('to', 'IN'),
#   ('_her_', 'NN'),
#   ('.', '.'),
#   ("''", "''")],
#  [('``', '``'),
#   ('Impossible', 'JJ'),
#   (',', ','),
#   ('Mr.', 'NP'),
#   ('Bennet', 'NN'),
#   (',', ','),
#   ('impossible', 'JJ'),
#   (',', ','),
#   ('when', 'WRB'),
#   ('I', 'PPSS'),
#   ('am', 'BEM'),
#   ('not', '*'),
#   ('acquainted', 'VBN'),
#   ('with', 'IN'),
#   ('him', 'PPO'),
#   ('myself', 'PPL'),
#   (';', '.'),
#   ('how', 'WRB'),
#   ('can', 'MD'),
#   ('you', 'PPSS'),
#   ('be', 'BE'),
#   ('so', 'QL'),
#   ('teasing', 'VBG'),
#   ('?', '.'),
#   ("''", "''")],
#  [('``', '``'),
#   ('I', 'PPSS'),
#   ('honour', 'NN'),
#   ('your', 'PP$'),
#   ('circumspection', 'NN'),
#   ('.', '.')],
#  [('A', 'AT'),
#   ('fortnight', 'NN'),
#   ("'s", 'NN'),
#   ('acquaintance', 'NN'),
#   ('is', 'BEZ'),
#   ('certainly', 'RB'),
#   ('very', 'QL'),
#   ('little', 'AP'),
#   ('.', '.')],
#  [('One', 'CD'),
#   ('can', 'MD'),
#   ('not', '*'),
#   ('know', 'VB'),
#   ('what', 'WDT'),
#   ('a', 'AT'),
#   ('man', 'NN'),
#   ('really', 'RB'),
#   ('is', 'BEZ'),
#   ('by', 'IN'),
#   ('the', 'AT'),
#   ('end', 'NN'),
#   ('of', 'IN'),
#   ('a', 'AT'),
#   ('fortnight', 'NN'),
#   ('.', '.')],
#  [('But', 'CC'),
#   ('if', 'CS'),
#   ('_we_', 'NN'),
#   ('do', 'DO'),
#   ('not', '*'),
#   ('venture', 'NN'),
#   ('somebody', 'PN'),
#   ('else', 'RB'),
#   ('will', 'MD'),
#   (';', '.'),
#   ('and', 'CC'),
#   ('after', 'IN'),
#   ('all', 'ABN'),
#   (',', ','),
#   ('Mrs.', 'NP'),
#   ('Long', 'NP'),
#   ('and', 'CC'),
#   ('her', 'PP$'),
#   ('neices', 'NN'),
#   ('must', 'MD'),
#   ('stand', 'VB'),
#   ('their', 'PP$'),
#   ('chance', 'NN'),
#   (';', '.'),
#   ('and', 'CC'),
#   (',', ','),
#   ('therefore', 'RB'),
#   (',', ','),
#   ('as', 'CS'),
#   ('she', 'PPS'),
#   ('will', 'MD'),
#   ('think', 'VB'),
#   ('it', 'PPO'),
#   ('an', 'AT'),
#   ('act', 'NN'),
#   ('of', 'IN'),
#   ('kindness', 'NN'),
#   (',', ','),
#   ('if', 'CS'),
#   ('you', 'PPSS'),
#   ('decline', 'NN'),
#   ('the', 'AT'),
#   ('office', 'NN'),
#   (',', ','),
#   ('I', 'PPSS'),
#   ('will', 'MD'),
#   ('take', 'VB'),
#   ('it', 'PPO'),
#   ('on', 'IN'),
#   ('myself', 'PPL'),
#   ('.', '.'),
#   ("''", "''")],
#  [('The', 'AT'),
#   ('girls', 'NNS'),
#   ('stared', 'VBD'),
#   ('at', 'IN'),
#   ('their', 'PP$'),
#   ('father', 'NN'),
#   ('.', '.')],
#  [('Mrs.', 'NP'),
#   ('Bennet', 'NN'),
#   ('said', 'VBD'),
#   ('only', 'RB'),
#   (',', ','),
#   ('``', '``'),
#   ('Nonsense', 'NN'),
#   (',', ','),
#   ('nonsense', 'NN'),
#   ('!', '.'),
#   ("''", "''")],
#  [('``', '``'),
#   ('What', 'WDT'),
#   ('can', 'MD'),
#   ('be', 'BE'),
#   ('the', 'AT'),
#   ('meaning', 'NN'),
#   ('of', 'IN'),
#   ('that', 'DT'),
#   ('emphatic', 'JJ'),
#   ('exclamation', 'NN'),
#   ('?', '.'),
#   ("''", "''")],
#  [('cried', 'VBD'), ('he', 'PPS'), ('.', '.')],
#  [('``', '``'),
#   ('Do', 'DO'),
#   ('you', 'PPSS'),
#   ('consider', 'VB'),
#   ('the', 'AT'),
#   ('forms', 'NNS'),
#   ('of', 'IN'),
#   ('introduction', 'NN'),
#   (',', ','),
#   ('and', 'CC'),
#   ('the', 'AT'),
#   ('stress', 'NN'),
#   ('that', 'CS'),
#   ('is', 'BEZ'),
#   ('laid', 'VBN'),
#   ('on', 'IN'),
#   ('them', 'PPO'),
#   (',', ','),
#   ('as', 'CS'),
#   ('nonsense', 'NN'),
#   ('?', '.')],
#  [('I', 'PPSS'),
#   ('can', 'MD'),
#   ('not', '*'),
#   ('quite', 'QL'),
#   ('agree', 'VB'),
#   ('with', 'IN'),
#   ('you', 'PPO'),
#   ('_there_', 'NN'),
#   ('.', '.')],
#  [('What', 'WDT'),
#   ('say', 'VB'),
#   ('you', 'PPO'),
#   (',', ','),
#   ('Mary', 'NP'),
#   ('?', '.')],
#  [('For', 'IN'),
#   ('you', 'PPO'),
#   ('are', 'BER'),
#   ('a', 'AT'),
#   ('young', 'JJ'),
#   ('lady', 'NN'),
#   ('of', 'IN'),
#   ('deep', 'JJ'),
#   ('reflection', 'NN'),
#   (',', ','),
#   ('I', 'PPSS'),
#   ('know', 'VB'),
#   (',', ','),
#   ('and', 'CC'),
#   ('read', 'VB'),
#   ('great', 'JJ'),
#   ('books', 'NNS'),
#   ('and', 'CC'),
#   ('make', 'VB'),
#   ('extracts', 'NNS'),
#   ('.', '.'),
#   ("''", "''")],
#  [('Mary', 'NP'),
#   ('wished', 'VBD'),
#   ('to', 'TO'),
#   ('say', 'VB'),
#   ('something', 'PN'),
#   ('sensible', 'JJ'),
#   (',', ','),
#   ('but', 'CC'),
#   ('knew', 'VBD'),
#   ('not', '*'),
#   ('how', 'WRB'),
#   ('.', '.')],
#  [('``', '``'),
#   ('While', 'CS'),
#   ('Mary', 'NP'),
#   ('is', 'BEZ'),
#   ('adjusting', 'VBG'),
#   ('her', 'PP$'),
#   ('ideas', 'NNS'),
#   (',', ','),
#   ("''", "''"),
#   ('he', 'PPS'),
#   ('continued', 'VBD'),
#   (',', ','),
#   ('``', '``'),
#   ('let', 'VB'),
#   ('us', 'PPO'),
#   ('return', 'VB'),
#   ('to', 'TO'),
#   ('Mr', 'NN'),
#   ('.', '.')],
#  [('Bingley', 'NN'), ('.', '.'), ("''", "''")],
#  [('``', '``'),
#   ('I', 'PPSS'),
#   ('am', 'BEM'),
#   ('sick', 'JJ'),
#   ('of', 'IN'),
#   ('Mr.', 'NP'),
#   ('Bingley', 'NN'),
#   (',', ','),
#   ("''", "''"),
#   ('cried', 'VBD'),
#   ('his', 'PP$'),
#   ('wife', 'NN'),
#   ('.', '.')],
#  [('``', '``'),
#   ('I', 'PPSS'),
#   ('am', 'BEM'),
#   ('sorry', 'JJ'),
#   ('to', 'TO'),
#   ('hear', 'VB'),
#   ('_that_', 'NN'),
#   (';', '.'),
#   ('but', 'CC'),
#   ('why', 'WRB'),
#   ('did', 'DOD'),
#   ('not', '*'),
#   ('you', 'PPO'),
#   ('tell', 'VB'),
#   ('me', 'PPO'),
#   ('that', 'CS'),
#   ('before', 'RB'),
#   ('?', '.')],
#  [('If', 'CS'),
#   ('I', 'PPSS'),
#   ('had', 'HVD'),
#   ('known', 'VBN'),
#   ('as', 'CS'),
#   ('much', 'AP'),
#   ('this', 'DT'),
#   ('morning', 'NN'),
#   ('I', 'PPSS'),
#   ('certainly', 'RB'),
#   ('would', 'MD'),
#   ('not', '*'),
#   ('have', 'HV'),
#   ('called', 'VBN'),
#   ('on', 'IN'),
#   ('him', 'PPO'),
#   ('.', '.')],
#  [('It', 'PPS'),
#   ('is', 'BEZ'),
#   ('very', 'QL'),
#   ('unlucky', 'JJ'),
#   (';', '.'),
#   ('but', 'CC'),
#   ('as', 'CS'),
#   ('I', 'PPSS'),
#   ('have', 'HV'),
#   ('actually', 'RB'),
#   ('paid', 'VBN'),
#   ('the', 'AT'),
#   ('visit', 'NN'),
#   (',', ','),
#   ('we', 'PPSS'),
#   ('can', 'MD'),
#   ('not', '*'),
#   ('escape', 'VB'),
#   ('the', 'AT'),
#   ('acquaintance', 'NN'),
#   ('now', 'RB'),
#   ('.', '.'),
#   ("''", "''")],
#  [('The', 'AT'),
#   ('astonishment', 'NN'),
#   ('of', 'IN'),
#   ('the', 'AT'),
#   ('ladies', 'NNS'),
#   ('was', 'BEDZ'),
#   ('just', 'RB'),
#   ('what', 'WDT'),
#   ('he', 'PPS'),
#   ('wished', 'VBD'),
#   (';', '.'),
#   ('that', 'CS'),
#   ('of', 'IN'),
#   ('Mrs.', 'NP'),
#   ('Bennet', 'NN'),
#   ('perhaps', 'RB'),
#   ('surpassing', 'NN'),
#   ('the', 'AT'),
#   ('rest', 'NN'),
#   (';', '.'),
#   ('though', 'CS'),
#   (',', ','),
#   ('when', 'WRB'),
#   ('the', 'AT'),
#   ('first', 'OD'),
#   ('tumult', 'NN'),
#   ('of', 'IN'),
#   ('joy', 'NN'),
#   ('was', 'BEDZ'),
#   ('over', 'RP'),
#   (',', ','),
#   ('she', 'PPS'),
#   ('began', 'VBD'),
#   ('to', 'TO'),
#   ('declare', 'VB'),
#   ('that', 'CS'),
#   ('it', 'PPS'),
#   ('was', 'BEDZ'),
#   ('what', 'WDT'),
#   ('she', 'PPS'),
#   ('had', 'HVD'),
#   ('expected', 'VBN'),
#   ('all', 'ABN'),
#   ('the', 'AT'),
#   ('while', 'NN'),
#   ('.', '.')],
#  [('``', '``'),
#   ('How', 'WRB'),
#   ('good', 'JJ'),
#   ('it', 'PPS'),
#   ('was', 'BEDZ'),
#   ('in', 'IN'),
#   ('you', 'PPO'),
#   (',', ','),
#   ('my', 'PP$'),
#   ('dear', 'NN'),
#   ('Mr.', 'NP'),
#   ('Bennet', 'NN'),
#   ('!', '.')],
#  [('But', 'CC'),
#   ('I', 'PPSS'),
#   ('knew', 'VBD'),
#   ('I', 'PPSS'),
#   ('should', 'MD'),
#   ('persuade', 'VB'),
#   ('you', 'PPO'),
#   ('at', 'IN'),
#   ('last', 'AP'),
#   ('.', '.')],
#  [('I', 'PPSS'),
#   ('was', 'BEDZ'),
#   ('sure', 'JJ'),
#   ('you', 'PPSS'),
#   ('loved', 'VBD'),
#   ('your', 'PP$'),
#   ('girls', 'NNS'),
#   ('too', 'RB'),
#   ('well', 'RB'),
#   ('to', 'IN'),
#   ('neglect', 'NN'),
#   ('such', 'JJ'),
#   ('an', 'AT'),
#   ('acquaintance', 'NN'),
#   ('.', '.')],
#  [('Well', 'UH'),
#   (',', ','),
#   ('how', 'WRB'),
#   ('pleased', 'VBN'),
#   ('I', 'PPSS'),
#   ('am', 'BEM'),
#   ('!', '.')],
#  [('and', 'CC'),
#   ('it', 'PPS'),
#   ('is', 'BEZ'),
#   ('such', 'JJ'),
#   ('a', 'AT'),
#   ('good', 'JJ'),
#   ('joke', 'NN'),
#   (',', ','),
#   ('too', 'RB'),
#   (',', ','),
#   ('that', 'CS'),
#   ('you', 'PPSS'),
#   ('should', 'MD'),
#   ('have', 'HV'),
#   ('gone', 'VBN'),
#   ('this', 'DT'),
#   ('morning', 'NN'),
#   ('and', 'CC'),
#   ('never', 'RB'),
#   ('said', 'VBD'),
#   ('a', 'AT'),
#   ('word', 'NN'),
#   ('about', 'IN'),
#   ('it', 'PPO'),
#   ('till', 'CS'),
#   ('now', 'RB'),
#   ('.', '.'),
#   ("''", "''")],
#  [('``', '``'),
#   ('Now', 'RB'),
#   (',', ','),
#   ('Kitty', 'NP'),
#   (',', ','),
#   ('you', 'PPSS'),
#   ('may', 'MD'),
#   ('cough', 'VB'),
#   ('as', 'CS'),
#   ('much', 'AP'),
#   ('as', 'CS'),
#   ('you', 'PPSS'),
#   ('choose', 'VB'),
#   (',', ','),
#   ("''", "''"),
#   ('said', 'VBD'),
#   ('Mr.', 'NP'),
#   ('Bennet', 'NN'),
#   (';', '.'),
#   ('and', 'CC'),
#   (',', ','),
#   ('as', 'CS'),
#   ('he', 'PPS'),
#   ('spoke', 'VBD'),
#   (',', ','),
#   ('he', 'PPS'),
#   ('left', 'VBD'),
#   ('the', 'AT'),
#   ('room', 'NN'),
#   (',', ','),
#   ('fatigued', 'VBN'),
#   ('with', 'IN'),
#   ('the', 'AT'),
#   ('raptures', 'NNS'),
#   ('of', 'IN'),
#   ('his', 'PP$'),
#   ('wife', 'NN'),
#   ('.', '.')],
#  [('``', '``'),
#   ('What', 'WDT'),
#   ('an', 'AT'),
#   ('excellent', 'JJ'),
#   ('father', 'NN'),
#   ('you', 'PPSS'),
#   ('have', 'HV'),
#   (',', ','),
#   ('girls', 'NNS'),
#   ('!', '.'),
#   ("''", "''")],
#  [('said', 'VBD'),
#   ('she', 'PPS'),
#   (',', ','),
#   ('when', 'WRB'),
#   ('the', 'AT'),
#   ('door', 'NN'),
#   ('was', 'BEDZ'),
#   ('shut', 'VBN'),
#   ('.', '.')],
#  [('``', '``'),
#   ('I', 'PPSS'),
#   ('do', 'DO'),
#   ('not', '*'),
#   ('know', 'VB'),
#   ('how', 'WRB'),
#   ('you', 'PPSS'),
#   ('will', 'MD'),
#   ('ever', 'RB'),
#   ('make', 'VB'),
#   ('him', 'PPO'),
#   ('amends', 'NN'),
#   ('for', 'IN'),
#   ('his', 'PP$'),
#   ('kindness', 'NN'),
#   (';', '.'),
#   ('or', 'CC'),
#   ('me', 'PPO'),
#   (',', ','),
#   ('either', 'CC'),
#   (',', ','),
#   ('for', 'IN'),
#   ('that', 'DT'),
#   ('matter', 'NN'),
#   ('.', '.')],
#  [('At', 'IN'),
#   ('our', 'PP$'),
#   ('time', 'NN'),
#   ('of', 'IN'),
#   ('life', 'NN'),
#   ('it', 'PPS'),
#   ('is', 'BEZ'),
#   ('not', '*'),
#   ('so', 'QL'),
#   ('pleasant', 'JJ'),
#   (',', ','),
#   ('I', 'PPSS'),
#   ('can', 'MD'),
#   ('tell', 'VB'),
#   ('you', 'PPO'),
#   (',', ','),
#   ('to', 'TO'),
#   ('be', 'BE'),
#   ('making', 'VBG'),
#   ('new', 'JJ'),
#   ('acquaintances', 'NN'),
#   ('every', 'AT'),
#   ('day', 'NN'),
#   (';', '.'),
#   ('but', 'CC'),
#   ('for', 'IN'),
#   ('your', 'PP$'),
#   ('sakes', 'NN'),
#   (',', ','),
#   ('we', 'PPSS'),
#   ('would', 'MD'),
#   ('do', 'DO'),
#   ('anything', 'PN'),
#   ('.', '.')],
#  [('Lydia', 'NP'),
#   (',', ','),
#   ('my', 'PP$'),
#   ('love', 'NN'),
#   (',', ','),
#   ('though', 'CS'),
#   ('you', 'PPSS'),
#   ('_are_', 'NN'),
#   ('the', 'AT'),
#   ('youngest', 'JJT'),
#   (',', ','),
#   ('I', 'PPSS'),
#   ('dare', 'VB'),
#   ('say', 'VB'),
#   ('Mr.', 'NP'),
#   ('Bingley', 'NN'),
#   ('will', 'MD'),
#   ('dance', 'VB'),
#   ('with', 'IN'),
#   ('you', 'PPO'),
#   ('at', 'IN'),
#   ('the', 'AT'),
#   ('next', 'AP'),
#   ('ball', 'NN'),
#   ('.', '.'),
#   ("''", "''")],
#  [('``', '``'), ('Oh', 'UH'), ('!', '.'), ("''", "''")],
#  [('said', 'VBD'),
#   ('Lydia', 'NP'),
#   ('stoutly', 'RB'),
#   (',', ','),
#   ('``', '``'),
#   ('I', 'PPSS'),
#   ('am', 'BEM'),
#   ('not', '*'),
#   ('afraid', 'JJ'),
#   (';', '.'),
#   ('for', 'IN'),
#   ('though', 'CS'),
#   ('I', 'PPSS'),
#   ('_am_', 'NN'),
#   ('the', 'AT'),
#   ('youngest', 'JJT'),
#   (',', ','),
#   ('I', 'PPSS'),
#   ("'m", 'NN'),
#   ('the', 'AT'),
#   ('tallest', 'NN'),
#   ('.', '.'),
#   ("''", "''")],
#  [('The', 'AT'),
#   ('rest', 'NN'),
#   ('of', 'IN'),
#   ('the', 'AT'),
#   ('evening', 'NN'),
#   ('was', 'BEDZ'),
#   ('spent', 'VBN'),
#   ('in', 'IN'),
#   ('conjecturing', 'NN'),
#   ('how', 'WRB'),
#   ('soon', 'RB'),
#   ('he', 'PPS'),
#   ('would', 'MD'),
#   ('return', 'VB'),
#   ('Mr.', 'NP'),
#   ('Bennet', 'NN'),
#   ("'s", 'NN'),
#   ('visit', 'NN'),
#   (',', ','),
#   ('and', 'CC'),
#   ('determining', 'VBG'),
#   ('when', 'WRB'),
#   ('they', 'PPSS'),
#   ('should', 'MD'),
#   ('ask', 'VB'),
#   ('him', 'PPO'),
#   ('to', 'TO'),
#   ('dinner', 'NN'),
#   ('.', '.')],
#  [('Chapter', 'NN-HL'),
#   ('3', 'CD-HL'),
#   ('Not', '*'),
#   ('all', 'ABN'),
#   ('that', 'DT'),
#   ('Mrs.', 'NP'),
#   ('Bennet', 'NN'),
#   (',', ','),
#   ('however', 'RB'),
#   (',', ','),
#   ('with', 'IN'),
#   ('the', 'AT'),
#   ('assistance', 'NN'),
#   ('of', 'IN'),
#   ('her', 'PP$'),
#   ('five', 'CD'),
#   ('daughters', 'NNS'),
#   (',', ','),
#   ('could', 'MD'),
#   ('ask', 'VB'),
#   ('on', 'IN'),
#   ('the', 'AT'),
#   ('subject', 'NN'),
#   (',', ','),
#   ('was', 'BEDZ'),
#   ('sufficient', 'JJ'),
#   ('to', 'TO'),
#   ('draw', 'VB'),
#   ('from', 'IN'),
#   ('her', 'PP$'),
#   ('husband', 'NN'),
#   ('any', 'DTI'),
#   ('satisfactory', 'JJ'),
#   ('description', 'NN'),
#   ('of', 'IN'),
#   ('Mr.', 'NP'),
#   ('Bingley', 'NN'),
#   ('.', '.')],
#  [('They', 'PPSS'),
#   ('attacked', 'VBN'),
#   ('him', 'PPO'),
#   ('in', 'IN'),
#   ('various', 'JJ'),
#   ('ways', 'NNS'),
#   ('--', '--'),
#   ('with', 'IN'),
#   ('barefaced', 'NN'),
#   ('questions', 'NNS'),
#   (',', ','),
#   ('ingenious', 'JJ'),
#   ('suppositions', 'NNS'),
#   (',', ','),
#   ('and', 'CC'),
#   ('distant', 'JJ'),
#   ('surmises', 'NNS'),
#   (';', '.'),
#   ('but', 'CC'),
#   ('he', 'PPS'),
#   ('eluded', 'VBD'),
#   ('the', 'AT'),
#   ('skill', 'NN'),
#   ('of', 'IN'),
#   ('them', 'PPO'),
#   ('all', 'ABN'),
#   (',', ','),
#   ('and', 'CC'),
#   ('they', 'PPSS'),
#   ('were', 'BED'),
#   ('at', 'IN'),
#   ('last', 'AP'),
#   ('obliged', 'VBN'),
#   ('to', 'TO'),
#   ('accept', 'VB'),
#   ('the', 'AT'),
#   ('second-hand', 'NN'),
#   ('intelligence', 'NN'),
#   ('of', 'IN'),
#   ('their', 'PP$'),
#   ('neighbour', 'NN'),
#   (',', ','),
#   ('Lady', 'NN-TL'),
#   ('Lucas', 'NP'),
#   ('.', '.')],
#  [('Her', 'PP$'),
#   ('report', 'NN'),
#   ('was', 'BEDZ'),
#   ('highly', 'QL'),
#   ('favourable', 'NN'),
#   ('.', '.')],
#  [('Sir', 'NP'),
#   ('William', 'NP'),
#   ('had', 'HVD'),
#   ('been', 'BEN'),
#   ('delighted', 'VBN'),
#   ('with', 'IN'),
#   ('him', 'PPO'),
#   ('.', '.')],
#  [('He', 'PPS'),
#   ('was', 'BEDZ'),
#   ('quite', 'QL'),
#   ('young', 'JJ'),
#   (',', ','),
#   ('wonderfully', 'QL'),
#   ('handsome', 'JJ'),
#   (',', ','),
#   ('extremely', 'QL'),
#   ('agreeable', 'JJ'),
#   (',', ','),
#   ('and', 'CC'),
#   (',', ','),
#   ('to', 'TO'),
#   ('crown', 'NN'),
#   ('the', 'AT'),
#   ('whole', 'JJ'),
#   (',', ','),
#   ('he', 'PPS'),
#   ('meant', 'VBD'),
#   ('to', 'TO'),
#   ('be', 'BE'),
#   ('at', 'IN'),
#   ('the', 'AT'),
#   ('next', 'AP'),
#   ('assembly', 'NN'),
#   ('with', 'IN'),
#   ('a', 'AT'),
#   ('large', 'JJ'),
#   ('party', 'NN'),
#   ('.', '.')],
#  [('Nothing', 'PN'),
#   ('could', 'MD'),
#   ('be', 'BE'),
#   ('more', 'QL'),
#   ('delightful', 'JJ'),
#   ('!', '.')],
#  [('To', 'TO'),
#   ('be', 'BE'),
#   ('fond', 'JJ'),
#   ('of', 'IN'),
#   ('dancing', 'VBG'),
#   ('was', 'BEDZ'),
#   ('a', 'AT'),
#   ('certain', 'JJ'),
#   ('step', 'NN'),
#   ('towards', 'IN'),
#   ('falling', 'VBG'),
#   ('in', 'IN'),
#   ('love', 'NN'),
#   (';', '.'),
#   ('and', 'CC'),
#   ('very', 'QL'),
#   ('lively', 'JJ'),
#   ('hopes', 'NNS'),
#   ('of', 'IN'),
#   ('Mr.', 'NP'),
#   ('Bingley', 'NN'),
#   ("'s", 'NN'),
#   ('heart', 'NN'),
#   ('were', 'BED'),
#   ('entertained', 'VBN'),
#   ('.', '.')],
#  [('``', '``'),
#   ('If', 'CS'),
#   ('I', 'PPSS'),
#   ('can', 'MD'),
#   ('but', 'CC'),
#   ('see', 'VB'),
#   ('one', 'CD'),
#   ('of', 'IN'),
#   ('my', 'PP$'),
#   ('daughters', 'NNS'),
#   ('happily', 'RB'),
#   ('settled', 'VBN'),
#   ('at', 'IN'),
#   ('Netherfield', 'NN'),
#   (',', ','),
#   ("''", "''"),
#   ('said', 'VBD'),
#   ('Mrs.', 'NP'),
#   ('Bennet', 'NN'),
#   ('to', 'IN'),
#   ('her', 'PP$'),
#   ('husband', 'NN'),
#   (',', ','),
#   ('``', '``'),
#   ('and', 'CC'),
#   ('all', 'ABN'),
#   ('the', 'AT'),
#   ('others', 'NNS'),
#   ('equally', 'RB'),
#   ('well', 'RB'),
#   ('married', 'VBN'),
#   (',', ','),
#   ('I', 'PPSS'),
#   ('shall', 'MD'),
#   ('have', 'HV'),
#   ('nothing', 'PN'),
#   ('to', 'TO'),
#   ('wish', 'VB'),
#   ('for', 'IN'),
#   ('.', '.'),
#   ("''", "''")],
#  [('In', 'IN'),
#   ('a', 'AT'),
#   ('few', 'AP'),
#   ('days', 'NNS'),
#   ('Mr.', 'NP'),
#   ('Bingley', 'NN'),
#   ('returned', 'VBD'),
#   ('Mr.', 'NP'),
#   ('Bennet', 'NN'),
#   ("'s", 'NN'),
#   ('visit', 'NN'),
#   (',', ','),
#   ('and', 'CC'),
#   ('sat', 'VBD'),
#   ('about', 'IN'),
#   ('ten', 'CD'),
#   ('minutes', 'NNS'),
#   ('with', 'IN'),
#   ('him', 'PPO'),
#   ('in', 'IN'),
#   ('his', 'PP$'),
#   ('library', 'NN'),
#   ('.', '.')],
#  [('He', 'PPS'),
#   ('had', 'HVD'),
#   ('entertained', 'VBN'),
#   ('hopes', 'NNS'),
#   ('of', 'IN'),
#   ('being', 'BEG'),
#   ('admitted', 'VBN'),
#   ('to', 'TO'),
#   ('a', 'AT'),
#   ('sight', 'NN'),
#   ('of', 'IN'),
#   ('the', 'AT'),
#   ('young', 'JJ'),
#   ('ladies', 'NNS'),
#   (',', ','),
#   ('of', 'IN'),
#   ('whose', 'WP$'),
#   ('beauty', 'NN'),
#   ('he', 'PPS'),
#   ('had', 'HVD'),
#   ('heard', 'VBN'),
#   ('much', 'RB'),
#   (';', '.'),
#   ('but', 'CC'),
#   ('he', 'PPS'),
#   ('saw', 'VBD'),
#   ('only', 'RB'),
#   ('the', 'AT'),
#   ('father', 'NN'),
#   ('.', '.')],
#  [('The', 'AT'),
#   ('ladies', 'NNS'),
#   ('were', 'BED'),
#   ('somewhat', 'QL'),
#   ('more', 'QL'),
#   ('fortunate', 'JJ'),
#   (',', ','),
#   ('for', 'IN'),
#   ('they', 'PPSS'),
#   ('had', 'HVD'),
#   ('the', 'AT'),
#   ('advantage', 'NN'),
#   ('of', 'IN'),
#   ('ascertaining', 'NN'),
#   ('from', 'IN'),
#   ('an', 'AT'),
#   ('upper', 'JJ'),
#   ('window', 'NN'),
#   ('that', 'CS'),
#   ('he', 'PPS'),
#   ('wore', 'VBD'),
#   ('a', 'AT'),
#   ('blue', 'JJ'),
#   ('coat', 'NN'),
#   (',', ','),
#   ('and', 'CC'),
#   ('rode', 'VBD'),
#   ('a', 'AT'),
#   ('black', 'JJ'),
#   ('horse', 'NN'),
#   ('.', '.')],
#  [('An', 'AT'),
#   ('invitation', 'NN'),
#   ('to', 'IN'),
#   ('dinner', 'NN'),
#   ('was', 'BEDZ'),
#   ('soon', 'RB'),
#   ('afterwards', 'RB'),
#   ('dispatched', 'VBN'),
#   (';', '.'),
#   ('and', 'CC'),
#   ('already', 'RB'),
#   ('had', 'HVD'),
#   ('Mrs.', 'NP'),
#   ('Bennet', 'NN'),
#   ('planned', 'VBN'),
#   ('the', 'AT'),
#   ('courses', 'NNS'),
#   ('that', 'WPS'),
#   ('were', 'BED'),
#   ('to', 'TO'),
#   ('do', 'DO'),
#   ('credit', 'NN'),
#   ('to', 'IN'),
#   ('her', 'PP$'),
#   ('housekeeping', 'NN'),
#   (',', ','),
#   ('when', 'WRB'),
#   ('an', 'AT'),
#   ('answer', 'NN'),
#   ('arrived', 'VBD'),
#   ('which', 'WDT'),
#   ('deferred', 'NN'),
#   ('it', 'PPS'),
#   ('all', 'ABN'),
#   ('.', '.')],
#  [('Mr.', 'NP'),
#   ('Bingley', 'NN'),
#   ('was', 'BEDZ'),
#   ('obliged', 'VBN'),
#   ('to', 'TO'),
#   ('be', 'BE'),
#   ('in', 'IN'),
#   ('town', 'NN'),
#   ('the', 'AT'),
#   ('following', 'VBG'),
#   ('day', 'NN'),
#   (',', ','),
#   ('and', 'CC'),
#   (',', ','),
#   ('consequently', 'RB'),
#   (',', ','),
#   ('unable', 'JJ'),
#   ('to', 'TO'),
#   ('accept', 'VB'),
#   ('the', 'AT'),
#   ('honour', 'NN'),
#   ('of', 'IN'),
#   ('their', 'PP$'),
#   ('invitation', 'NN'),
#   (',', ','),
#   ('etc', 'NN'),
#   ('.', '.')],
#  [('Mrs.', 'NP'),
#   ('Bennet', 'NN'),
#   ('was', 'BEDZ'),
#   ('quite', 'QL'),
#   ('disconcerted', 'NN'),
#   ('.', '.')],
#  [('She', 'PPS'),
#   ('could', 'MD'),
#   ('not', '*'),
#   ('imagine', 'VB'),
#   ('what', 'WDT'),
#   ('business', 'NN'),
#   ('he', 'PPS'),
#   ('could', 'MD'),
#   ('have', 'HV'),
#   ('in', 'IN'),
#   ('town', 'NN'),
#   ('so', 'CS'),
#   ('soon', 'RB'),
#   ('after', 'IN'),
#   ('his', 'PP$'),
#   ('arrival', 'NN'),
#   ('in', 'IN'),
#   ('Hertfordshire', 'NN'),
#   (';', '.'),
#   ('and', 'CC'),
#   ('she', 'PPS'),
#   ('began', 'VBD'),
#   ('to', 'TO'),
#   ('fear', 'VB'),
#   ('that', 'CS'),
#   ('he', 'PPS'),
#   ('might', 'MD'),
#   ('be', 'BE'),
#   ('always', 'RB'),
#   ('flying', 'VBG'),
#   ('about', 'IN'),
#   ('from', 'IN'),
#   ('one', 'CD'),
#   ('place', 'NN'),
#   ('to', 'IN'),
#   ('another', 'DT'),
#   (',', ','),
#   ('and', 'CC'),
#   ('never', 'RB'),
#   ('settled', 'VBN'),
#   ('at', 'IN'),
#   ('Netherfield', 'NN'),
#   ('as', 'CS'),
#   ('he', 'PPS'),
#   ('ought', 'MD'),
#   ('to', 'TO'),
#   ('be', 'BE'),
#   ('.', '.')],
#  [('Lady', 'NN-TL'),
#   ('Lucas', 'NP'),
#   ('quieted', 'VBD'),
#   ('her', 'PPO'),
#   ('fears', 'NNS'),
#   ('a', 'AT'),
#   ('little', 'JJ'),
#   ('by', 'IN'),
#   ('starting', 'VBG'),
#   ('the', 'AT'),
#   ('idea', 'NN'),
#   ('of', 'IN'),
#   ('his', 'PP$'),
#   ('being', 'BEG'),
#   ('gone', 'VBN'),
#   ('to', 'TO'),
#   ('London', 'NP'),
#   ('only', 'RB'),
#   ('to', 'IN'),
#   ('get', 'VB'),
#   ('a', 'AT'),
#   ('large', 'JJ'),
#   ('party', 'NN'),
#   ('for', 'IN'),
#   ('the', 'AT'),
#   ('ball', 'NN'),
#   (';', '.'),
#   ('and', 'CC'),
#   ('a', 'AT'),
#   ('report', 'NN'),
#   ('soon', 'RB'),
#   ('followed', 'VBN'),
#   ('that', 'CS'),
#   ('Mr.', 'NP'),
#   ('Bingley', 'NN'),
#   ('was', 'BEDZ'),
#   ('to', 'TO'),
#   ('bring', 'VB'),
#   ('twelve', 'CD'),
#   ('ladies', 'NNS'),
#   ('and', 'CC'),
#   ('seven', 'CD'),
#   ('gentlemen', 'NNS'),
#   ('with', 'IN'),
#   ('him', 'PPO'),
#   ('to', 'TO'),
#   ('the', 'AT'),
#   ('assembly', 'NN'),
#   ('.', '.')],
#  [('The', 'AT'),
#   ('girls', 'NNS'),
#   ('grieved', 'NN'),
#   ('over', 'IN'),
#   ('such', 'JJ'),
#   ('a', 'AT'),
#   ('number', 'NN'),
#   ('of', 'IN'),
#   ('ladies', 'NNS'),
#   (',', ','),
#   ('but', 'CC'),
#   ('were', 'BED'),
#   ('comforted', 'VBN'),
#   ('the', 'AT'),
#   ('day', 'NN'),
#   ('before', 'IN'),
#   ('the', 'AT'),
#   ('ball', 'NN'),
#   ('by', 'IN'),
#   ('hearing', 'VBG'),
#   (',', ','),
#   ('that', 'CS'),
#   ('instead', 'RB'),
#   ('of', 'IN'),
#   ('twelve', 'CD'),
#   ('he', 'PPS'),
#   ('brought', 'VBD'),
#   ('only', 'RB'),
#   ('six', 'CD'),
#   ('with', 'IN'),
#   ('him', 'PPO'),
#   ('from', 'IN'),
#   ('London', 'NP'),
#   ('--', '--'),
#   ('his', 'PP$'),
#   ('five', 'CD'),
#   ('sisters', 'NNS'),
#   ('and', 'CC'),
#   ('a', 'AT'),
#   ('cousin', 'NN'),
#   ('.', '.')],
#  [('And', 'CC'),
#   ('when', 'WRB'),
#   ('the', 'AT'),
#   ('party', 'NN'),
#   ('entered', 'VBD'),
#   ('the', 'AT'),
#   ('assembly', 'NN'),
#   ('room', 'NN'),
#   ('it', 'PPS'),
#   ('consisted', 'VBD'),
#   ('of', 'IN'),
#   ('only', 'RB'),
#   ('five', 'CD'),
#   ('altogether', 'RB'),
#   ('--', '--'),
#   ('Mr.', 'NP'),
#   ('Bingley', 'NN'),
#   (',', ','),
#   ('his', 'PP$'),
#   ('two', 'CD'),
#   ('sisters', 'NNS'),
#   (',', ','),
#   ('the', 'AT'),
#   ('husband', 'NN'),
#   ('of', 'IN'),
#   ('the', 'AT'),
#   ('eldest', 'JJT'),
#   (',', ','),
#   ('and', 'CC'),
#   ('another', 'DT'),
#   ('young', 'JJ'),
#   ('man', 'NN'),
#   ('.', '.')],
#  [('Mr.', 'NP'),
#   ('Bingley', 'NN'),
#   ('was', 'BEDZ'),
#   ('good-looking', 'JJ'),
#   ('and', 'CC'),
#   ('gentlemanlike', 'NN'),
#   (';', '.'),
#   ('he', 'PPS'),
#   ('had', 'HVD'),
#   ('a', 'AT'),
#   ('pleasant', 'JJ'),
#   ('countenance', 'NN'),
#   (',', ','),
#   ('and', 'CC'),
#   ('easy', 'JJ'),
#   (',', ','),
#   ('unaffected', 'JJ'),
#   ('manners', 'NNS'),
#   ('.', '.')],
#  [('His', 'PP$'),
#   ('sisters', 'NNS'),
#   ('were', 'BED'),
#   ('fine', 'JJ'),
#   ('women', 'NNS'),
#   (',', ','),
#   ('with', 'IN'),
#   ('an', 'AT'),
#   ('air', 'NN'),
#   ('of', 'IN'),
#   ('decided', 'VBD'),
#   ('fashion', 'NN'),
#   ('.', '.')],
#  [('His', 'PP$'),
#   ('brother-in-law', 'NN'),
#   (',', ','),
#   ('Mr.', 'NP'),
#   ('Hurst', 'NN'),
#   (',', ','),
#   ('merely', 'RB'),
#   ('looked', 'VBD'),
#   ('the', 'AT'),
#   ('gentleman', 'NN'),
#   (';', '.'),
#   ('but', 'CC'),
#   ('his', 'PP$'),
#   ('friend', 'NN'),
#   ('Mr.', 'NP'),
#   ('Darcy', 'NN'),
#   ('soon', 'RB'),
#   ('drew', 'VBD'),
#   ('the', 'AT'),
#   ('attention', 'NN'),
#   ('of', 'IN'),
#   ('the', 'AT'),
#   ('room', 'NN'),
#   ('by', 'IN'),
#   ('his', 'PP$'),
#   ('fine', 'JJ'),
#   (',', ','),
#   ('tall', 'JJ'),
#   ('person', 'NN'),
#   (',', ','),
#   ('handsome', 'JJ'),
#   ('features', 'NNS'),
#   (',', ','),
#   ('noble', 'JJ'),
#   ('mien', 'NN'),
#   (',', ','),
#   ('and', 'CC'),
#   ('the', 'AT'),
#   ('report', 'NN'),
#   ('which', 'WDT'),
#   ('was', 'BEDZ'),
#   ('in', 'IN'),
#   ('general', 'JJ'),
#   ('circulation', 'NN'),
#   ('within', 'IN'),
#   ('five', 'CD'),
#   ('minutes', 'NNS'),
#   ('after', 'IN'),
#   ('his', 'PP$'),
#   ('entrance', 'NN'),
#   (',', ','),
#   ('of', 'IN'),
#   ('his', 'PP$'),
#   ('having', 'HVG'),
#   ('ten', 'CD'),
#   ('thousand', 'CD'),
#   ('a', 'AT'),
#   ('year', 'NN'),
#   ('.', '.')],
#  [('The', 'AT'),
#   ('gentlemen', 'NNS'),
#   ('pronounced', 'VBN'),
#   ('him', 'PPO'),
#   ('to', 'TO'),
#   ('be', 'BE'),
#   ('a', 'AT'),
#   ('fine', 'JJ'),
#   ('figure', 'NN'),
#   ('of', 'IN'),
#   ('a', 'AT'),
#   ('man', 'NN'),
#   (',', ','),
#   ('the', 'AT'),
#   ('ladies', 'NNS'),
#   ('declared', 'VBD'),
# ...
#   ('--', '--'),
#   ('and', 'CC'),
#   ('Miss', 'NP'),
#   ('Bingley', 'NN'),
#   ('was', 'BEDZ'),
#   ('uncivil', 'JJ'),
#   ('to', 'TO'),
#   ('_her_', 'NN'),
#   (',', ','),
#   ('and', 'CC'),
#   ('more', 'AP'),
#   ('teasing', 'VBG'),
#   ('than', 'CS'),
#   ('usual', 'JJ'),
#   ('to', 'TO'),
#   ('himself', 'PPL'),
#   ('.', '.')],
#  [('He', 'PPS'),
#   ('wisely', 'RB'),
#   ('resolved', 'VBN'),
#   ('to', 'TO'),
#   ('be', 'BE'),
#   ('particularly', 'QL'),
#   ('careful', 'JJ'),
#   ('that', 'CS'),
#   ('no', 'AT'),
#   ('sign', 'NN'),
#   ('of', 'IN'),
#   ('admiration', 'NN'),
#   ('should', 'MD'),
#   ('_now_', 'NN'),
#   ('escape', 'VB'),
#   ('him', 'PPO'),
#   (',', ','),
#   ('nothing', 'PN'),
#   ('that', 'WPS'),
#   ('could', 'MD'),
#   ('elevate', 'NN'),
#   ('her', 'PP$'),
#   ('with', 'IN'),
#   ('the', 'AT'),
#   ('hope', 'NN'),
#   ('of', 'IN'),
#   ('influencing', 'VBG'),
#   ('his', 'PP$'),
#   ('felicity', 'NN'),
#   (';', '.'),
#   ('sensible', 'JJ'),
#   ('that', 'CS'),
#   ('if', 'CS'),
#   ('such', 'JJ'),
#   ('an', 'AT'),
#   ('idea', 'NN'),
#   ('had', 'HVD'),
#   ('been', 'BEN'),
#   ('suggested', 'VBN'),
#   (',', ','),
#   ('his', 'PP$'),
#   ('behaviour', 'NN'),
#   ('during', 'IN'),
#   ('the', 'AT'),
#   ('last', 'AP'),
#   ('day', 'NN'),
#   ('must', 'MD'),
#   ('have', 'HV'),
#   ('material', 'NN'),
#   ('weight', 'NN'),
#   ('in', 'IN'),
#   ('confirming', 'VBG'),
#   ('or', 'CC'),
#   ('crushing', 'VBG'),
#   ('it', 'PPO'),
#   ('.', '.')],
#  [('Steady', 'JJ'),
#   ('to', 'TO'),
#   ('his', 'PP$'),
#   ('purpose', 'NN'),
#   (',', ','),
#   ('he', 'PPS'),
#   ('scarcely', 'RB'),
#   ('spoke', 'VBD'),
#   ('ten', 'CD'),
#   ('words', 'NNS'),
#   ('to', 'TO'),
#   ('her', 'PP$'),
#   ('through', 'IN'),
#   ('the', 'AT'),
#   ('whole', 'JJ'),
#   ('of', 'IN'),
#   ('Saturday', 'NR'),
#   (',', ','),
#   ('and', 'CC'),
#   ('though', 'CS'),
#   ('they', 'PPSS'),
#   ('were', 'BED'),
#   ('at', 'IN'),
#   ('one', 'CD'),
#   ('time', 'NN'),
#   ('left', 'VBN'),
#   ('by', 'IN'),
#   ('themselves', 'PPLS'),
#   ('for', 'IN'),
#   ('half-an-hour', 'NN'),
#   (',', ','),
#   ('he', 'PPS'),
#   ('adhered', 'VBN'),
#   ('most', 'AP'),
#   ('conscientiously', 'NN'),
#   ('to', 'IN'),
#   ('his', 'PP$'),
#   ('book', 'NN'),
#   (',', ','),
#   ('and', 'CC'),
#   ('would', 'MD'),
#   ('not', '*'),
#   ('even', 'RB'),
#   ('look', 'VB'),
#   ('at', 'IN'),
#   ('her', 'PP$'),
#   ('.', '.')],
#  [('On', 'IN'),
#   ('Sunday', 'NR'),
#   (',', ','),
#   ('after', 'IN'),
#   ('morning', 'NN'),
#   ('service', 'NN'),
#   (',', ','),
#   ('the', 'AT'),
#   ('separation', 'NN'),
#   (',', ','),
#   ('so', 'CS'),
#   ('agreeable', 'JJ'),
#   ('to', 'TO'),
#   ('almost', 'RB'),
#   ('all', 'ABN'),
#   (',', ','),
#   ('took', 'VBD'),
#   ('place', 'NN'),
#   ('.', '.')],
#  [('Miss', 'NP'),
#   ('Bingley', 'NN'),
#   ("'s", 'NN'),
#   ('civility', 'NN'),
#   ('to', 'IN'),
#   ('Elizabeth', 'NP'),
#   ('increased', 'VBD'),
#   ('at', 'IN'),
#   ('last', 'AP'),
#   ('very', 'QL'),
#   ('rapidly', 'RB'),
#   (',', ','),
#   ('as', 'CS'),
#   ('well', 'RB'),
#   ('as', 'CS'),
#   ('her', 'PP$'),
#   ('affection', 'NN'),
#   ('for', 'IN'),
#   ('Jane', 'NP'),
#   (';', '.'),
#   ('and', 'CC'),
#   ('when', 'WRB'),
#   ('they', 'PPSS'),
#   ('parted', 'VBD'),
#   (',', ','),
#   ('after', 'IN'),
#   ('assuring', 'VBG'),
#   ('the', 'AT'),
#   ('latter', 'AP'),
#   ('of', 'IN'),
#   ('the', 'AT'),
#   ('pleasure', 'NN'),
#   ('it', 'PPS'),
#   ('would', 'MD'),
#   ('always', 'RB'),
#   ('give', 'VB'),
#   ('her', 'PPO'),
#   ('to', 'TO'),
#   ('see', 'VB'),
#   ('her', 'PPO'),
#   ('either', 'RB'),
#   ('at', 'IN'),
#   ('Longbourn', 'NN'),
#   ('or', 'CC'),
#   ('Netherfield', 'NN'),
#   (',', ','),
#   ('and', 'CC'),
#   ('embracing', 'VBG'),
#   ('her', 'PP$'),
#   ('most', 'QL'),
#   ('tenderly', 'RB'),
#   (',', ','),
#   ('she', 'PPS'),
#   ('even', 'RB'),
#   ('shook', 'VBD'),
#   ('hands', 'NNS'),
#   ('with', 'IN'),
#   ('the', 'AT'),
#   ('former', 'AP'),
#   ('.', '.')],
#  [('Elizabeth', 'NP'),
#   ('took', 'VBD'),
#   ('leave', 'VB'),
#   ('of', 'IN'),
#   ('the', 'AT'),
#   ('whole', 'JJ'),
#   ('party', 'NN'),
#   ('in', 'IN'),
#   ('the', 'AT'),
#   ('liveliest', 'NN'),
#   ('of', 'IN'),
#   ('spirits', 'NNS'),
#   ('.', '.')],
#  [('They', 'PPSS'),
#   ('were', 'BED'),
#   ('not', '*'),
#   ('welcomed', 'VBD'),
#   ('home', 'NR'),
#   ('very', 'QL'),
#   ('cordially', 'NN'),
#   ('by', 'IN'),
#   ('their', 'PP$'),
#   ('mother', 'NN'),
#   ('.', '.')],
#  [('Mrs.', 'NP'),
#   ('Bennet', 'NN'),
#   ('wondered', 'VBD'),
#   ('at', 'IN'),
#   ('their', 'PP$'),
#   ('coming', 'NN'),
#   (',', ','),
#   ('and', 'CC'),
#   ('thought', 'VBD'),
#   ('them', 'PPO'),
#   ('very', 'QL'),
#   ('wrong', 'JJ'),
#   ('to', 'TO'),
#   ('give', 'VB'),
#   ('so', 'QL'),
#   ('much', 'AP'),
#   ('trouble', 'NN'),
#   (',', ','),
#   ('and', 'CC'),
#   ('was', 'BEDZ'),
#   ('sure', 'JJ'),
#   ('Jane', 'NP'),
#   ('would', 'MD'),
#   ('have', 'HV'),
#   ('caught', 'VBN'),
#   ('cold', 'JJ'),
#   ('again', 'RB'),
#   ('.', '.')],
#  [('But', 'CC'),
#   ('their', 'PP$'),
#   ('father', 'NN'),
#   (',', ','),
#   ('though', 'CS'),
#   ('very', 'QL'),
#   ('laconic', 'NN'),
#   ('in', 'IN'),
#   ('his', 'PP$'),
#   ('expressions', 'NNS'),
#   ('of', 'IN'),
#   ('pleasure', 'NN'),
#   (',', ','),
#   ('was', 'BEDZ'),
#   ('really', 'RB'),
#   ('glad', 'JJ'),
#   ('to', 'TO'),
#   ('see', 'VB'),
#   ('them', 'PPO'),
#   (';', '.'),
#   ('he', 'PPS'),
#   ('had', 'HVD'),
#   ('felt', 'VBN'),
#   ('their', 'PP$'),
#   ('importance', 'NN'),
#   ('in', 'IN'),
#   ('the', 'AT'),
#   ('family', 'NN'),
#   ('circle', 'NN'),
#   ('.', '.')],
#  [('The', 'AT'),
#   ('evening', 'NN'),
#   ('conversation', 'NN'),
#   (',', ','),
#   ('when', 'WRB'),
#   ('they', 'PPSS'),
#   ('were', 'BED'),
#   ('all', 'ABN'),
#   ('assembled', 'VBN'),
#   (',', ','),
#   ('had', 'HVD'),
#   ('lost', 'VBN'),
#   ('much', 'RB'),
#   ('of', 'IN'),
#   ('its', 'PP$'),
#   ('animation', 'NN'),
#   (',', ','),
#   ('and', 'CC'),
#   ('almost', 'RB'),
#   ('all', 'ABN'),
#   ('its', 'PP$'),
#   ('sense', 'NN'),
#   ('by', 'IN'),
#   ('the', 'AT'),
#   ('absence', 'NN'),
#   ('of', 'IN'),
#   ('Jane', 'NP'),
#   ('and', 'CC'),
#   ('Elizabeth', 'NP'),
#   ('.', '.')],
#  [('They', 'PPSS'),
#   ('found', 'VBD'),
#   ('Mary', 'NP'),
#   (',', ','),
#   ('as', 'CS'),
#   ('usual', 'JJ'),
#   (',', ','),
#   ('deep', 'JJ'),
#   ('in', 'IN'),
#   ('the', 'AT'),
#   ('study', 'NN'),
#   ('of', 'IN'),
#   ('thorough-bass', 'NN'),
#   ('and', 'CC'),
#   ('human', 'JJ'),
#   ('nature', 'NN'),
#   (';', '.'),
#   ('and', 'CC'),
#   ('had', 'HVD'),
#   ('some', 'DTI'),
#   ('extracts', 'NNS'),
#   ('to', 'TO'),
#   ('admire', 'VB'),
#   (',', ','),
#   ('and', 'CC'),
#   ('some', 'DTI'),
#   ('new', 'JJ'),
#   ('observations', 'NNS'),
#   ('of', 'IN'),
#   ('threadbare', 'JJ'),
#   ('morality', 'NN'),
#   ('to', 'IN'),
#   ('listen', 'VB'),
#   ('to', 'TO'),
#   ('.', '.')],
#  [('Catherine', 'NP'),
#   ('and', 'CC'),
#   ('Lydia', 'NP'),
#   ('had', 'HVD'),
#   ('information', 'NN'),
#   ('for', 'IN'),
#   ('them', 'PPO'),
#   ('of', 'IN'),
#   ('a', 'AT'),
#   ('different', 'JJ'),
#   ('sort', 'NN'),
#   ('.', '.')],
#  [('Much', 'AP'),
#   ('had', 'HVD'),
#   ('been', 'BEN'),
#   ('done', 'VBN'),
#   ('and', 'CC'),
#   ('much', 'QL'),
#   ('had', 'HVD'),
#   ('been', 'BEN'),
#   ('said', 'VBN'),
#   ('in', 'IN'),
#   ('the', 'AT'),
#   ('regiment', 'NN'),
#   ('since', 'CS'),
#   ('the', 'AT'),
#   ('preceding', 'VBG'),
#   ('Wednesday', 'NR'),
#   (';', '.'),
#   ('several', 'AP'),
#   ('of', 'IN'),
#   ('the', 'AT'),
#   ('officers', 'NNS'),
#   ('had', 'HVD'),
#   ('dined', 'VBN'),
#   ('lately', 'RB'),
#   ('with', 'IN'),
#   ('their', 'PP$'),
#   ('uncle', 'NN'),
#   (',', ','),
#   ('a', 'AT'),
#   ('private', 'JJ'),
#   ('had', 'HVD'),
#   ('been', 'BEN'),
#   ('flogged', 'VBD'),
#   (',', ','),
#   ('and', 'CC'),
#   ('it', 'PPS'),
#   ('had', 'HVD'),
#   ('actually', 'RB'),
#   ('been', 'BEN'),
#   ('hinted', 'VBN'),
#   ('that', 'CS'),
#   ('Colonel', 'NN-TL'),
#   ('Forster', 'NN'),
#   ('was', 'BEDZ'),
#   ('going', 'VBG'),
#   ('to', 'TO'),
#   ('be', 'BE'),
#   ('married', 'VBN'),
#   ('.', '.')],
#  [('Chapter', 'NN-HL'),
#   ('13', 'CD-HL'),
#   ("''", "''"),
#   ('I', 'PPSS'),
#   ('hope', 'VB'),
#   (',', ','),
#   ('my', 'PP$'),
#   ('dear', 'NN'),
#   (',', ','),
#   ("''", "''"),
#   ('said', 'VBD'),
#   ('Mr.', 'NP'),
#   ('Bennet', 'NN'),
#   ('to', 'IN'),
#   ('his', 'PP$'),
#   ('wife', 'NN'),
#   (',', ','),
#   ('as', 'CS'),
#   ('they', 'PPSS'),
#   ('were', 'BED'),
#   ('at', 'IN'),
#   ('breakfast', 'NN'),
#   ('the', 'AT'),
#   ('next', 'AP'),
#   ('morning', 'NN'),
#   (',', ','),
#   ('``', '``'),
#   ('that', 'CS'),
#   ('you', 'PPSS'),
#   ('have', 'HV'),
#   ('ordered', 'VBN'),
#   ('a', 'AT'),
#   ('good', 'JJ'),
#   ('dinner', 'NN'),
#   ('to-day', 'NR'),
#   (',', ','),
#   ('because', 'CS'),
#   ('I', 'PPSS'),
#   ('have', 'HV'),
#   ('reason', 'NN'),
#   ('to', 'IN'),
#   ('expect', 'VB'),
#   ('an', 'AT'),
#   ('addition', 'NN'),
#   ('to', 'IN'),
#   ('our', 'PP$'),
#   ('family', 'NN'),
#   ('party', 'NN'),
#   ('.', '.'),
#   ("''", "''")],
#  [('``', '``'),
#   ('Who', 'WPS'),
#   ('do', 'DO'),
#   ('you', 'PPSS'),
#   ('mean', 'VB'),
#   (',', ','),
#   ('my', 'PP$'),
#   ('dear', 'NN'),
#   ('?', '.')],
#  [('I', 'PPSS'),
#   ('know', 'VB'),
#   ('of', 'IN'),
#   ('nobody', 'PN'),
#   ('that', 'WPS'),
#   ('is', 'BEZ'),
#   ('coming', 'VBG'),
#   (',', ','),
#   ('I', 'PPSS'),
#   ('am', 'BEM'),
#   ('sure', 'JJ'),
#   (',', ','),
#   ('unless', 'CS'),
#   ('Charlotte', 'NP'),
#   ('Lucas', 'NP'),
#   ('should', 'MD'),
#   ('happen', 'VB'),
#   ('to', 'TO'),
#   ('call', 'VB'),
#   ('in', 'IN'),
#   ('--', '--'),
#   ('and', 'CC'),
#   ('I', 'PPSS'),
#   ('hope', 'VB'),
#   ('_my_', 'NN'),
#   ('dinners', 'NNS'),
#   ('are', 'BER'),
#   ('good', 'JJ'),
#   ('enough', 'QLP'),
#   ('for', 'IN'),
#   ('her', 'PP$'),
#   ('.', '.')],
#  [('I', 'PPSS'),
#   ('do', 'DO'),
#   ('not', '*'),
#   ('believe', 'VB'),
#   ('she', 'PPS'),
#   ('often', 'RB'),
#   ('sees', 'VBZ'),
#   ('such', 'JJ'),
#   ('at', 'IN'),
#   ('home', 'NR'),
#   ('.', '.'),
#   ("''", "''")],
#  [('``', '``'),
#   ('The', 'AT'),
#   ('person', 'NN'),
#   ('of', 'IN'),
#   ('whom', 'WPO'),
#   ('I', 'PPSS'),
#   ('speak', 'VB'),
#   ('is', 'BEZ'),
#   ('a', 'AT'),
#   ('gentleman', 'NN'),
#   (',', ','),
#   ('and', 'CC'),
#   ('a', 'AT'),
#   ('stranger', 'NN'),
#   ('.', '.'),
#   ("''", "''")],
#  [('Mrs.', 'NP'),
#   ('Bennet', 'NN'),
#   ("'s", 'NN'),
#   ('eyes', 'NNS'),
#   ('sparkled', 'VBD'),
#   ('.', '.')],
#  [('``', '``'),
#   ('A', 'AT'),
#   ('gentleman', 'NN'),
#   ('and', 'CC'),
#   ('a', 'AT'),
#   ('stranger', 'NN'),
#   ('!', '.')],
#  [('It', 'PPS'),
#   ('is', 'BEZ'),
#   ('Mr.', 'NP'),
#   ('Bingley', 'NN'),
#   (',', ','),
#   ('I', 'PPSS'),
#   ('am', 'BEM'),
#   ('sure', 'JJ'),
#   ('!', '.')],
#  [('Well', 'UH'),
#   (',', ','),
#   ('I', 'PPSS'),
#   ('am', 'BEM'),
#   ('sure', 'JJ'),
#   ('I', 'PPSS'),
#   ('shall', 'MD'),
#   ('be', 'BE'),
#   ('extremely', 'QL'),
#   ('glad', 'JJ'),
#   ('to', 'TO'),
#   ('see', 'VB'),
#   ('Mr.', 'NP'),
#   ('Bingley', 'NN'),
#   ('.', '.')],
#  [('But', 'CC'), ('--', '--'), ('good', 'JJ'), ('Lord', 'NN-TL'), ('!', '.')],
#  [('how', 'WRB'), ('unlucky', 'JJ'), ('!', '.')],
#  [('There', 'EX'),
#   ('is', 'BEZ'),
#   ('not', '*'),
#   ('a', 'AT'),
#   ('bit', 'NN'),
#   ('of', 'IN'),
#   ('fish', 'NN'),
#   ('to', 'IN'),
#   ('be', 'BE'),
#   ('got', 'VBD'),
#   ('to-day', 'NR'),
#   ('.', '.')],
#  [('Lydia', 'NP'),
#   (',', ','),
#   ('my', 'PP$'),
#   ('love', 'NN'),
#   (',', ','),
#   ('ring', 'NN'),
#   ('the', 'AT'),
#   ('bell', 'NN'),
#   ('--', '--'),
#   ('I', 'PPSS'),
#   ('must', 'MD'),
#   ('speak', 'VB'),
#   ('to', 'TO'),
#   ('Hill', 'NN-TL'),
#   ('this', 'DT'),
#   ('moment', 'NN'),
#   ('.', '.'),
#   ("''", "''")],
#  [('``', '``'),
#   ('It', 'PPS'),
#   ('is', 'BEZ'),
#   ('_not_', 'NN'),
#   ('Mr.', 'NP'),
#   ('Bingley', 'NN'),
#   (',', ','),
#   ("''", "''"),
#   ('said', 'VBD'),
#   ('her', 'PPO'),
#   ('husband', 'NN'),
#   (';', '.'),
#   ('``', '``'),
#   ('it', 'PPS'),
#   ('is', 'BEZ'),
#   ('a', 'AT'),
#   ('person', 'NN'),
#   ('whom', 'WPO'),
#   ('I', 'PPSS'),
#   ('never', 'RB'),
#   ('saw', 'VBD'),
#   ('in', 'IN'),
#   ('the', 'AT'),
#   ('whole', 'JJ'),
#   ('course', 'NN'),
#   ('of', 'IN'),
#   ('my', 'PP$'),
#   ('life', 'NN'),
#   ('.', '.'),
#   ("''", "''")],
#  [('This', 'DT'),
#   ('roused', 'VBD'),
#   ('a', 'AT'),
#   ('general', 'JJ'),
#   ('astonishment', 'NN'),
#   (';', '.'),
#   ('and', 'CC'),
#   ('he', 'PPS'),
#   ('had', 'HVD'),
#   ('the', 'AT'),
#   ('pleasure', 'NN'),
#   ('of', 'IN'),
#   ('being', 'BEG'),
#   ('eagerly', 'RB'),
#   ('questioned', 'VBD'),
#   ('by', 'IN'),
#   ('his', 'PP$'),
#   ('wife', 'NN'),
#   ('and', 'CC'),
#   ('his', 'PP$'),
#   ('five', 'CD'),
#   ('daughters', 'NNS'),
#   ('at', 'IN'),
#   ('once', 'RB'),
#   ('.', '.')],
#  [('After', 'IN'),
#   ('amusing', 'JJ'),
#   ('himself', 'PPL'),
#   ('some', 'DTI'),
#   ('time', 'NN'),
#   ('with', 'IN'),
#   ('their', 'PP$'),
#   ('curiosity', 'NN'),
#   (',', ','),
#   ('he', 'PPS'),
#   ('thus', 'RB'),
#   ('explained', 'VBN'),
#   (':', ':'),
#   ("''", "''"),
#   ('About', 'RB'),
#   ('a', 'AT'),
#   ('month', 'NN'),
#   ('ago', 'RB'),
#   ('I', 'PPSS'),
#   ('received', 'VBD'),
#   ('this', 'DT'),
#   ('letter', 'NN'),
#   (';', '.'),
#   ('and', 'CC'),
#   ('about', 'IN'),
#   ('a', 'AT'),
#   ('fortnight', 'NN'),
#   ('ago', 'RB'),
#   ('I', 'PPSS'),
#   ('answered', 'VBD'),
#   ('it', 'PPO'),
#   (',', ','),
#   ('for', 'IN'),
#   ('I', 'PPSS-NC'),
#   ('thought', 'VBD'),
#   ('it', 'PPO'),
#   ('a', 'AT'),
#   ('case', 'NN'),
#   ('of', 'IN'),
#   ('some', 'DTI'),
#   ('delicacy', 'NN'),
#   (',', ','),
#   ('and', 'CC'),
#   ('requiring', 'VBG'),
#   ('early', 'JJ'),
#   ('attention', 'NN'),
#   ('.', '.')],
#  [('It', 'PPS'),
#   ('is', 'BEZ'),
#   ('from', 'IN'),
#   ('my', 'PP$'),
#   ('cousin', 'NN'),
#   (',', ','),
#   ('Mr.', 'NP'),
#   ('Collins', 'NP'),
#   (',', ','),
#   ('who', 'WPS'),
#   (',', ','),
#   ('when', 'WRB'),
#   ('I', 'PPSS'),
#   ('am', 'BEM'),
#   ('dead', 'JJ'),
#   (',', ','),
#   ('may', 'MD'),
#   ('turn', 'VB'),
#   ('you', 'PPO'),
#   ('all', 'ABN'),
#   ('out', 'RP'),
#   ('of', 'IN'),
#   ('this', 'DT'),
#   ('house', 'NN'),
#   ('as', 'CS'),
#   ('soon', 'RB'),
#   ('as', 'CS'),
#   ('he', 'PPS'),
#   ('pleases', 'VBZ'),
#   ('.', '.'),
#   ("''", "''")],
#  [('``', '``'), ('Oh', 'UH'), ('!', '.')],
#  [('my', 'PP$'),
#   ('dear', 'NN'),
#   (',', ','),
#   ("''", "''"),
#   ('cried', 'VBD'),
#   ('his', 'PP$'),
#   ('wife', 'NN'),
#   (',', ','),
#   ('``', '``'),
#   ('I', 'PPSS'),
#   ('can', 'MD'),
#   ('not', '*'),
#   ('bear', 'VB'),
#   ('to', 'TO'),
#   ('hear', 'VB'),
#   ('that', 'CS'),
#   ('mentioned', 'VBN'),
#   ('.', '.')],
#  [('Pray', 'NN'),
#   ('do', 'DO'),
#   ('not', '*'),
#   ('talk', 'VB'),
#   ('of', 'IN'),
#   ('that', 'DT'),
#   ('odious', 'JJ'),
#   ('man', 'NN'),
#   ('.', '.')],
#  [('I', 'PPSS'),
#   ('do', 'DO'),
#   ('think', 'VB'),
#   ('it', 'PPO'),
#   ('is', 'BEZ'),
#   ('the', 'AT'),
#   ('hardest', 'JJT'),
#   ('thing', 'NN'),
#   ('in', 'IN'),
#   ('the', 'AT'),
#   ('world', 'NN'),
#   (',', ','),
#   ('that', 'CS'),
#   ('your', 'PP$'),
#   ('estate', 'NN'),
#   ('should', 'MD'),
#   ('be', 'BE'),
#   ('entailed', 'NN'),
#   ('away', 'RB'),
#   ('from', 'IN'),
#   ('your', 'PP$'),
#   ('own', 'JJ'),
#   ('children', 'NNS'),
#   (';', '.'),
#   ('and', 'CC'),
#   ('I', 'PPSS'),
#   ('am', 'BEM'),
#   ('sure', 'JJ'),
#   (',', ','),
#   ('if', 'CS'),
#   ('I', 'PPSS'),
#   ('had', 'HVD'),
#   ('been', 'BEN'),
#   ('you', 'PPSS'),
#   (',', ','),
#   ('I', 'PPSS'),
#   ('should', 'MD'),
#   ('have', 'HV'),
#   ('tried', 'VBN'),
#   ('long', 'RB'),
#   ('ago', 'RB'),
#   ('to', 'IN'),
#   ('do', 'DO'),
#   ('something', 'PN'),
#   ('or', 'CC'),
#   ('other', 'AP'),
#   ('about', 'IN'),
#   ('it', 'PPO'),
#   ('.', '.'),
#   ("''", "''")],
#  [('Jane', 'NP'),
#   ('and', 'CC'),
#   ('Elizabeth', 'NP'),
#   ('tried', 'VBD'),
#   ('to', 'TO'),
#   ('explain', 'VB'),
#   ('to', 'TO'),
#   ('her', 'PP$'),
#   ('the', 'AT'),
#   ('nature', 'NN'),
#   ('of', 'IN'),
#   ('an', 'AT'),
#   ('entail', 'VB'),
#   ('.', '.')],
#  [('They', 'PPSS'),
#   ('had', 'HVD'),
#   ('often', 'RB'),
#   ('attempted', 'VBN'),
#   ('to', 'TO'),
#   ('do', 'DO'),
#   ('it', 'PPO'),
#   ('before', 'RB'),
#   (',', ','),
#   ('but', 'CC'),
#   ('it', 'PPS'),
#   ('was', 'BEDZ'),
#   ('a', 'AT'),
#   ('subject', 'NN'),
#   ('on', 'IN'),
#   ('which', 'WDT'),
#   ('Mrs.', 'NP'),
#   ('Bennet', 'NN'),
#   ('was', 'BEDZ'),
#   ('beyond', 'IN'),
#   ('the', 'AT'),
#   ('reach', 'NN'),
#   ('of', 'IN'),
#   ('reason', 'NN'),
#   (',', ','),
#   ('and', 'CC'),
#   ('she', 'PPS'),
#   ('continued', 'VBD'),
#   ('to', 'TO'),
#   ('rail', 'NN'),
#   ('bitterly', 'RB'),
#   ('against', 'IN'),
#   ('the', 'AT'),
#   ('cruelty', 'NN'),
#   ('of', 'IN'),
#   ('settling', 'VBG'),
#   ('an', 'AT'),
#   ('estate', 'NN'),
#   ('away', 'RB'),
#   ('from', 'IN'),
#   ('a', 'AT'),
#   ('family', 'NN'),
#   ('of', 'IN'),
#   ('five', 'CD'),
#   ('daughters', 'NNS'),
#   (',', ','),
#   ('in', 'IN'),
#   ('favour', 'NN'),
#   ('of', 'IN'),
#   ('a', 'AT'),
#   ('man', 'NN'),
#   ('whom', 'WPO'),
#   ('nobody', 'PN'),
#   ('cared', 'VBD'),
#   ('anything', 'PN'),
#   ('about', 'IN'),
#   ('.', '.')],
#  ...]

# %% [markdown]
# **Chunker:** Code for the proper noun chunker goes here:

# %%
cp1 = nltk.RegexpParser('PN: {(<IN>|<NP>)<NN><.>|<,><NP><,>}')

# %% [markdown]
# **Test the Chunker:** Test your proper noun recognizer on a lot of sentences to see how well it is working.  You might want to add prepositions in order to improve your results.

# %%
pro_nouns = []
for sent in txt_tagged:
    tree = cp1.parse(sent)
    for subtree in tree.subtrees():
        if subtree.label() == 'PN': 
            pn = " ".join(str(e) for e in subtree[0:])
            print(pn)
            pro_nouns.append(pn)
# print(pro_nouns)
# Out:
# ('Mr.', 'NP') ('Bennet', 'NN') (',', ',')
# ('before', 'IN') ('Michaelmas', 'NN') (',', ',')
# ('Mr.', 'NP') ('Bennet', 'NN') (',', ',')
# ('of', 'IN') ('beauty', 'NN') (',', ',')
# ('Mr.', 'NP') ('Bennet', 'NN') (',', ',')
# ('Mr.', 'NP') ('Bingley', 'NN') ('.', '.')
# ('Mr.', 'NP') ('Bennet', 'NN') (';', '.')
# ('Kitty', 'NP') ('fretfully', 'NN') ('.', '.')
# ('to', 'IN') ('_her_', 'NN') ('.', '.')
# ('Mr.', 'NP') ('Bennet', 'NN') (',', ',')
# ('of', 'IN') ('kindness', 'NN') (',', ',')
# ('of', 'IN') ('introduction', 'NN') (',', ',')
# ('Mr.', 'NP') ('Bingley', 'NN') (',', ',')
# ('Mr.', 'NP') ('Bennet', 'NN') ('!', '.')
# ('Mr.', 'NP') ('Bennet', 'NN') (';', '.')
# ('Mrs.', 'NP') ('Bennet', 'NN') (',', ',')
# ('Mr.', 'NP') ('Bingley', 'NN') ('.', '.')
# ('in', 'IN') ('love', 'NN') (';', '.')
# ('at', 'IN') ('Netherfield', 'NN') (',', ',')
# ('in', 'IN') ('Hertfordshire', 'NN') (';', '.')
# ('Mr.', 'NP') ('Bingley', 'NN') (',', ',')
# ('Mr.', 'NP') ('Hurst', 'NN') (',', ',')
# ('Mr.', 'NP') ('Bingley', 'NN') (',', ',')
# ('at', 'IN') ('Netherfield', 'NN') ('.', '.')
# ('Miss', 'NP') ('Bingley', 'NN') (',', ',')
# ('Mrs.', 'NP') ('Bennet', 'NN') (',', ',')
# ('Mr.', 'NP') ('Bingley', 'NN') (',', ',')
# ('Mr.', 'NP') ('Bingley', 'NN') (',', ',')
# ('Mr.', 'NP') ('Darcy', 'NN') (',', ',')
# ('Miss', 'NP') ('Bennet', 'NN') ('.', '.')
# ('of', 'IN') ('time', 'NN') (';', '.')
# ('Mr.', 'NP') ('Bennet', 'NN') (',', ',')
# ('of', 'IN') ('_that_', 'NN') (',', ',')
# ('for', 'IN') ('_me_', 'NN') (',', ',')
# ('of', 'IN') ('finery', 'NN') ('.', '.')
# ('Mr.', 'NP') ('Darcy', 'NN') ('.', '.')
# ('by', 'IN') ('surprise', 'NN') (',', ',')
# ('in', 'IN') ('silence', 'NN') (',', ',')
# ('in', 'IN') ('town', 'NN') (',', ',')
# ('of', 'IN') ('rank', 'NN') (',', ',')
# ('by', 'IN') ('trade', 'NN') ('.', '.')
# ('at', 'IN') ('Netherfield', 'NN') (',', ',')
# ('to', 'IN') ('purchase', 'NN') ('.', '.')
# ('Mrs.', 'NP') ('Hurst', 'NN') (',', ',')
# ('of', 'IN') ('character', 'NN') ('.', '.')
# ('Miss', 'NP') ('Bennet', 'NN') (',', ',')
# ('in', 'IN') ('Meryton', 'NN') (',', ',')
# ('from', 'IN') ('Meryton', 'NN') (',', ',')
# ('by', 'IN') ('business', 'NN') (',', ',')
# ('of', 'IN') ('woman', 'NN') (',', ',')
# ('Mrs.', 'NP') ('Bennet', 'NN') ('.', '.')
# ('about', 'IN') ('twenty-seven', 'NN') (',', ',')
# ('about', 'IN') ('Mr', 'NN') ('.', '.')
# ('Miss', 'NP') ('Bennet', 'NN') (',', ',')
# ('with', 'IN') ('pride', 'NN') (',', ',')
# ('with', 'IN') ('Eliza', 'NN') ('.', '.')
# ('with', 'IN') ('_him_', 'NN') (',', ',')
# ('with', 'IN') ('family', 'NN') (',', ',')
# ('Mr.', 'NP') ('Darcy', 'NN') (',', ',')
# ('of', 'IN') ('foxhounds', 'NN') (',', ',')
# ('Mrs.', 'NP') ('Bennet', 'NN') (';', '.')
# ('of', 'IN') ('Netherfield', 'NN') ('.', '.')
# ('Miss', 'NP') ('Bingley', 'NN') (';', '.')
# ('in', 'IN') ('love', 'NN') (';', '.')
# ('without', 'IN') ('encouragement', 'NN') ('.', '.')
# ('by', 'IN') ('design', 'NN') ('.', '.')
# ('at', 'IN') ('Meryton', 'NN') (';', '.')
# ('of', 'IN') ('chance', 'NN') ('.', '.')
# ('of', 'IN') ('vexation', 'NN') (';', '.')
# ('Lucas', 'NP') ("'s", 'NN') (',', ',')
# ('Mr.', 'NP') ('Darcy', 'NN') (',', ',')
# ('at', 'IN') ('Meryton', 'NN') ('?', '.')
# ('Mr.', 'NP') ('Darcy', 'NN') (',', ',')
# ('for', 'IN') ('display', 'NN') ('.', '.')
# ('Mr.', 'NP') ('Darcy', 'NN') ('!', '.')
# ('at', 'IN') ('Meryton', 'NN') (',', ',')
# ('at', 'IN') ('St', 'NN') ('.', '.')
# ('James', 'NP') ("'s", 'NN') ('?', '.')
# ('in', 'IN') ('town', 'NN') (',', ',')
# ('Miss', 'NP') ('Eliza', 'NN') (',', ',')
# ('Mr.', 'NP') ('Darcy', 'NN') (',', ',')
# ('Mr.', 'NP') ('Darcy', 'NN') (',', ',')
# ('at', 'IN') ('persuasion', 'NN') ('.', '.')
# ('Miss', 'NP') ('Eliza', 'NN') (',', ',')
# ('Miss', 'NP') ('Eliza', 'NN') (',', ',')
# ('Miss', 'NP') ('Bingley', 'NN') (':', ':')
# ('Elizabeth', 'NP') ('Bennet', 'NN') ('.', '.')
# ('Elizabeth', 'NP') ('Bennet', 'NN') ('!', '.')
# ('Miss', 'NP') ('Bingley', 'NN') ('.', '.')
# ('to', 'IN') ('love', 'NN') (',', ',')
# ('to', 'IN') ('matrimony', 'NN') (',', ',')
# ('of', 'IN') ('course', 'NN') (',', ',')
# ('in', 'IN') ('life', 'NN') (',', ',')
# ('in', 'IN') ('Meryton', 'NN') (',', ',')
# ('of', 'IN') ('trade', 'NN') ('.', '.')
# ('from', 'IN') ('Meryton', 'NN') (';', '.')
# ('Mrs.', 'NP') ('Bennet', 'NN') (',', ',')
# ('Mr.', 'NP') ('Bennet', 'NN') (',', ',')
# ('Miss', 'NP') ('Bennet', 'NN') (';', '.')
# ('from', 'IN') ('Netherfield', 'NN') (',', ',')
# ('with', 'IN') ('pleasure', 'NN') (',', ',')
# ('Miss', 'NP') ('Bingley', 'NN') (',', ',')
# ('of', 'IN') ('_that_', 'NN') ('.', '.')
# ('Mrs.', 'NP') ('Bennet', 'NN') (',', ',')
# ('on', 'IN') ('horseback', 'NN') (',', ',')
# ('Mr.', 'NP') ('Bennet', 'NN') (',', ',')
# ('on', 'IN') ('horseback', 'NN') (',', ',')
# ('without', 'IN') ('intermission', 'NN') (';', '.')
# ('Mr.', 'NP') ('Bennet', 'NN') (',', ',')
# ('Mr.', 'NP') ('Bingley', 'NN') (',', ',')
# ('by', 'IN') ('dinner', 'NN') ('.', '.')
# ('by', 'IN') ('reason', 'NN') (';', '.')
# ('of', 'IN') ('exercise', 'NN') ('.', '.')
# ('of', 'IN') ('surprise', 'NN') ('.', '.')
# ('Miss', 'NP') ('Bingley', 'NN') (';', '.')

# %% [markdown]
# **FreqDist Results:** After you have your proper noun recognizer working to your satisfaction, below  run it over your entire collection, feed the results into a FreqDist, and then print out the top 20 proper nouns by frequency.  That code goes here, along with the output:

# %%
fq = nltk.FreqDist(pro_nouns)
fq.most_common(20)
# Out:
# [("('for', 'IN') ('_me_', 'NN') (',', ',')", 1),
#  ("('of', 'IN') ('introduction', 'NN') (',', ',')", 1),
#  ("('at', 'IN') ('Netherfield', 'NN') (',', ',')", 1),
#  ("('before', 'IN') ('Michaelmas', 'NN') (',', ',')", 1),
#  ("('of', 'IN') ('_that_', 'NN') (',', ',')", 1),
#  ("('in', 'IN') ('Hertfordshire', 'NN') (';', '.')", 1),
#  ("('in', 'IN') ('love', 'NN') (';', '.')", 1),
#  ("('of', 'IN') ('time', 'NN') (';', '.')", 1),
#  ("('at', 'IN') ('Netherfield', 'NN') ('.', '.')", 1),
#  ("('of', 'IN') ('beauty', 'NN') (',', ',')", 1),
#  ("('of', 'IN') ('finery', 'NN') ('.', '.')", 1),
#  ("('to', 'IN') ('_her_', 'NN') ('.', '.')", 1),
#  ("('of', 'IN') ('kindness', 'NN') (',', ',')", 1)]
